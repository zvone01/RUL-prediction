# %% [markdown]
# multiple window sizes.
# idea is to have a couple of tcn with diffrent sizes
# output of those will go to NN
#
#      ---window size 10-- tcn --
#      ---window size 30-- tcn --
# input---window size 50-- tcn --  NN   -- result
#      ---window size 80-- tcn --
#      ---window size 99-- tcn --

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
from importlib.machinery import SourceFileLoader
somemodule = SourceFileLoader('tcn', '/content/drive/My Drive/Fax/Master Theses/keras-tcn-master/tcn/tcn.py').load_module()
# Out:
# TensorFlow 2.x selected.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Dropout, Embedding
from sklearn import preprocessing

import os
import tensorflow.keras as keras
import tensorflow.keras.backend as K
from tensorflow.python.keras.layers.core import Activation
from tensorflow.keras.models import Sequential,load_model, model_from_json

from tcn import TCN

# %%
# define paths
output_path = '/content/drive/My Drive/Fax/Master Theses/output-tcn-6-1'
tcn_models_path = '/content/drive/My Drive/Fax/Master Theses/output-tcn-6'

data_path = '/content/drive/My Drive/Fax/Master Theses/Data/CMAPSSData/'

# %%
##################################
# Data Ingestion
##################################

# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv(data_path+'train_FD001.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv(data_path+'test_FD001.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# read ground truth data - It contains the information of true remaining cycles for each engine in the testing data.
truth_df = pd.read_csv(data_path+'RUL_FD001.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %%
#MAXLIFE = 120
MAXLIFE = 137
def kink_RUL(cycle_list, max_cycle):
    '''
    Piecewise linear function with zero gradient and unit gradient

            ^
            |
    MAXLIFE |-----------
            |            \
            |             \
            |              \
            |               \
            |                \
            |----------------------->
    '''
    knee_point = max_cycle - MAXLIFE
    if knee_point <= 0:
      knee_point = 1
      
    kink_RUL = []
    stable_life = MAXLIFE
    for i in range(0, len(cycle_list)):
        if i < knee_point:
            kink_RUL.append(MAXLIFE)
        else:
            tmp = kink_RUL[i - 1] - (stable_life / (max_cycle - knee_point))
            kink_RUL.append(tmp)

    return kink_RUL


def compute_rul_of_one_id(FD00X_of_one_id, max_cycle_rul=None):
    '''
    Enter the data of an engine_id of train_FD001 and output the corresponding RUL (remaining life) of these data.
    type is list
    '''

    cycle_list = FD00X_of_one_id['cycle'].tolist()
    if max_cycle_rul is None:
        max_cycle = max(cycle_list)  # Failure cycle
    else:
        max_cycle = max(cycle_list) + max_cycle_rul
        # print(max(cycle_list), max_cycle_rul)

    # return kink_RUL(cycle_list,max_cycle)
    return kink_RUL(cycle_list, max_cycle)


def compute_rul_of_one_file(FD00X, id='engine_id', RUL_FD00X=None):
    '''
    Input train_FD001, output a list
    '''
    rul = []
    # In the loop train, each id value of the 'engine_id' column
    if RUL_FD00X is None:
        for _id in set(FD00X[id]):
            rul.extend(compute_rul_of_one_id(FD00X[FD00X[id] == _id]))
        return rul
    else:
        rul = []
        for _id in set(FD00X[id]):
            # print("#### id ####", int(RUL_FD00X.iloc[_id - 1]))
            true_rul.append(int(RUL_FD00X.iloc[_id - 1]))
            rul.extend(compute_rul_of_one_id(FD00X[FD00X[id] == _id], int(RUL_FD00X.iloc[_id - 1])))
        return rul

# %%
rul=[]

for id in train_df['id'].unique():
  rul.extend(compute_rul_of_one_id (train_df[train_df['id']== id]))

# %%
#######
# TRAIN set
#######
# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
#rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
#rul.columns = ['id', 'max']
#train_df = train_df.merge(rul, on=['id'], how='left')
#train_df['RUL'] = train_df['max'] - train_df['cycle']
#train_df.drop('max', axis=1, inplace=True)
train_df['RUL']= rul

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# %%
######
# TEST set
######
# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
print(test_df.head())

# We use the ground truth dataset to generate labels for the test data.
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)


#test_df.to_csv('../../Dataset/PredictiveManteinanceEngineValidation.csv', encoding='utf-8',index = None)
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  0.632184  0.750000  ...  0.0  0.558140  0.661834     0.00000
# 1   1      2  0.344828  0.250000  ...  0.0  0.682171  0.686827     0.00277
# 2   1      3  0.517241  0.583333  ...  0.0  0.728682  0.721348     0.00554
# 3   1      4  0.741379  0.500000  ...  0.0  0.666667  0.662110     0.00831
# 4   1      5  0.580460  0.500000  ...  0.0  0.658915  0.716377     0.01108
#
# [5 rows x 27 columns]

# %%
# pick a large window size of 50 cycles
#sequence_length = 32
# pick the feature columns 
sensor_cols = ['s' + str(i) for i in range(1,22)]
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)


# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
  
    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]
        
# function to generate labels
def gen_labels(id_df, seq_length, label):
  
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    return data_matrix[seq_length:num_elements, :]


# generator for the sequences
# transform each id of the train dataset in a sequence
def get_seq(sequence_length):
  seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
            for id in train_df['id'].unique())
  seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
  print(seq_array.shape)
  return seq_array

# generate labels
def get_lebels(sequence_length):
  label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
              for id in train_df['id'].unique()]

  label_array = np.concatenate(label_gen).astype(np.float32)
  return label_array

# %%
seq_array1 =  get_seq(10)
seq_array2 =  get_seq(30)
seq_array3 =  get_seq(50)
seq_array4 =  get_seq(70)
seq_array5 =  get_seq(90)

label_array1 = get_lebels(10)
label_array2 = get_lebels(30)
label_array3 = get_lebels(50)
label_array4 = get_lebels(70)
label_array5 = get_lebels(90)
# Out:
# (19631, 10, 25)
# (17631, 30, 25)
# (15631, 50, 25)
# (13631, 70, 25)
# (11631, 90, 25)

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))
        
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
##output tcn-6
def train_model(seq_array, label_array, id):
  
  model_path = output_path+'/tcn_model'+ id +'.h5'
  print(model_path)
  nb_features = seq_array.shape[2]
  nb_out = label_array.shape[1]
  sequence_length = seq_array.shape[1]

  i = Input(shape=(sequence_length, nb_features))

  #m = TCN(nb_filters=12,dropout_rate = 0.2,dilations=[1, 2, 4, 8, 16, 32] ,return_sequences=True)(i)
  #m = TCN(nb_filters=6,dropout_rate = 0.2,dilations=[1, 2, 4, 8, 16, 32] ,return_sequences=False)(m)

  m = TCN(nb_filters=12,dropout_rate = 0.2,return_sequences=True)(i)
  m = TCN(nb_filters=6,dropout_rate = 0.2,return_sequences=False)(m)
  m = Dense(1, activation='linear')(m)
  model = Model(inputs=[i], outputs=[m])
  model.summary()

  model.compile('adam', 'mae')
  model.compile(loss=root_mean_squared_error, optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])

  history = model.fit(seq_array, label_array, epochs=100, batch_size=200, validation_split=0.05, verbose=2,
            callbacks = [#keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='min'),
                        keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
            )
  return history, model

# %%
def plot_stats(history, model,id,seq_array,label_array):
  # list all data in history
  print(history.history.keys())

  # summarize history for R^2
  fig_acc = plt.figure(figsize=(10, 10))
  plt.plot(history.history['r2_keras'])
  plt.plot(history.history['val_r2_keras'])
  plt.title('model r^2')
  plt.ylabel('R^2')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  fig_acc.savefig(output_path+"/model"+id+"_r2.png")

  # summarize history for MAE
  fig_acc = plt.figure(figsize=(10, 10))
  plt.plot(history.history['mae'])
  plt.plot(history.history['val_mae'])
  plt.title('model MAE')
  plt.ylabel('MAE')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  fig_acc.savefig(output_path+"/model"+id+"_mae.png")


  # summarize history for RMSE
  fig_acc = plt.figure(figsize=(10, 10))
  plt.plot(history.history['root_mean_squared_error'])
  plt.plot(history.history['val_root_mean_squared_error'])
  plt.title('model RMSE')
  plt.ylabel('RMSE')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  fig_acc.savefig(output_path+"/model"+id+"_mae.png")

  # summarize history for Loss
  fig_acc = plt.figure(figsize=(10, 10))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  fig_acc.savefig(output_path+"/model"+id+"_regression_loss.png")

  # training metrics
  scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
  print('\nMAE: {}'.format(scores[1]))
  print('\nR^2: {}'.format(scores[2]))
  print('\nRMSE: {}'.format(scores[3]))

  y_pred = model.predict(seq_array,verbose=1, batch_size=200)
  y_true = label_array

# %%
##################################
# EVALUATE ON TEST DATA
##################################
def evaluate_on_test_data(model_path,id,sequence_length ):
  # We pick the last sequence for each id in the test data
  seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                        for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

  seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
  print("seq_array_test_last")
  print(seq_array_test_last.shape)

  # Similarly, we pick the labels
  #print("y_mask")
  y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
  label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
  label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
  print(label_array_test_last.shape)
  #print("label_array_test_last")
  #print(label_array_test_last)

  # if best iteration's model was saved then load and use it
  if os.path.isfile(model_path):

      # restore weights
      estimator = load_model(model_path,custom_objects={'r2_keras': r2_keras, 'root_mean_squared_error': root_mean_squared_error,'TCN': TCN})

      
      # test metrics
      scores_test = estimator.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
      print('\nMAE: {}'.format(scores_test[1]))
      print('\nR^2: {}'.format(scores_test[2]))
      print('\nRMSE: {}'.format(scores_test[3]))

      y_pred_test = estimator.predict(seq_array_test_last)
      y_true_test = label_array_test_last

      test_set = pd.DataFrame(y_pred_test)
      test_set.to_csv(output_path+'/submit_test'+id+'.csv', index = None)



      result = pd.DataFrame( columns = ['pred', 'true']) 
      result['pred'] = y_pred_test.flatten().round()
      result['true'] = y_true_test.flatten()
      result.sort_values(by='true', inplace=True)
      # Plot in blue color the predicted data and in orange color the
      # actual data to verify visually the accuracy of the model.
          
      x = np.arange(len(y_pred_test))
      width = 0.35  # the width of the bars

      fig, ax = plt.subplots(figsize=(100, 50))
      rects1 = ax.bar(x - width/2,result['pred'], width, label='predicted')
      rects2 = ax.bar(x + width/2,result['true'], width, label='true')

      # Add some text for labels, title and custom x-axis tick labels, etc.
      ax.set_ylabel('value')
      ax.set_title('prediction')
      ax.set_xticks(x)
      ax.legend()


      def autolabel(rects):
          """Attach a text label above each bar in *rects*, displaying its height."""
          for rect in rects:
              height = rect.get_height()
              ax.annotate('{}'.format(height),
                          xy=(rect.get_x() + rect.get_width() / 2, height),
                          xytext=(0, 3),  # 3 points vertical offset
                          textcoords="offset points",
                          ha='center', va='bottom')


      autolabel(rects1)
      autolabel(rects2)

      plt.show()
      fig.savefig(output_path+"/model"+id+"_verify_bar.png")

# %%
def train_tcn(id,seq_array,label_array):
  id = str(id)
  sequence_length = seq_array.shape[1]
  model_path = output_path+'/tcn_model'+ id +'.h5'

  history, model = train_model(seq_array, label_array, id)
  plot_stats(history,model,id, seq_array,label_array)
  evaluate_on_test_data(model_path,id,sequence_length )

# %% [markdown]
# #FUSE models

# %%
seq_array1new  = seq_array5[:,-seq_array1.shape[1]:,]
seq_array2new  = seq_array5[:,-seq_array2.shape[1]:,]
seq_array3new  = seq_array5[:,-seq_array3.shape[1]:,]
seq_array4new  = seq_array5[:,-seq_array4.shape[1]:,]

# %%
def get_encoded_data(model_path,data):
  if os.path.isfile(model_path):

      # restore weights

      model = load_model(model_path,custom_objects={'r2_keras': r2_keras, 'root_mean_squared_error': root_mean_squared_error,'TCN': TCN})
      estimator_model = Model(inputs=model.inputs, outputs=model.layers[2].output)
      #estimator_model.summary()
      encoded_data = estimator_model.predict(data,verbose=1, batch_size=200)
      return encoded_data

# %%
data1 = get_encoded_data(tcn_models_path+'/tcn_model1.h5',seq_array1new)
data2 = get_encoded_data(tcn_models_path+'/tcn_model2.h5',seq_array2new)
data3 = get_encoded_data(tcn_models_path+'/tcn_model3.h5',seq_array3new)
data4 = get_encoded_data(tcn_models_path+'/tcn_model4.h5',seq_array4new)
data5 = get_encoded_data(tcn_models_path+'/tcn_model5.h5',seq_array5)
# Out:
# 11631/11631 [==============================] - 2s 179us/sample
# 11631/11631 [==============================] - 3s 258us/sample
# 11631/11631 [==============================] - 4s 345us/sample
# 11631/11631 [==============================] - 5s 439us/sample
# 11631/11631 [==============================] - 6s 502us/sample

# %%
seq_array_new = np.array([data1,data2,data3,data4,data5])
seq_array_new = np.swapaxes(seq_array_new,0,1)
seq_array_new.shape
# Out:
# (11631, 5, 6)

# %%
# Train fuse TCN model:
##output tcn-6-1
 
model_path = output_path+'/tcn_model_fuse.h5'
print(model_path)
nb_features = seq_array_new.shape[2]
nb_out = label_array5.shape[1]
sequence_length = seq_array_new.shape[1]

i = Input(shape=(sequence_length, nb_features))

#m = TCN(nb_filters=12,dropout_rate = 0.2,dilations=[1, 2, 4, 8, 16, 32] ,return_sequences=True)(i)
#m = TCN(nb_filters=6,dropout_rate = 0.2,dilations=[1, 2, 4, 8, 16, 32] ,return_sequences=False)(m)

m = TCN(nb_filters=6,dropout_rate = 0.2,return_sequences=False)(i)
m = Dense(1, activation='linear')(m)
model = Model(inputs=[i], outputs=[m])
model.summary()

model.compile('adam', 'mae')
model.compile(loss=root_mean_squared_error, optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])

history = model.fit(seq_array_new, label_array5, epochs=100, batch_size=200, validation_split=0.05, verbose=2,
          callbacks = [#keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='min'),
                      keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
          )
# Out:
# /content/drive/My Drive/Fax/Master Theses/output-tcn-6-1/tcn_model_fuse.h5
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 5, 6)]            0
# _________________________________________________________________
# tcn_1 (TCN)                  (None, 6)                 1188
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 1,195
# Trainable params: 1,195
# Non-trainable params: 0
# _________________________________________________________________
# Train on 11049 samples, validate on 582 samples
# Epoch 1/100
# 11049/11049 - 5s - loss: 120.4729 - mae: 83.5270 - r2_keras: -9.3907e+00 - root_mean_squared_error: 119.5755 - val_loss: 19.6845 - val_mae: 15.1536 - val_r2_keras: 0.7005 - val_root_mean_squared_error: 19.5558
# Epoch 2/100
# 11049/11049 - 2s - loss: 42.7080 - mae: 29.7453 - r2_keras: -1.3523e-01 - root_mean_squared_error: 42.5342 - val_loss: 15.5816 - val_mae: 11.8999 - val_r2_keras: 0.8141 - val_root_mean_squared_error: 15.4660
# Epoch 3/100
# 11049/11049 - 2s - loss: 22.0511 - mae: 15.4888 - r2_keras: 0.7073 - root_mean_squared_error: 21.9678 - val_loss: 10.7521 - val_mae: 7.8105 - val_r2_keras: 0.8936 - val_root_mean_squared_error: 10.6566
# Epoch 4/100
# 11049/11049 - 2s - loss: 15.5729 - mae: 10.8487 - r2_keras: 0.8557 - root_mean_squared_error: 15.5179 - val_loss: 10.4233 - val_mae: 7.7379 - val_r2_keras: 0.9103 - val_root_mean_squared_error: 10.3348
# Epoch 5/100
# 11049/11049 - 2s - loss: 13.0384 - mae: 9.1164 - r2_keras: 0.8973 - root_mean_squared_error: 13.0788 - val_loss: 9.7983 - val_mae: 7.2295 - val_r2_keras: 0.9006 - val_root_mean_squared_error: 9.7080
# Epoch 6/100
# 11049/11049 - 2s - loss: 11.7246 - mae: 8.2400 - r2_keras: 0.9177 - root_mean_squared_error: 11.7344 - val_loss: 10.3288 - val_mae: 7.7747 - val_r2_keras: 0.9174 - val_root_mean_squared_error: 10.2592
# Epoch 7/100
# 11049/11049 - 2s - loss: 11.0926 - mae: 7.7086 - r2_keras: 0.9265 - root_mean_squared_error: 11.0683 - val_loss: 9.7399 - val_mae: 7.1576 - val_r2_keras: 0.9234 - val_root_mean_squared_error: 9.6642
# Epoch 8/100
# 11049/11049 - 2s - loss: 10.1341 - mae: 7.2054 - r2_keras: 0.9383 - root_mean_squared_error: 10.1307 - val_loss: 9.5179 - val_mae: 6.8928 - val_r2_keras: 0.9245 - val_root_mean_squared_error: 9.4416
# Epoch 9/100
# 11049/11049 - 2s - loss: 9.8383 - mae: 6.9512 - r2_keras: 0.9419 - root_mean_squared_error: 9.8603 - val_loss: 9.4380 - val_mae: 6.8718 - val_r2_keras: 0.9076 - val_root_mean_squared_error: 9.3533
# Epoch 10/100
# 11049/11049 - 2s - loss: 9.7053 - mae: 6.8070 - r2_keras: 0.9438 - root_mean_squared_error: 9.7076 - val_loss: 9.2577 - val_mae: 6.6070 - val_r2_keras: 0.9241 - val_root_mean_squared_error: 9.1816
# Epoch 11/100
# 11049/11049 - 2s - loss: 9.4743 - mae: 6.6417 - r2_keras: 0.9461 - root_mean_squared_error: 9.4771 - val_loss: 9.2179 - val_mae: 6.5624 - val_r2_keras: 0.9235 - val_root_mean_squared_error: 9.1412
# Epoch 12/100
# 11049/11049 - 2s - loss: 9.1456 - mae: 6.4588 - r2_keras: 0.9499 - root_mean_squared_error: 9.1614 - val_loss: 9.8819 - val_mae: 7.4138 - val_r2_keras: 0.8919 - val_root_mean_squared_error: 9.7940
# Epoch 13/100
# 11049/11049 - 2s - loss: 8.9737 - mae: 6.3454 - r2_keras: 0.9519 - root_mean_squared_error: 8.9504 - val_loss: 9.2265 - val_mae: 6.5654 - val_r2_keras: 0.9162 - val_root_mean_squared_error: 9.1470
# Epoch 14/100
# 11049/11049 - 2s - loss: 8.7637 - mae: 6.2670 - r2_keras: 0.9541 - root_mean_squared_error: 8.7810 - val_loss: 9.3192 - val_mae: 6.6938 - val_r2_keras: 0.9108 - val_root_mean_squared_error: 9.2376
# Epoch 15/100
# 11049/11049 - 2s - loss: 8.7592 - mae: 6.2522 - r2_keras: 0.9542 - root_mean_squared_error: 8.7506 - val_loss: 9.2020 - val_mae: 6.5711 - val_r2_keras: 0.9174 - val_root_mean_squared_error: 9.1238
# Epoch 16/100
# 11049/11049 - 2s - loss: 8.6788 - mae: 6.2107 - r2_keras: 0.9553 - root_mean_squared_error: 8.6567 - val_loss: 9.6787 - val_mae: 7.1485 - val_r2_keras: 0.8972 - val_root_mean_squared_error: 9.5932
# Epoch 17/100
# 11049/11049 - 2s - loss: 8.6916 - mae: 6.1682 - r2_keras: 0.9552 - root_mean_squared_error: 8.6587 - val_loss: 9.1520 - val_mae: 6.5051 - val_r2_keras: 0.9196 - val_root_mean_squared_error: 9.0747
# Epoch 18/100
# 11049/11049 - 2s - loss: 8.5820 - mae: 6.1252 - r2_keras: 0.9560 - root_mean_squared_error: 8.5757 - val_loss: 9.2786 - val_mae: 6.6779 - val_r2_keras: 0.9109 - val_root_mean_squared_error: 9.1991
# Epoch 19/100
# 11049/11049 - 2s - loss: 8.4874 - mae: 6.0369 - r2_keras: 0.9569 - root_mean_squared_error: 8.4779 - val_loss: 9.1755 - val_mae: 6.5008 - val_r2_keras: 0.9223 - val_root_mean_squared_error: 9.0990
# Epoch 20/100
# 11049/11049 - 2s - loss: 8.5573 - mae: 6.1018 - r2_keras: 0.9563 - root_mean_squared_error: 8.5569 - val_loss: 9.1559 - val_mae: 6.4711 - val_r2_keras: 0.9188 - val_root_mean_squared_error: 9.0773
# Epoch 21/100
# 11049/11049 - 2s - loss: 8.4590 - mae: 6.0341 - r2_keras: 0.9573 - root_mean_squared_error: 8.4664 - val_loss: 9.8030 - val_mae: 7.2847 - val_r2_keras: 0.8932 - val_root_mean_squared_error: 9.7159
# Epoch 22/100
# 11049/11049 - 2s - loss: 8.4722 - mae: 6.0394 - r2_keras: 0.9571 - root_mean_squared_error: 8.4680 - val_loss: 9.3991 - val_mae: 6.8133 - val_r2_keras: 0.9058 - val_root_mean_squared_error: 9.3164
# Epoch 23/100
# 11049/11049 - 2s - loss: 8.3310 - mae: 5.9609 - r2_keras: 0.9586 - root_mean_squared_error: 8.3379 - val_loss: 9.2176 - val_mae: 6.5556 - val_r2_keras: 0.9140 - val_root_mean_squared_error: 9.1361
# Epoch 24/100
# 11049/11049 - 2s - loss: 8.3496 - mae: 5.9332 - r2_keras: 0.9581 - root_mean_squared_error: 8.3616 - val_loss: 9.3538 - val_mae: 6.6947 - val_r2_keras: 0.9091 - val_root_mean_squared_error: 9.2704
# Epoch 25/100
# 11049/11049 - 2s - loss: 8.3560 - mae: 5.9306 - r2_keras: 0.9581 - root_mean_squared_error: 8.3529 - val_loss: 9.1807 - val_mae: 6.4651 - val_r2_keras: 0.9211 - val_root_mean_squared_error: 9.1016
# Epoch 26/100
# 11049/11049 - 2s - loss: 8.3621 - mae: 5.9201 - r2_keras: 0.9581 - root_mean_squared_error: 8.3518 - val_loss: 9.2796 - val_mae: 6.6000 - val_r2_keras: 0.9120 - val_root_mean_squared_error: 9.1970
# Epoch 27/100
# 11049/11049 - 2s - loss: 8.3079 - mae: 5.9067 - r2_keras: 0.9586 - root_mean_squared_error: 8.3060 - val_loss: 9.1720 - val_mae: 6.4604 - val_r2_keras: 0.9226 - val_root_mean_squared_error: 9.0940
# Epoch 28/100
# 11049/11049 - 2s - loss: 8.2435 - mae: 5.8637 - r2_keras: 0.9594 - root_mean_squared_error: 8.2399 - val_loss: 9.4116 - val_mae: 6.8024 - val_r2_keras: 0.9054 - val_root_mean_squared_error: 9.3265
# Epoch 29/100
# 11049/11049 - 2s - loss: 8.1871 - mae: 5.8429 - r2_keras: 0.9602 - root_mean_squared_error: 8.1775 - val_loss: 9.9226 - val_mae: 7.4158 - val_r2_keras: 0.8896 - val_root_mean_squared_error: 9.8324
# Epoch 30/100
# 11049/11049 - 2s - loss: 8.1346 - mae: 5.8305 - r2_keras: 0.9606 - root_mean_squared_error: 8.1360 - val_loss: 9.7207 - val_mae: 7.1617 - val_r2_keras: 0.8955 - val_root_mean_squared_error: 9.6315
# Epoch 31/100
# 11049/11049 - 2s - loss: 8.1306 - mae: 5.8168 - r2_keras: 0.9606 - root_mean_squared_error: 8.1334 - val_loss: 9.1310 - val_mae: 6.4139 - val_r2_keras: 0.9211 - val_root_mean_squared_error: 9.0512
# Epoch 32/100
# 11049/11049 - 2s - loss: 8.1806 - mae: 5.8163 - r2_keras: 0.9602 - root_mean_squared_error: 8.1708 - val_loss: 9.1946 - val_mae: 6.4639 - val_r2_keras: 0.9184 - val_root_mean_squared_error: 9.1140
# Epoch 33/100
# 11049/11049 - 2s - loss: 8.1916 - mae: 5.8370 - r2_keras: 0.9600 - root_mean_squared_error: 8.1936 - val_loss: 9.1678 - val_mae: 6.4804 - val_r2_keras: 0.9150 - val_root_mean_squared_error: 9.0867
# Epoch 34/100
# 11049/11049 - 2s - loss: 8.1029 - mae: 5.8017 - r2_keras: 0.9609 - root_mean_squared_error: 8.0995 - val_loss: 9.2385 - val_mae: 6.5815 - val_r2_keras: 0.9112 - val_root_mean_squared_error: 9.1553
# Epoch 35/100
# 11049/11049 - 2s - loss: 8.0978 - mae: 5.7794 - r2_keras: 0.9609 - root_mean_squared_error: 8.0877 - val_loss: 9.1558 - val_mae: 6.4369 - val_r2_keras: 0.9191 - val_root_mean_squared_error: 9.0755
# Epoch 36/100
# 11049/11049 - 2s - loss: 8.0292 - mae: 5.7532 - r2_keras: 0.9615 - root_mean_squared_error: 8.0372 - val_loss: 9.1901 - val_mae: 6.4661 - val_r2_keras: 0.9258 - val_root_mean_squared_error: 9.1141
# Epoch 37/100
# 11049/11049 - 2s - loss: 8.1551 - mae: 5.7936 - r2_keras: 0.9602 - root_mean_squared_error: 8.1509 - val_loss: 9.0943 - val_mae: 6.3772 - val_r2_keras: 0.9217 - val_root_mean_squared_error: 9.0149
# Epoch 38/100
# 11049/11049 - 2s - loss: 8.0127 - mae: 5.7397 - r2_keras: 0.9616 - root_mean_squared_error: 8.0059 - val_loss: 9.0919 - val_mae: 6.3596 - val_r2_keras: 0.9210 - val_root_mean_squared_error: 9.0119
# Epoch 39/100
# 11049/11049 - 2s - loss: 7.9979 - mae: 5.7409 - r2_keras: 0.9620 - root_mean_squared_error: 7.9688 - val_loss: 9.4245 - val_mae: 6.8235 - val_r2_keras: 0.9033 - val_root_mean_squared_error: 9.3382
# Epoch 40/100
# 11049/11049 - 2s - loss: 8.1333 - mae: 5.7996 - r2_keras: 0.9605 - root_mean_squared_error: 8.1312 - val_loss: 9.1128 - val_mae: 6.3749 - val_r2_keras: 0.9201 - val_root_mean_squared_error: 9.0321
# Epoch 41/100
# 11049/11049 - 2s - loss: 7.9997 - mae: 5.7247 - r2_keras: 0.9622 - root_mean_squared_error: 7.9665 - val_loss: 9.0445 - val_mae: 6.3458 - val_r2_keras: 0.9197 - val_root_mean_squared_error: 8.9642
# Epoch 42/100
# 11049/11049 - 2s - loss: 8.0339 - mae: 5.7102 - r2_keras: 0.9615 - root_mean_squared_error: 8.0231 - val_loss: 9.2650 - val_mae: 6.6296 - val_r2_keras: 0.9090 - val_root_mean_squared_error: 9.1811
# Epoch 43/100
# 11049/11049 - 2s - loss: 8.0373 - mae: 5.7312 - r2_keras: 0.9612 - root_mean_squared_error: 8.0464 - val_loss: 9.0758 - val_mae: 6.3568 - val_r2_keras: 0.9195 - val_root_mean_squared_error: 8.9946
# Epoch 44/100
# 11049/11049 - 2s - loss: 7.9686 - mae: 5.6953 - r2_keras: 0.9620 - root_mean_squared_error: 7.9824 - val_loss: 9.3384 - val_mae: 6.7194 - val_r2_keras: 0.9058 - val_root_mean_squared_error: 9.2531
# Epoch 45/100
# 11049/11049 - 2s - loss: 7.9764 - mae: 5.6911 - r2_keras: 0.9620 - root_mean_squared_error: 7.9824 - val_loss: 9.2292 - val_mae: 6.5381 - val_r2_keras: 0.9114 - val_root_mean_squared_error: 9.1448
# Epoch 46/100
# 11049/11049 - 2s - loss: 8.0031 - mae: 5.7042 - r2_keras: 0.9617 - root_mean_squared_error: 8.0109 - val_loss: 10.3335 - val_mae: 7.7926 - val_r2_keras: 0.8782 - val_root_mean_squared_error: 10.2373
# Epoch 47/100
# 11049/11049 - 2s - loss: 7.9147 - mae: 5.6717 - r2_keras: 0.9627 - root_mean_squared_error: 7.9020 - val_loss: 9.0906 - val_mae: 6.3409 - val_r2_keras: 0.9202 - val_root_mean_squared_error: 9.0099
# Epoch 48/100
# 11049/11049 - 2s - loss: 8.0202 - mae: 5.6905 - r2_keras: 0.9612 - root_mean_squared_error: 8.0375 - val_loss: 9.0698 - val_mae: 6.3130 - val_r2_keras: 0.9242 - val_root_mean_squared_error: 8.9911
# Epoch 49/100
# 11049/11049 - 2s - loss: 8.0440 - mae: 5.7076 - r2_keras: 0.9617 - root_mean_squared_error: 8.0108 - val_loss: 9.1462 - val_mae: 6.4237 - val_r2_keras: 0.9142 - val_root_mean_squared_error: 9.0632
# Epoch 50/100
# 11049/11049 - 2s - loss: 8.0746 - mae: 5.7280 - r2_keras: 0.9614 - root_mean_squared_error: 8.0526 - val_loss: 9.0470 - val_mae: 6.2881 - val_r2_keras: 0.9246 - val_root_mean_squared_error: 8.9683
# Epoch 51/100
# 11049/11049 - 2s - loss: 7.9363 - mae: 5.6458 - r2_keras: 0.9626 - root_mean_squared_error: 7.9299 - val_loss: 9.2978 - val_mae: 6.6558 - val_r2_keras: 0.9066 - val_root_mean_squared_error: 9.2123
# Epoch 52/100
# 11049/11049 - 2s - loss: 7.9074 - mae: 5.6771 - r2_keras: 0.9628 - root_mean_squared_error: 7.8903 - val_loss: 9.1428 - val_mae: 6.4319 - val_r2_keras: 0.9150 - val_root_mean_squared_error: 9.0600
# Epoch 53/100
# 11049/11049 - 2s - loss: 7.9395 - mae: 5.6816 - r2_keras: 0.9625 - root_mean_squared_error: 7.9355 - val_loss: 9.6552 - val_mae: 7.0861 - val_r2_keras: 0.8958 - val_root_mean_squared_error: 9.5659
# Epoch 54/100
# 11049/11049 - 2s - loss: 7.8835 - mae: 5.6316 - r2_keras: 0.9628 - root_mean_squared_error: 7.8865 - val_loss: 9.2151 - val_mae: 6.5241 - val_r2_keras: 0.9107 - val_root_mean_squared_error: 9.1307
# Epoch 55/100
# 11049/11049 - 2s - loss: 7.9772 - mae: 5.6695 - r2_keras: 0.9620 - root_mean_squared_error: 7.9791 - val_loss: 9.1181 - val_mae: 6.4079 - val_r2_keras: 0.9141 - val_root_mean_squared_error: 9.0350
# Epoch 56/100
# 11049/11049 - 2s - loss: 7.9116 - mae: 5.6630 - r2_keras: 0.9629 - root_mean_squared_error: 7.8940 - val_loss: 9.1068 - val_mae: 6.3613 - val_r2_keras: 0.9154 - val_root_mean_squared_error: 9.0232
# Epoch 57/100
# 11049/11049 - 2s - loss: 7.9165 - mae: 5.6637 - r2_keras: 0.9628 - root_mean_squared_error: 7.9039 - val_loss: 9.1198 - val_mae: 6.3935 - val_r2_keras: 0.9127 - val_root_mean_squared_error: 9.0347
# Epoch 58/100
# 11049/11049 - 2s - loss: 7.8849 - mae: 5.6344 - r2_keras: 0.9630 - root_mean_squared_error: 7.8645 - val_loss: 9.0020 - val_mae: 6.1990 - val_r2_keras: 0.9194 - val_root_mean_squared_error: 8.9200
# Epoch 59/100
# 11049/11049 - 2s - loss: 7.8833 - mae: 5.6280 - r2_keras: 0.9632 - root_mean_squared_error: 7.8597 - val_loss: 8.9875 - val_mae: 6.1937 - val_r2_keras: 0.9249 - val_root_mean_squared_error: 8.9084
# Epoch 60/100
# 11049/11049 - 2s - loss: 7.8413 - mae: 5.6142 - r2_keras: 0.9633 - root_mean_squared_error: 7.8340 - val_loss: 8.8743 - val_mae: 6.0842 - val_r2_keras: 0.9257 - val_root_mean_squared_error: 8.7951
# Epoch 61/100
# 11049/11049 - 2s - loss: 7.8067 - mae: 5.5710 - r2_keras: 0.9626 - root_mean_squared_error: 7.8395 - val_loss: 9.0379 - val_mae: 6.2514 - val_r2_keras: 0.9274 - val_root_mean_squared_error: 8.9619
# Epoch 62/100
# 11049/11049 - 2s - loss: 7.9087 - mae: 5.6181 - r2_keras: 0.9630 - root_mean_squared_error: 7.8791 - val_loss: 8.9487 - val_mae: 6.1856 - val_r2_keras: 0.9254 - val_root_mean_squared_error: 8.8695
# Epoch 63/100
# 11049/11049 - 2s - loss: 7.8583 - mae: 5.6061 - r2_keras: 0.9632 - root_mean_squared_error: 7.8721 - val_loss: 9.2972 - val_mae: 6.6133 - val_r2_keras: 0.9048 - val_root_mean_squared_error: 9.2093
# Epoch 64/100
# 11049/11049 - 2s - loss: 7.9078 - mae: 5.6127 - r2_keras: 0.9626 - root_mean_squared_error: 7.9109 - val_loss: 9.0220 - val_mae: 6.2703 - val_r2_keras: 0.9150 - val_root_mean_squared_error: 8.9364
# Epoch 65/100
# 11049/11049 - 2s - loss: 7.8806 - mae: 5.6557 - r2_keras: 0.9630 - root_mean_squared_error: 7.8632 - val_loss: 8.9958 - val_mae: 6.1984 - val_r2_keras: 0.9269 - val_root_mean_squared_error: 8.9179
# Epoch 66/100
# 11049/11049 - 2s - loss: 7.8015 - mae: 5.5814 - r2_keras: 0.9637 - root_mean_squared_error: 7.7869 - val_loss: 9.0602 - val_mae: 6.3015 - val_r2_keras: 0.9139 - val_root_mean_squared_error: 8.9752
# Epoch 67/100
# 11049/11049 - 2s - loss: 7.8107 - mae: 5.5730 - r2_keras: 0.9635 - root_mean_squared_error: 7.8263 - val_loss: 8.9660 - val_mae: 6.1896 - val_r2_keras: 0.9187 - val_root_mean_squared_error: 8.8826
# Epoch 68/100
# 11049/11049 - 2s - loss: 7.8777 - mae: 5.6116 - r2_keras: 0.9632 - root_mean_squared_error: 7.8606 - val_loss: 8.9509 - val_mae: 6.1360 - val_r2_keras: 0.9243 - val_root_mean_squared_error: 8.8710
# Epoch 69/100
# 11049/11049 - 2s - loss: 7.8149 - mae: 5.5696 - r2_keras: 0.9636 - root_mean_squared_error: 7.8143 - val_loss: 9.0210 - val_mae: 6.2270 - val_r2_keras: 0.9285 - val_root_mean_squared_error: 8.9440
# Epoch 70/100
# 11049/11049 - 2s - loss: 7.7557 - mae: 5.5619 - r2_keras: 0.9642 - root_mean_squared_error: 7.7515 - val_loss: 9.3328 - val_mae: 6.6179 - val_r2_keras: 0.9045 - val_root_mean_squared_error: 9.2450
# Epoch 71/100
# 11049/11049 - 2s - loss: 7.7929 - mae: 5.5579 - r2_keras: 0.9636 - root_mean_squared_error: 7.7966 - val_loss: 8.9147 - val_mae: 6.1176 - val_r2_keras: 0.9229 - val_root_mean_squared_error: 8.8335
# Epoch 72/100
# 11049/11049 - 2s - loss: 7.7528 - mae: 5.5493 - r2_keras: 0.9639 - root_mean_squared_error: 7.7804 - val_loss: 9.0292 - val_mae: 6.3083 - val_r2_keras: 0.9138 - val_root_mean_squared_error: 8.9442
# Epoch 73/100
# 11049/11049 - 2s - loss: 7.7896 - mae: 5.5619 - r2_keras: 0.9638 - root_mean_squared_error: 7.7645 - val_loss: 8.9195 - val_mae: 6.1142 - val_r2_keras: 0.9220 - val_root_mean_squared_error: 8.8378
# Epoch 74/100
# 11049/11049 - 2s - loss: 7.7946 - mae: 5.5585 - r2_keras: 0.9633 - root_mean_squared_error: 7.8302 - val_loss: 9.0137 - val_mae: 6.2159 - val_r2_keras: 0.9199 - val_root_mean_squared_error: 8.9324
# Epoch 75/100
# 11049/11049 - 2s - loss: 7.7895 - mae: 5.5569 - r2_keras: 0.9640 - root_mean_squared_error: 7.7889 - val_loss: 8.9820 - val_mae: 6.1691 - val_r2_keras: 0.9211 - val_root_mean_squared_error: 8.9011
# Epoch 76/100
# 11049/11049 - 2s - loss: 7.7721 - mae: 5.5631 - r2_keras: 0.9641 - root_mean_squared_error: 7.7630 - val_loss: 8.9273 - val_mae: 6.1818 - val_r2_keras: 0.9181 - val_root_mean_squared_error: 8.8430
# Epoch 77/100
# 11049/11049 - 2s - loss: 7.8465 - mae: 5.5903 - r2_keras: 0.9622 - root_mean_squared_error: 7.9245 - val_loss: 8.9449 - val_mae: 6.1201 - val_r2_keras: 0.9246 - val_root_mean_squared_error: 8.8646
# Epoch 78/100
# 11049/11049 - 2s - loss: 7.7901 - mae: 5.5738 - r2_keras: 0.9638 - root_mean_squared_error: 7.7873 - val_loss: 8.9811 - val_mae: 6.1449 - val_r2_keras: 0.9219 - val_root_mean_squared_error: 8.9003
# Epoch 79/100
# 11049/11049 - 2s - loss: 7.8098 - mae: 5.5476 - r2_keras: 0.9638 - root_mean_squared_error: 7.8003 - val_loss: 8.9168 - val_mae: 6.1136 - val_r2_keras: 0.9195 - val_root_mean_squared_error: 8.8338
# Epoch 80/100
# 11049/11049 - 2s - loss: 7.8582 - mae: 5.5765 - r2_keras: 0.9630 - root_mean_squared_error: 7.8785 - val_loss: 8.9871 - val_mae: 6.1829 - val_r2_keras: 0.9192 - val_root_mean_squared_error: 8.9045
# Epoch 81/100
# 11049/11049 - 2s - loss: 7.7949 - mae: 5.5572 - r2_keras: 0.9640 - root_mean_squared_error: 7.7759 - val_loss: 8.9621 - val_mae: 6.1421 - val_r2_keras: 0.9262 - val_root_mean_squared_error: 8.8837
# Epoch 82/100
# 11049/11049 - 2s - loss: 7.7147 - mae: 5.5119 - r2_keras: 0.9645 - root_mean_squared_error: 7.7067 - val_loss: 9.0800 - val_mae: 6.3147 - val_r2_keras: 0.9117 - val_root_mean_squared_error: 8.9938
# Epoch 83/100
# 11049/11049 - 2s - loss: 7.7885 - mae: 5.5564 - r2_keras: 0.9640 - root_mean_squared_error: 7.7868 - val_loss: 9.3418 - val_mae: 6.6450 - val_r2_keras: 0.9027 - val_root_mean_squared_error: 9.2521
# Epoch 84/100
# 11049/11049 - 2s - loss: 7.6870 - mae: 5.5145 - r2_keras: 0.9645 - root_mean_squared_error: 7.7163 - val_loss: 9.0454 - val_mae: 6.2157 - val_r2_keras: 0.9163 - val_root_mean_squared_error: 8.9618
# Epoch 85/100
# 11049/11049 - 2s - loss: 7.7328 - mae: 5.5260 - r2_keras: 0.9643 - root_mean_squared_error: 7.7396 - val_loss: 8.9476 - val_mae: 6.1323 - val_r2_keras: 0.9257 - val_root_mean_squared_error: 8.8687
# Epoch 86/100
# 11049/11049 - 2s - loss: 7.7304 - mae: 5.5238 - r2_keras: 0.9643 - root_mean_squared_error: 7.7374 - val_loss: 9.0995 - val_mae: 6.3092 - val_r2_keras: 0.9098 - val_root_mean_squared_error: 9.0123
# Epoch 87/100
# 11049/11049 - 2s - loss: 7.8021 - mae: 5.5315 - r2_keras: 0.9638 - root_mean_squared_error: 7.7856 - val_loss: 9.2847 - val_mae: 6.5644 - val_r2_keras: 0.9042 - val_root_mean_squared_error: 9.1966
# Epoch 88/100
# 11049/11049 - 2s - loss: 7.7282 - mae: 5.5242 - r2_keras: 0.9641 - root_mean_squared_error: 7.7444 - val_loss: 9.0541 - val_mae: 6.2744 - val_r2_keras: 0.9290 - val_root_mean_squared_error: 8.9790
# Epoch 89/100
# 11049/11049 - 2s - loss: 7.7331 - mae: 5.5166 - r2_keras: 0.9643 - root_mean_squared_error: 7.7418 - val_loss: 9.2388 - val_mae: 6.5770 - val_r2_keras: 0.9045 - val_root_mean_squared_error: 9.1507
# Epoch 90/100
# 11049/11049 - 2s - loss: 7.6661 - mae: 5.4863 - r2_keras: 0.9650 - root_mean_squared_error: 7.6493 - val_loss: 9.0029 - val_mae: 6.2384 - val_r2_keras: 0.9299 - val_root_mean_squared_error: 8.9299
# Epoch 91/100
# 11049/11049 - 2s - loss: 7.7287 - mae: 5.5207 - r2_keras: 0.9642 - root_mean_squared_error: 7.7609 - val_loss: 9.8407 - val_mae: 7.2306 - val_r2_keras: 0.8883 - val_root_mean_squared_error: 9.7466
# Epoch 92/100
# 11049/11049 - 2s - loss: 7.6635 - mae: 5.4863 - r2_keras: 0.9649 - root_mean_squared_error: 7.6538 - val_loss: 8.9727 - val_mae: 6.1537 - val_r2_keras: 0.9273 - val_root_mean_squared_error: 8.8962
# Epoch 93/100
# 11049/11049 - 2s - loss: 7.7134 - mae: 5.5316 - r2_keras: 0.9642 - root_mean_squared_error: 7.7307 - val_loss: 9.1102 - val_mae: 6.4009 - val_r2_keras: 0.9089 - val_root_mean_squared_error: 9.0239
# Epoch 94/100
# 11049/11049 - 2s - loss: 7.6779 - mae: 5.4804 - r2_keras: 0.9647 - root_mean_squared_error: 7.6877 - val_loss: 9.0423 - val_mae: 6.2633 - val_r2_keras: 0.9128 - val_root_mean_squared_error: 8.9571
# Epoch 95/100
# 11049/11049 - 2s - loss: 7.6973 - mae: 5.4870 - r2_keras: 0.9643 - root_mean_squared_error: 7.7016 - val_loss: 8.8759 - val_mae: 6.0986 - val_r2_keras: 0.9188 - val_root_mean_squared_error: 8.7889
# Epoch 96/100
# 11049/11049 - 2s - loss: 7.6917 - mae: 5.4840 - r2_keras: 0.9645 - root_mean_squared_error: 7.7128 - val_loss: 8.8687 - val_mae: 6.0697 - val_r2_keras: 0.9205 - val_root_mean_squared_error: 8.7833
# Epoch 97/100
# 11049/11049 - 2s - loss: 7.6734 - mae: 5.4905 - r2_keras: 0.9649 - root_mean_squared_error: 7.6770 - val_loss: 9.0248 - val_mae: 6.2427 - val_r2_keras: 0.9115 - val_root_mean_squared_error: 8.9387
# Epoch 98/100
# 11049/11049 - 2s - loss: 7.6810 - mae: 5.5057 - r2_keras: 0.9647 - root_mean_squared_error: 7.6807 - val_loss: 8.8161 - val_mae: 6.0139 - val_r2_keras: 0.9245 - val_root_mean_squared_error: 8.7351
# Epoch 99/100
# 11049/11049 - 2s - loss: 7.6015 - mae: 5.4451 - r2_keras: 0.9655 - root_mean_squared_error: 7.5995 - val_loss: 8.8342 - val_mae: 6.0655 - val_r2_keras: 0.9182 - val_root_mean_squared_error: 8.7502
# Epoch 100/100
# 11049/11049 - 2s - loss: 7.7059 - mae: 5.4980 - r2_keras: 0.9647 - root_mean_squared_error: 7.7031 - val_loss: 8.8080 - val_mae: 6.0169 - val_r2_keras: 0.9244 - val_root_mean_squared_error: 8.7260

# %%
plot_stats(history,model,'_fuse_TCN', seq_array_new,label_array5)
# Out:
# dict_keys(['loss', 'mae', 'r2_keras', 'root_mean_squared_error', 'val_loss', 'val_mae', 'val_r2_keras', 'val_root_mean_squared_error'])
# 11631/11631 [==============================] - 1s 44us/sample - loss: 7.5812 - mae: 5.5560 - r2_keras: 0.9523 - root_mean_squared_error: 7.5028
#
# MAE: 5.556022644042969
#
# R^2: 0.952330470085144
#
# RMSE: 7.502808570861816
# 11631/11631 [==============================] - 1s 70us/sample

# %%
def get_test_data_tcn(model_path,sequence_length,sequence_length_max ):
  # We pick the last sequence for each id in the test data
  seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                        for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length_max]

  seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
  #print("seq_array_test_last")
  #print(seq_array_test_last.shape)

  return get_encoded_data(model_path,seq_array_test_last)

# %%
test_data1 = get_test_data_tcn(tcn_models_path+'/tcn_model1.h5',seq_array1new.shape[1],seq_array5.shape[1])
test_data2 = get_test_data_tcn(tcn_models_path+'/tcn_model2.h5',seq_array2new.shape[1],seq_array5.shape[1])
test_data3 = get_test_data_tcn(tcn_models_path+'/tcn_model3.h5',seq_array3new.shape[1],seq_array5.shape[1])
test_data4 = get_test_data_tcn(tcn_models_path+'/tcn_model4.h5',seq_array4new.shape[1],seq_array5.shape[1])
test_data5 = get_test_data_tcn(tcn_models_path+'/tcn_model5.h5',seq_array5.shape[1],seq_array5.shape[1])
# Out:
# 74/74 [==============================] - 1s 7ms/sample
# 74/74 [==============================] - 1s 7ms/sample
# 74/74 [==============================] - 1s 8ms/sample
# 74/74 [==============================] - 1s 8ms/sample
# 74/74 [==============================] - 1s 8ms/sample

# %%
seq_array_test_new = np.array([test_data1,test_data2,test_data3,test_data4,test_data5])
seq_array_test_new = np.swapaxes(seq_array_test_new,0,1)
seq_array_test_new.shape
# Out:
# (74, 5, 6)

# %%
##################################
# EVALUATE ON TEST DATA
##################################
#def evaluate_on_test_data(model_path,id,sequence_length ):

tcn_fuse_model_path = output_path+'/tcn_model_fuse.h5'
# We pick the last sequence for each id in the test data

sequence_length = seq_array5.shape[1]
# Similarly, we pick the labels

y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
print(label_array_test_last.shape)
#print("label_array_test_last")
#print(label_array_test_last)

# if best iteration's model was saved then load and use it
if os.path.isfile(tcn_fuse_model_path):

    # restore weights
    estimator = load_model(tcn_fuse_model_path,custom_objects={'r2_keras': r2_keras, 'root_mean_squared_error': root_mean_squared_error,'TCN': TCN})

    
    # test metrics
    scores_test = estimator.evaluate(seq_array_test_new, label_array_test_last, verbose=2)
    print('\nMAE: {}'.format(scores_test[1]))
    print('\nR^2: {}'.format(scores_test[2]))
    print('\nRMSE: {}'.format(scores_test[3]))

    y_pred_test = estimator.predict(seq_array_test_new)
    y_true_test = label_array_test_last

    test_set = pd.DataFrame(y_pred_test)
    test_set.to_csv(output_path+'/submit_test_fuse_dense.csv', index = None)



    result = pd.DataFrame( columns = ['pred', 'true']) 
    result['pred'] = y_pred_test.flatten().round()
    result['true'] = y_true_test.flatten()
    result.sort_values(by='true', inplace=True)
    # Plot in blue color the predicted data and in orange color the
    # actual data to verify visually the accuracy of the model.
        
    x = np.arange(len(y_pred_test))
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots(figsize=(100, 50))
    rects1 = ax.bar(x - width/2,result['pred'], width, label='predicted')
    rects2 = ax.bar(x + width/2,result['true'], width, label='true')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('value')
    ax.set_title('prediction')
    ax.set_xticks(x)
    ax.legend()


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)

    plt.show()
    fig.savefig(output_path+"/model_fuse_dense_verify_bar.png")
# Out:
# (74, 1)
# 74/74 - 0s - loss: 10.5134 - mae: 7.4700 - r2_keras: 0.9289 - root_mean_squared_error: 10.5115
#
# MAE: 7.469980716705322
#
# R^2: 0.928856372833252
#
# RMSE: 10.511451721191406
