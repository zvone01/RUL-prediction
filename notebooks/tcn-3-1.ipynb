# %% [markdown]
# Using autoencoder and TCN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
from importlib.machinery import SourceFileLoader
somemodule = SourceFileLoader('tcn', '/content/drive/My Drive/Fax/Master Theses/keras-tcn-master/tcn/tcn.py').load_module()
# Out:
# TensorFlow 2.x selected.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Dropout, Embedding
from sklearn import preprocessing

import os
import tensorflow.keras as keras
import tensorflow.keras.backend as K
from tensorflow.python.keras.layers.core import Activation
from tensorflow.keras.models import Sequential,load_model, model_from_json

from tcn import TCN

# %%
# define paths
output_path = '/content/drive/My Drive/Fax/Master Theses/output-tcn-3-1'
model_path = output_path+'/mode.h5'
model_path_autoecoder = output_path+'/encoder_mode.h5'
data_path = '/content/drive/My Drive/Fax/Master Theses/Data/CMAPSSData/'

# %%
##################################
# Data Ingestion
##################################

# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv(data_path+'train_FD001.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv(data_path+'test_FD001.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# read ground truth data - It contains the information of true remaining cycles for each engine in the testing data.
truth_df = pd.read_csv(data_path+'RUL_FD001.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %%
#######
# TRAIN set
#######
# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

# generate label columns for training data
# we will only make use of "label1" for binary classification, 
# while trying to answer the question: is a specific engine going to fail within w1 cycles?
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# %%
######
# TEST set
######
# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
print(test_df.head())

# We use the ground truth dataset to generate labels for the test data.
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)

# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2

#test_df.to_csv('../../Dataset/PredictiveManteinanceEngineValidation.csv', encoding='utf-8',index = None)
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  0.632184  0.750000  ...  0.0  0.558140  0.661834     0.00000
# 1   1      2  0.344828  0.250000  ...  0.0  0.682171  0.686827     0.00277
# 2   1      3  0.517241  0.583333  ...  0.0  0.728682  0.721348     0.00554
# 3   1      4  0.741379  0.500000  ...  0.0  0.666667  0.662110     0.00831
# 4   1      5  0.580460  0.500000  ...  0.0  0.658915  0.716377     0.01108
#
# [5 rows x 27 columns]

# %%
# pick the feature columns 
sensor_cols = ['s' + str(i) for i in range(1,22)]
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)

train_x = train_df[sequence_cols].values.astype(np.float32)
print(train_x.shape)
# Out:
# (20631, 25)

# %%
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
##################################
# Autoencoder
##################################

def autoencoder(data):

  n_samples = data.shape[0]
  nb_features = data.shape[1]

  input_d = Input(shape=(nb_features,))
  encoded = Dense(32, activation='relu')(input_d)
  encoded = Dense(16, activation='relu')(encoded)
  encoded = Dense(8, activation='relu')(encoded)

  decoded = Dense(16, activation='relu')(encoded)
  decoded = Dense(32, activation='relu')(decoded)
  decoded = Dense(nb_features, activation='sigmoid')(decoded)

  autoencoder = Model(input_d, decoded)
  autoencoder.compile('adam', 'mae')

  autoencoder.compile(loss= root_mean_squared_error, optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])
  autoencoder.summary()
  history = autoencoder.fit(data, data,
                  epochs=200,
                  verbose=2,
                  batch_size=256,
                  shuffle=True,
                  validation_data=(data, data),
                  callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                        keras.callbacks.ModelCheckpoint(model_path_autoecoder,monitor='val_loss', save_best_only=True, mode='min', verbose=0)])

  return autoencoder

# %%
encoder_model = autoencoder(train_x)
encoded_data = encoder_model.predict(train_x,verbose=1, batch_size=200)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                144
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_5 (Dense)              (None, 25)                825
# =================================================================
# Total params: 3,009
# Trainable params: 3,009
# Non-trainable params: 0
# _________________________________________________________________
# Train on 20631 samples, validate on 20631 samples
# Epoch 1/200
# 20631/20631 - 1s - loss: 0.1876 - mae: 0.1516 - r2_keras: 0.4765 - root_mean_squared_error: 0.1872 - val_loss: 0.1146 - val_mae: 0.0780 - val_r2_keras: 0.8293 - val_root_mean_squared_error: 0.1146
# Epoch 2/200
# 20631/20631 - 0s - loss: 0.1011 - mae: 0.0646 - r2_keras: 0.8672 - root_mean_squared_error: 0.1011 - val_loss: 0.0912 - val_mae: 0.0557 - val_r2_keras: 0.8922 - val_root_mean_squared_error: 0.0911
# Epoch 3/200
# 20631/20631 - 0s - loss: 0.0890 - mae: 0.0539 - r2_keras: 0.8976 - root_mean_squared_error: 0.0889 - val_loss: 0.0865 - val_mae: 0.0522 - val_r2_keras: 0.9029 - val_root_mean_squared_error: 0.0864
# Epoch 4/200
# 20631/20631 - 0s - loss: 0.0849 - mae: 0.0513 - r2_keras: 0.9067 - root_mean_squared_error: 0.0849 - val_loss: 0.0824 - val_mae: 0.0504 - val_r2_keras: 0.9119 - val_root_mean_squared_error: 0.0823
# Epoch 5/200
# 20631/20631 - 0s - loss: 0.0802 - mae: 0.0494 - r2_keras: 0.9167 - root_mean_squared_error: 0.0802 - val_loss: 0.0787 - val_mae: 0.0491 - val_r2_keras: 0.9195 - val_root_mean_squared_error: 0.0786
# Epoch 6/200
# 20631/20631 - 0s - loss: 0.0766 - mae: 0.0474 - r2_keras: 0.9240 - root_mean_squared_error: 0.0766 - val_loss: 0.0766 - val_mae: 0.0478 - val_r2_keras: 0.9237 - val_root_mean_squared_error: 0.0766
# Epoch 7/200
# 20631/20631 - 0s - loss: 0.0750 - mae: 0.0463 - r2_keras: 0.9272 - root_mean_squared_error: 0.0750 - val_loss: 0.0740 - val_mae: 0.0456 - val_r2_keras: 0.9288 - val_root_mean_squared_error: 0.0739
# Epoch 8/200
# 20631/20631 - 0s - loss: 0.0741 - mae: 0.0456 - r2_keras: 0.9289 - root_mean_squared_error: 0.0741 - val_loss: 0.0736 - val_mae: 0.0455 - val_r2_keras: 0.9296 - val_root_mean_squared_error: 0.0735
# Epoch 9/200
# 20631/20631 - 0s - loss: 0.0734 - mae: 0.0452 - r2_keras: 0.9301 - root_mean_squared_error: 0.0735 - val_loss: 0.0740 - val_mae: 0.0461 - val_r2_keras: 0.9288 - val_root_mean_squared_error: 0.0740
# Epoch 10/200
# 20631/20631 - 0s - loss: 0.0728 - mae: 0.0448 - r2_keras: 0.9314 - root_mean_squared_error: 0.0728 - val_loss: 0.0731 - val_mae: 0.0456 - val_r2_keras: 0.9305 - val_root_mean_squared_error: 0.0730
# Epoch 11/200
# 20631/20631 - 0s - loss: 0.0722 - mae: 0.0446 - r2_keras: 0.9326 - root_mean_squared_error: 0.0722 - val_loss: 0.0720 - val_mae: 0.0449 - val_r2_keras: 0.9326 - val_root_mean_squared_error: 0.0720
# Epoch 12/200
# 20631/20631 - 0s - loss: 0.0713 - mae: 0.0442 - r2_keras: 0.9341 - root_mean_squared_error: 0.0713 - val_loss: 0.0713 - val_mae: 0.0446 - val_r2_keras: 0.9338 - val_root_mean_squared_error: 0.0713
# Epoch 13/200
# 20631/20631 - 0s - loss: 0.0702 - mae: 0.0438 - r2_keras: 0.9362 - root_mean_squared_error: 0.0702 - val_loss: 0.0694 - val_mae: 0.0440 - val_r2_keras: 0.9374 - val_root_mean_squared_error: 0.0694
# Epoch 14/200
# 20631/20631 - 0s - loss: 0.0688 - mae: 0.0433 - r2_keras: 0.9387 - root_mean_squared_error: 0.0688 - val_loss: 0.0670 - val_mae: 0.0424 - val_r2_keras: 0.9416 - val_root_mean_squared_error: 0.0670
# Epoch 15/200
# 20631/20631 - 0s - loss: 0.0669 - mae: 0.0423 - r2_keras: 0.9421 - root_mean_squared_error: 0.0669 - val_loss: 0.0658 - val_mae: 0.0419 - val_r2_keras: 0.9439 - val_root_mean_squared_error: 0.0657
# Epoch 16/200
# 20631/20631 - 0s - loss: 0.0650 - mae: 0.0410 - r2_keras: 0.9454 - root_mean_squared_error: 0.0650 - val_loss: 0.0642 - val_mae: 0.0408 - val_r2_keras: 0.9466 - val_root_mean_squared_error: 0.0641
# Epoch 17/200
# 20631/20631 - 0s - loss: 0.0634 - mae: 0.0400 - r2_keras: 0.9479 - root_mean_squared_error: 0.0634 - val_loss: 0.0619 - val_mae: 0.0391 - val_r2_keras: 0.9503 - val_root_mean_squared_error: 0.0619
# Epoch 18/200
# 20631/20631 - 0s - loss: 0.0623 - mae: 0.0392 - r2_keras: 0.9498 - root_mean_squared_error: 0.0623 - val_loss: 0.0620 - val_mae: 0.0393 - val_r2_keras: 0.9502 - val_root_mean_squared_error: 0.0619
# Epoch 19/200
# 20631/20631 - 0s - loss: 0.0616 - mae: 0.0387 - r2_keras: 0.9510 - root_mean_squared_error: 0.0615 - val_loss: 0.0613 - val_mae: 0.0388 - val_r2_keras: 0.9512 - val_root_mean_squared_error: 0.0613
# Epoch 20/200
# 20631/20631 - 0s - loss: 0.0610 - mae: 0.0384 - r2_keras: 0.9518 - root_mean_squared_error: 0.0610 - val_loss: 0.0607 - val_mae: 0.0384 - val_r2_keras: 0.9523 - val_root_mean_squared_error: 0.0606
# Epoch 21/200
# 20631/20631 - 0s - loss: 0.0605 - mae: 0.0380 - r2_keras: 0.9526 - root_mean_squared_error: 0.0605 - val_loss: 0.0599 - val_mae: 0.0377 - val_r2_keras: 0.9535 - val_root_mean_squared_error: 0.0599
# Epoch 22/200
# 20631/20631 - 0s - loss: 0.0600 - mae: 0.0378 - r2_keras: 0.9534 - root_mean_squared_error: 0.0600 - val_loss: 0.0603 - val_mae: 0.0382 - val_r2_keras: 0.9528 - val_root_mean_squared_error: 0.0603
# Epoch 23/200
# 20631/20631 - 0s - loss: 0.0596 - mae: 0.0375 - r2_keras: 0.9541 - root_mean_squared_error: 0.0595 - val_loss: 0.0596 - val_mae: 0.0375 - val_r2_keras: 0.9540 - val_root_mean_squared_error: 0.0595
# Epoch 24/200
# 20631/20631 - 0s - loss: 0.0592 - mae: 0.0372 - r2_keras: 0.9547 - root_mean_squared_error: 0.0592 - val_loss: 0.0585 - val_mae: 0.0366 - val_r2_keras: 0.9556 - val_root_mean_squared_error: 0.0585
# Epoch 25/200
# 20631/20631 - 0s - loss: 0.0588 - mae: 0.0370 - r2_keras: 0.9553 - root_mean_squared_error: 0.0588 - val_loss: 0.0587 - val_mae: 0.0369 - val_r2_keras: 0.9554 - val_root_mean_squared_error: 0.0587
# Epoch 26/200
# 20631/20631 - 0s - loss: 0.0584 - mae: 0.0367 - r2_keras: 0.9559 - root_mean_squared_error: 0.0584 - val_loss: 0.0580 - val_mae: 0.0365 - val_r2_keras: 0.9564 - val_root_mean_squared_error: 0.0580
# Epoch 27/200
# 20631/20631 - 0s - loss: 0.0579 - mae: 0.0364 - r2_keras: 0.9566 - root_mean_squared_error: 0.0579 - val_loss: 0.0580 - val_mae: 0.0366 - val_r2_keras: 0.9564 - val_root_mean_squared_error: 0.0580
# Epoch 28/200
# 20631/20631 - 0s - loss: 0.0574 - mae: 0.0361 - r2_keras: 0.9573 - root_mean_squared_error: 0.0574 - val_loss: 0.0578 - val_mae: 0.0361 - val_r2_keras: 0.9567 - val_root_mean_squared_error: 0.0578
# Epoch 29/200
# 20631/20631 - 0s - loss: 0.0570 - mae: 0.0357 - r2_keras: 0.9580 - root_mean_squared_error: 0.0570 - val_loss: 0.0572 - val_mae: 0.0358 - val_r2_keras: 0.9576 - val_root_mean_squared_error: 0.0572
# Epoch 30/200
# 20631/20631 - 0s - loss: 0.0565 - mae: 0.0354 - r2_keras: 0.9587 - root_mean_squared_error: 0.0565 - val_loss: 0.0572 - val_mae: 0.0361 - val_r2_keras: 0.9575 - val_root_mean_squared_error: 0.0572
# Epoch 31/200
# 20631/20631 - 0s - loss: 0.0561 - mae: 0.0351 - r2_keras: 0.9592 - root_mean_squared_error: 0.0561 - val_loss: 0.0558 - val_mae: 0.0349 - val_r2_keras: 0.9596 - val_root_mean_squared_error: 0.0558
# Epoch 32/200
# 20631/20631 - 0s - loss: 0.0559 - mae: 0.0350 - r2_keras: 0.9596 - root_mean_squared_error: 0.0559 - val_loss: 0.0552 - val_mae: 0.0346 - val_r2_keras: 0.9605 - val_root_mean_squared_error: 0.0552
# Epoch 33/200
# 20631/20631 - 0s - loss: 0.0556 - mae: 0.0348 - r2_keras: 0.9600 - root_mean_squared_error: 0.0556 - val_loss: 0.0550 - val_mae: 0.0347 - val_r2_keras: 0.9607 - val_root_mean_squared_error: 0.0550
# Epoch 34/200
# 20631/20631 - 0s - loss: 0.0553 - mae: 0.0347 - r2_keras: 0.9604 - root_mean_squared_error: 0.0553 - val_loss: 0.0545 - val_mae: 0.0344 - val_r2_keras: 0.9615 - val_root_mean_squared_error: 0.0545
# Epoch 35/200
# 20631/20631 - 0s - loss: 0.0551 - mae: 0.0346 - r2_keras: 0.9606 - root_mean_squared_error: 0.0551 - val_loss: 0.0543 - val_mae: 0.0342 - val_r2_keras: 0.9617 - val_root_mean_squared_error: 0.0543
# Epoch 36/200
# 20631/20631 - 0s - loss: 0.0549 - mae: 0.0346 - r2_keras: 0.9610 - root_mean_squared_error: 0.0549 - val_loss: 0.0550 - val_mae: 0.0346 - val_r2_keras: 0.9607 - val_root_mean_squared_error: 0.0550
# Epoch 37/200
# 20631/20631 - 0s - loss: 0.0547 - mae: 0.0345 - r2_keras: 0.9612 - root_mean_squared_error: 0.0547 - val_loss: 0.0550 - val_mae: 0.0346 - val_r2_keras: 0.9608 - val_root_mean_squared_error: 0.0550
# Epoch 38/200
# 20631/20631 - 0s - loss: 0.0545 - mae: 0.0343 - r2_keras: 0.9616 - root_mean_squared_error: 0.0545 - val_loss: 0.0541 - val_mae: 0.0340 - val_r2_keras: 0.9620 - val_root_mean_squared_error: 0.0541
# Epoch 39/200
# 20631/20631 - 0s - loss: 0.0544 - mae: 0.0343 - r2_keras: 0.9617 - root_mean_squared_error: 0.0544 - val_loss: 0.0538 - val_mae: 0.0338 - val_r2_keras: 0.9625 - val_root_mean_squared_error: 0.0538
# Epoch 40/200
# 20631/20631 - 0s - loss: 0.0541 - mae: 0.0342 - r2_keras: 0.9621 - root_mean_squared_error: 0.0542 - val_loss: 0.0538 - val_mae: 0.0344 - val_r2_keras: 0.9625 - val_root_mean_squared_error: 0.0538
# Epoch 41/200
# 20631/20631 - 0s - loss: 0.0540 - mae: 0.0342 - r2_keras: 0.9623 - root_mean_squared_error: 0.0540 - val_loss: 0.0538 - val_mae: 0.0341 - val_r2_keras: 0.9625 - val_root_mean_squared_error: 0.0538
# Epoch 42/200
# 20631/20631 - 0s - loss: 0.0539 - mae: 0.0341 - r2_keras: 0.9624 - root_mean_squared_error: 0.0539 - val_loss: 0.0537 - val_mae: 0.0339 - val_r2_keras: 0.9626 - val_root_mean_squared_error: 0.0537
# Epoch 43/200
# 20631/20631 - 0s - loss: 0.0536 - mae: 0.0340 - r2_keras: 0.9628 - root_mean_squared_error: 0.0536 - val_loss: 0.0536 - val_mae: 0.0337 - val_r2_keras: 0.9627 - val_root_mean_squared_error: 0.0536
# Epoch 44/200
# 20631/20631 - 0s - loss: 0.0535 - mae: 0.0339 - r2_keras: 0.9629 - root_mean_squared_error: 0.0535 - val_loss: 0.0534 - val_mae: 0.0336 - val_r2_keras: 0.9631 - val_root_mean_squared_error: 0.0534
# Epoch 45/200
# 20631/20631 - 0s - loss: 0.0533 - mae: 0.0338 - r2_keras: 0.9632 - root_mean_squared_error: 0.0533 - val_loss: 0.0541 - val_mae: 0.0341 - val_r2_keras: 0.9620 - val_root_mean_squared_error: 0.0541
# Epoch 46/200
# 20631/20631 - 0s - loss: 0.0532 - mae: 0.0337 - r2_keras: 0.9634 - root_mean_squared_error: 0.0532 - val_loss: 0.0527 - val_mae: 0.0336 - val_r2_keras: 0.9640 - val_root_mean_squared_error: 0.0527
# Epoch 47/200
# 20631/20631 - 0s - loss: 0.0530 - mae: 0.0336 - r2_keras: 0.9637 - root_mean_squared_error: 0.0530 - val_loss: 0.0534 - val_mae: 0.0342 - val_r2_keras: 0.9630 - val_root_mean_squared_error: 0.0534
# Epoch 48/200
# 20631/20631 - 0s - loss: 0.0529 - mae: 0.0335 - r2_keras: 0.9638 - root_mean_squared_error: 0.0529 - val_loss: 0.0529 - val_mae: 0.0335 - val_r2_keras: 0.9637 - val_root_mean_squared_error: 0.0529
# Epoch 49/200
# 20631/20631 - 0s - loss: 0.0527 - mae: 0.0335 - r2_keras: 0.9640 - root_mean_squared_error: 0.0527 - val_loss: 0.0523 - val_mae: 0.0333 - val_r2_keras: 0.9646 - val_root_mean_squared_error: 0.0523
# Epoch 50/200
# 20631/20631 - 0s - loss: 0.0525 - mae: 0.0333 - r2_keras: 0.9644 - root_mean_squared_error: 0.0525 - val_loss: 0.0533 - val_mae: 0.0337 - val_r2_keras: 0.9632 - val_root_mean_squared_error: 0.0533
# Epoch 51/200
# 20631/20631 - 0s - loss: 0.0523 - mae: 0.0332 - r2_keras: 0.9646 - root_mean_squared_error: 0.0523 - val_loss: 0.0520 - val_mae: 0.0329 - val_r2_keras: 0.9649 - val_root_mean_squared_error: 0.0520
# Epoch 52/200
# 20631/20631 - 0s - loss: 0.0521 - mae: 0.0331 - r2_keras: 0.9649 - root_mean_squared_error: 0.0521 - val_loss: 0.0520 - val_mae: 0.0333 - val_r2_keras: 0.9649 - val_root_mean_squared_error: 0.0520
# Epoch 53/200
# 20631/20631 - 0s - loss: 0.0519 - mae: 0.0330 - r2_keras: 0.9651 - root_mean_squared_error: 0.0519 - val_loss: 0.0515 - val_mae: 0.0328 - val_r2_keras: 0.9656 - val_root_mean_squared_error: 0.0515
# Epoch 54/200
# 20631/20631 - 0s - loss: 0.0517 - mae: 0.0328 - r2_keras: 0.9654 - root_mean_squared_error: 0.0517 - val_loss: 0.0517 - val_mae: 0.0328 - val_r2_keras: 0.9653 - val_root_mean_squared_error: 0.0517
# Epoch 55/200
# 20631/20631 - 0s - loss: 0.0515 - mae: 0.0328 - r2_keras: 0.9657 - root_mean_squared_error: 0.0515 - val_loss: 0.0509 - val_mae: 0.0323 - val_r2_keras: 0.9663 - val_root_mean_squared_error: 0.0509
# Epoch 56/200
# 20631/20631 - 0s - loss: 0.0512 - mae: 0.0326 - r2_keras: 0.9660 - root_mean_squared_error: 0.0512 - val_loss: 0.0507 - val_mae: 0.0322 - val_r2_keras: 0.9667 - val_root_mean_squared_error: 0.0506
# Epoch 57/200
# 20631/20631 - 0s - loss: 0.0511 - mae: 0.0325 - r2_keras: 0.9663 - root_mean_squared_error: 0.0511 - val_loss: 0.0522 - val_mae: 0.0330 - val_r2_keras: 0.9647 - val_root_mean_squared_error: 0.0522
# Epoch 58/200
# 20631/20631 - 0s - loss: 0.0508 - mae: 0.0324 - r2_keras: 0.9665 - root_mean_squared_error: 0.0508 - val_loss: 0.0510 - val_mae: 0.0324 - val_r2_keras: 0.9662 - val_root_mean_squared_error: 0.0510
# Epoch 59/200
# 20631/20631 - 0s - loss: 0.0507 - mae: 0.0322 - r2_keras: 0.9667 - root_mean_squared_error: 0.0507 - val_loss: 0.0508 - val_mae: 0.0321 - val_r2_keras: 0.9666 - val_root_mean_squared_error: 0.0508
# Epoch 60/200
# 20631/20631 - 0s - loss: 0.0505 - mae: 0.0321 - r2_keras: 0.9670 - root_mean_squared_error: 0.0505 - val_loss: 0.0497 - val_mae: 0.0318 - val_r2_keras: 0.9679 - val_root_mean_squared_error: 0.0497
# Epoch 61/200
# 20631/20631 - 0s - loss: 0.0503 - mae: 0.0320 - r2_keras: 0.9672 - root_mean_squared_error: 0.0503 - val_loss: 0.0509 - val_mae: 0.0322 - val_r2_keras: 0.9664 - val_root_mean_squared_error: 0.0509
# Epoch 62/200
# 20631/20631 - 0s - loss: 0.0502 - mae: 0.0319 - r2_keras: 0.9673 - root_mean_squared_error: 0.0502 - val_loss: 0.0512 - val_mae: 0.0325 - val_r2_keras: 0.9659 - val_root_mean_squared_error: 0.0512
# Epoch 63/200
# 20631/20631 - 0s - loss: 0.0501 - mae: 0.0319 - r2_keras: 0.9675 - root_mean_squared_error: 0.0501 - val_loss: 0.0501 - val_mae: 0.0316 - val_r2_keras: 0.9675 - val_root_mean_squared_error: 0.0501
# Epoch 64/200
# 20631/20631 - 0s - loss: 0.0500 - mae: 0.0317 - r2_keras: 0.9677 - root_mean_squared_error: 0.0500 - val_loss: 0.0497 - val_mae: 0.0315 - val_r2_keras: 0.9680 - val_root_mean_squared_error: 0.0497
# Epoch 65/200
# 20631/20631 - 0s - loss: 0.0498 - mae: 0.0317 - r2_keras: 0.9679 - root_mean_squared_error: 0.0498 - val_loss: 0.0494 - val_mae: 0.0312 - val_r2_keras: 0.9684 - val_root_mean_squared_error: 0.0494
# Epoch 66/200
# 20631/20631 - 0s - loss: 0.0498 - mae: 0.0316 - r2_keras: 0.9679 - root_mean_squared_error: 0.0498 - val_loss: 0.0493 - val_mae: 0.0312 - val_r2_keras: 0.9684 - val_root_mean_squared_error: 0.0493
# Epoch 67/200
# 20631/20631 - 0s - loss: 0.0496 - mae: 0.0315 - r2_keras: 0.9681 - root_mean_squared_error: 0.0496 - val_loss: 0.0501 - val_mae: 0.0317 - val_r2_keras: 0.9674 - val_root_mean_squared_error: 0.0501
# Epoch 68/200
# 20631/20631 - 0s - loss: 0.0496 - mae: 0.0315 - r2_keras: 0.9682 - root_mean_squared_error: 0.0496 - val_loss: 0.0489 - val_mae: 0.0311 - val_r2_keras: 0.9690 - val_root_mean_squared_error: 0.0489
# Epoch 69/200
# 20631/20631 - 0s - loss: 0.0494 - mae: 0.0314 - r2_keras: 0.9684 - root_mean_squared_error: 0.0494 - val_loss: 0.0488 - val_mae: 0.0308 - val_r2_keras: 0.9691 - val_root_mean_squared_error: 0.0488
# Epoch 70/200
# 20631/20631 - 0s - loss: 0.0494 - mae: 0.0314 - r2_keras: 0.9685 - root_mean_squared_error: 0.0494 - val_loss: 0.0504 - val_mae: 0.0317 - val_r2_keras: 0.9670 - val_root_mean_squared_error: 0.0504
# Epoch 71/200
# 20631/20631 - 0s - loss: 0.0493 - mae: 0.0313 - r2_keras: 0.9686 - root_mean_squared_error: 0.0493 - val_loss: 0.0491 - val_mae: 0.0314 - val_r2_keras: 0.9688 - val_root_mean_squared_error: 0.0491
# Epoch 72/200
# 20631/20631 - 0s - loss: 0.0491 - mae: 0.0312 - r2_keras: 0.9688 - root_mean_squared_error: 0.0491 - val_loss: 0.0495 - val_mae: 0.0320 - val_r2_keras: 0.9682 - val_root_mean_squared_error: 0.0495
# Epoch 73/200
# 20631/20631 - 0s - loss: 0.0491 - mae: 0.0312 - r2_keras: 0.9688 - root_mean_squared_error: 0.0491 - val_loss: 0.0490 - val_mae: 0.0311 - val_r2_keras: 0.9688 - val_root_mean_squared_error: 0.0490
# Epoch 74/200
# 20631/20631 - 0s - loss: 0.0490 - mae: 0.0311 - r2_keras: 0.9690 - root_mean_squared_error: 0.0490 - val_loss: 0.0495 - val_mae: 0.0313 - val_r2_keras: 0.9682 - val_root_mean_squared_error: 0.0495
# Epoch 75/200
# 20631/20631 - 0s - loss: 0.0488 - mae: 0.0309 - r2_keras: 0.9691 - root_mean_squared_error: 0.0488 - val_loss: 0.0487 - val_mae: 0.0306 - val_r2_keras: 0.9693 - val_root_mean_squared_error: 0.0486
# Epoch 76/200
# 20631/20631 - 0s - loss: 0.0488 - mae: 0.0309 - r2_keras: 0.9692 - root_mean_squared_error: 0.0488 - val_loss: 0.0487 - val_mae: 0.0308 - val_r2_keras: 0.9692 - val_root_mean_squared_error: 0.0487
# Epoch 77/200
# 20631/20631 - 0s - loss: 0.0487 - mae: 0.0309 - r2_keras: 0.9693 - root_mean_squared_error: 0.0487 - val_loss: 0.0484 - val_mae: 0.0306 - val_r2_keras: 0.9696 - val_root_mean_squared_error: 0.0484
# Epoch 78/200
# 20631/20631 - 0s - loss: 0.0485 - mae: 0.0308 - r2_keras: 0.9695 - root_mean_squared_error: 0.0485 - val_loss: 0.0483 - val_mae: 0.0304 - val_r2_keras: 0.9697 - val_root_mean_squared_error: 0.0483
# Epoch 79/200
# 20631/20631 - 0s - loss: 0.0484 - mae: 0.0306 - r2_keras: 0.9697 - root_mean_squared_error: 0.0484 - val_loss: 0.0483 - val_mae: 0.0308 - val_r2_keras: 0.9697 - val_root_mean_squared_error: 0.0483
# Epoch 80/200
# 20631/20631 - 0s - loss: 0.0483 - mae: 0.0307 - r2_keras: 0.9697 - root_mean_squared_error: 0.0484 - val_loss: 0.0474 - val_mae: 0.0300 - val_r2_keras: 0.9709 - val_root_mean_squared_error: 0.0474
# Epoch 81/200
# 20631/20631 - 0s - loss: 0.0482 - mae: 0.0305 - r2_keras: 0.9700 - root_mean_squared_error: 0.0482 - val_loss: 0.0483 - val_mae: 0.0305 - val_r2_keras: 0.9698 - val_root_mean_squared_error: 0.0483
# Epoch 82/200
# 20631/20631 - 0s - loss: 0.0480 - mae: 0.0304 - r2_keras: 0.9701 - root_mean_squared_error: 0.0481 - val_loss: 0.0482 - val_mae: 0.0306 - val_r2_keras: 0.9699 - val_root_mean_squared_error: 0.0482
# Epoch 83/200
# 20631/20631 - 0s - loss: 0.0479 - mae: 0.0303 - r2_keras: 0.9703 - root_mean_squared_error: 0.0479 - val_loss: 0.0480 - val_mae: 0.0306 - val_r2_keras: 0.9701 - val_root_mean_squared_error: 0.0480
# Epoch 84/200
# 20631/20631 - 0s - loss: 0.0478 - mae: 0.0303 - r2_keras: 0.9704 - root_mean_squared_error: 0.0478 - val_loss: 0.0476 - val_mae: 0.0303 - val_r2_keras: 0.9707 - val_root_mean_squared_error: 0.0475
# Epoch 85/200
# 20631/20631 - 0s - loss: 0.0477 - mae: 0.0302 - r2_keras: 0.9706 - root_mean_squared_error: 0.0477 - val_loss: 0.0471 - val_mae: 0.0299 - val_r2_keras: 0.9712 - val_root_mean_squared_error: 0.0471
# Epoch 86/200
# 20631/20631 - 0s - loss: 0.0475 - mae: 0.0301 - r2_keras: 0.9708 - root_mean_squared_error: 0.0475 - val_loss: 0.0477 - val_mae: 0.0305 - val_r2_keras: 0.9704 - val_root_mean_squared_error: 0.0477
# Epoch 87/200
# 20631/20631 - 0s - loss: 0.0475 - mae: 0.0300 - r2_keras: 0.9708 - root_mean_squared_error: 0.0475 - val_loss: 0.0470 - val_mae: 0.0300 - val_r2_keras: 0.9714 - val_root_mean_squared_error: 0.0470
# Epoch 88/200
# 20631/20631 - 0s - loss: 0.0473 - mae: 0.0299 - r2_keras: 0.9710 - root_mean_squared_error: 0.0473 - val_loss: 0.0477 - val_mae: 0.0303 - val_r2_keras: 0.9705 - val_root_mean_squared_error: 0.0477
# Epoch 89/200
# 20631/20631 - 0s - loss: 0.0473 - mae: 0.0299 - r2_keras: 0.9711 - root_mean_squared_error: 0.0473 - val_loss: 0.0478 - val_mae: 0.0302 - val_r2_keras: 0.9703 - val_root_mean_squared_error: 0.0478
# Epoch 90/200
# 20631/20631 - 0s - loss: 0.0471 - mae: 0.0298 - r2_keras: 0.9712 - root_mean_squared_error: 0.0471 - val_loss: 0.0477 - val_mae: 0.0304 - val_r2_keras: 0.9705 - val_root_mean_squared_error: 0.0477
# Epoch 91/200
# 20631/20631 - 0s - loss: 0.0471 - mae: 0.0297 - r2_keras: 0.9713 - root_mean_squared_error: 0.0471 - val_loss: 0.0467 - val_mae: 0.0298 - val_r2_keras: 0.9718 - val_root_mean_squared_error: 0.0466
# Epoch 92/200
# 20631/20631 - 0s - loss: 0.0470 - mae: 0.0297 - r2_keras: 0.9715 - root_mean_squared_error: 0.0470 - val_loss: 0.0466 - val_mae: 0.0293 - val_r2_keras: 0.9718 - val_root_mean_squared_error: 0.0466
# Epoch 93/200
# 20631/20631 - 0s - loss: 0.0469 - mae: 0.0296 - r2_keras: 0.9715 - root_mean_squared_error: 0.0469 - val_loss: 0.0466 - val_mae: 0.0291 - val_r2_keras: 0.9719 - val_root_mean_squared_error: 0.0466
# Epoch 94/200
# 20631/20631 - 0s - loss: 0.0469 - mae: 0.0295 - r2_keras: 0.9716 - root_mean_squared_error: 0.0468 - val_loss: 0.0464 - val_mae: 0.0295 - val_r2_keras: 0.9721 - val_root_mean_squared_error: 0.0464
# Epoch 95/200
# 20631/20631 - 0s - loss: 0.0468 - mae: 0.0295 - r2_keras: 0.9717 - root_mean_squared_error: 0.0468 - val_loss: 0.0466 - val_mae: 0.0292 - val_r2_keras: 0.9718 - val_root_mean_squared_error: 0.0466
# Epoch 96/200
# 20631/20631 - 0s - loss: 0.0467 - mae: 0.0295 - r2_keras: 0.9717 - root_mean_squared_error: 0.0467 - val_loss: 0.0473 - val_mae: 0.0300 - val_r2_keras: 0.9710 - val_root_mean_squared_error: 0.0473
# Epoch 97/200
# 20631/20631 - 0s - loss: 0.0467 - mae: 0.0294 - r2_keras: 0.9718 - root_mean_squared_error: 0.0467 - val_loss: 0.0471 - val_mae: 0.0297 - val_r2_keras: 0.9712 - val_root_mean_squared_error: 0.0471
# Epoch 98/200
# 20631/20631 - 0s - loss: 0.0467 - mae: 0.0294 - r2_keras: 0.9718 - root_mean_squared_error: 0.0467 - val_loss: 0.0462 - val_mae: 0.0288 - val_r2_keras: 0.9724 - val_root_mean_squared_error: 0.0462
# Epoch 99/200
# 20631/20631 - 0s - loss: 0.0466 - mae: 0.0293 - r2_keras: 0.9719 - root_mean_squared_error: 0.0466 - val_loss: 0.0476 - val_mae: 0.0296 - val_r2_keras: 0.9706 - val_root_mean_squared_error: 0.0476
# Epoch 100/200
# 20631/20631 - 0s - loss: 0.0466 - mae: 0.0293 - r2_keras: 0.9720 - root_mean_squared_error: 0.0465 - val_loss: 0.0465 - val_mae: 0.0295 - val_r2_keras: 0.9720 - val_root_mean_squared_error: 0.0465
# Epoch 101/200
# 20631/20631 - 0s - loss: 0.0465 - mae: 0.0293 - r2_keras: 0.9720 - root_mean_squared_error: 0.0465 - val_loss: 0.0465 - val_mae: 0.0291 - val_r2_keras: 0.9719 - val_root_mean_squared_error: 0.0465
# Epoch 102/200
# 20631/20631 - 0s - loss: 0.0465 - mae: 0.0292 - r2_keras: 0.9720 - root_mean_squared_error: 0.0465 - val_loss: 0.0458 - val_mae: 0.0286 - val_r2_keras: 0.9728 - val_root_mean_squared_error: 0.0458
# Epoch 103/200
# 20631/20631 - 0s - loss: 0.0464 - mae: 0.0292 - r2_keras: 0.9721 - root_mean_squared_error: 0.0464 - val_loss: 0.0472 - val_mae: 0.0295 - val_r2_keras: 0.9711 - val_root_mean_squared_error: 0.0472
# Epoch 104/200
# 20631/20631 - 0s - loss: 0.0463 - mae: 0.0292 - r2_keras: 0.9722 - root_mean_squared_error: 0.0463 - val_loss: 0.0479 - val_mae: 0.0303 - val_r2_keras: 0.9702 - val_root_mean_squared_error: 0.0479
# Epoch 105/200
# 20631/20631 - 0s - loss: 0.0464 - mae: 0.0292 - r2_keras: 0.9722 - root_mean_squared_error: 0.0464 - val_loss: 0.0470 - val_mae: 0.0292 - val_r2_keras: 0.9713 - val_root_mean_squared_error: 0.0470
# Epoch 106/200
# 20631/20631 - 0s - loss: 0.0463 - mae: 0.0291 - r2_keras: 0.9723 - root_mean_squared_error: 0.0463 - val_loss: 0.0474 - val_mae: 0.0295 - val_r2_keras: 0.9708 - val_root_mean_squared_error: 0.0474
# Epoch 107/200
# 20631/20631 - 0s - loss: 0.0463 - mae: 0.0291 - r2_keras: 0.9723 - root_mean_squared_error: 0.0463 - val_loss: 0.0457 - val_mae: 0.0286 - val_r2_keras: 0.9729 - val_root_mean_squared_error: 0.0457
# Epoch 108/200
# 20631/20631 - 0s - loss: 0.0461 - mae: 0.0291 - r2_keras: 0.9725 - root_mean_squared_error: 0.0461 - val_loss: 0.0480 - val_mae: 0.0303 - val_r2_keras: 0.9701 - val_root_mean_squared_error: 0.0480
# Epoch 109/200
# 20631/20631 - 0s - loss: 0.0461 - mae: 0.0290 - r2_keras: 0.9725 - root_mean_squared_error: 0.0461 - val_loss: 0.0461 - val_mae: 0.0287 - val_r2_keras: 0.9725 - val_root_mean_squared_error: 0.0461
# Epoch 110/200
# 20631/20631 - 0s - loss: 0.0458 - mae: 0.0288 - r2_keras: 0.9728 - root_mean_squared_error: 0.0458 - val_loss: 0.0460 - val_mae: 0.0292 - val_r2_keras: 0.9725 - val_root_mean_squared_error: 0.0460
# Epoch 111/200
# 20631/20631 - 0s - loss: 0.0455 - mae: 0.0286 - r2_keras: 0.9732 - root_mean_squared_error: 0.0455 - val_loss: 0.0457 - val_mae: 0.0286 - val_r2_keras: 0.9729 - val_root_mean_squared_error: 0.0457
# Epoch 112/200
# 20631/20631 - 0s - loss: 0.0451 - mae: 0.0283 - r2_keras: 0.9737 - root_mean_squared_error: 0.0451 - val_loss: 0.0463 - val_mae: 0.0293 - val_r2_keras: 0.9722 - val_root_mean_squared_error: 0.0463
# Epoch 113/200
# 20631/20631 - 0s - loss: 0.0448 - mae: 0.0281 - r2_keras: 0.9740 - root_mean_squared_error: 0.0448 - val_loss: 0.0446 - val_mae: 0.0276 - val_r2_keras: 0.9742 - val_root_mean_squared_error: 0.0446
# Epoch 114/200
# 20631/20631 - 0s - loss: 0.0446 - mae: 0.0279 - r2_keras: 0.9743 - root_mean_squared_error: 0.0446 - val_loss: 0.0447 - val_mae: 0.0281 - val_r2_keras: 0.9741 - val_root_mean_squared_error: 0.0447
# Epoch 115/200
# 20631/20631 - 0s - loss: 0.0444 - mae: 0.0278 - r2_keras: 0.9745 - root_mean_squared_error: 0.0444 - val_loss: 0.0438 - val_mae: 0.0269 - val_r2_keras: 0.9751 - val_root_mean_squared_error: 0.0438
# Epoch 116/200
# 20631/20631 - 0s - loss: 0.0443 - mae: 0.0277 - r2_keras: 0.9746 - root_mean_squared_error: 0.0443 - val_loss: 0.0439 - val_mae: 0.0278 - val_r2_keras: 0.9750 - val_root_mean_squared_error: 0.0439
# Epoch 117/200
# 20631/20631 - 0s - loss: 0.0442 - mae: 0.0277 - r2_keras: 0.9747 - root_mean_squared_error: 0.0442 - val_loss: 0.0441 - val_mae: 0.0274 - val_r2_keras: 0.9748 - val_root_mean_squared_error: 0.0441
# Epoch 118/200
# 20631/20631 - 0s - loss: 0.0442 - mae: 0.0276 - r2_keras: 0.9748 - root_mean_squared_error: 0.0442 - val_loss: 0.0446 - val_mae: 0.0274 - val_r2_keras: 0.9742 - val_root_mean_squared_error: 0.0446
# Epoch 119/200
# 20631/20631 - 0s - loss: 0.0440 - mae: 0.0275 - r2_keras: 0.9749 - root_mean_squared_error: 0.0440 - val_loss: 0.0437 - val_mae: 0.0272 - val_r2_keras: 0.9753 - val_root_mean_squared_error: 0.0437
# Epoch 120/200
# 20631/20631 - 0s - loss: 0.0440 - mae: 0.0275 - r2_keras: 0.9750 - root_mean_squared_error: 0.0440 - val_loss: 0.0432 - val_mae: 0.0268 - val_r2_keras: 0.9758 - val_root_mean_squared_error: 0.0432
# Epoch 121/200
# 20631/20631 - 0s - loss: 0.0439 - mae: 0.0275 - r2_keras: 0.9751 - root_mean_squared_error: 0.0439 - val_loss: 0.0438 - val_mae: 0.0274 - val_r2_keras: 0.9751 - val_root_mean_squared_error: 0.0438
# Epoch 122/200
# 20631/20631 - 0s - loss: 0.0439 - mae: 0.0274 - r2_keras: 0.9751 - root_mean_squared_error: 0.0439 - val_loss: 0.0439 - val_mae: 0.0272 - val_r2_keras: 0.9750 - val_root_mean_squared_error: 0.0439
# Epoch 123/200
# 20631/20631 - 0s - loss: 0.0438 - mae: 0.0273 - r2_keras: 0.9752 - root_mean_squared_error: 0.0438 - val_loss: 0.0440 - val_mae: 0.0274 - val_r2_keras: 0.9749 - val_root_mean_squared_error: 0.0440
# Epoch 124/200
# 20631/20631 - 0s - loss: 0.0438 - mae: 0.0273 - r2_keras: 0.9752 - root_mean_squared_error: 0.0438 - val_loss: 0.0437 - val_mae: 0.0277 - val_r2_keras: 0.9752 - val_root_mean_squared_error: 0.0437
# Epoch 125/200
# 20631/20631 - 0s - loss: 0.0437 - mae: 0.0272 - r2_keras: 0.9753 - root_mean_squared_error: 0.0437 - val_loss: 0.0443 - val_mae: 0.0271 - val_r2_keras: 0.9745 - val_root_mean_squared_error: 0.0443
# Epoch 126/200
# 20631/20631 - 0s - loss: 0.0437 - mae: 0.0272 - r2_keras: 0.9753 - root_mean_squared_error: 0.0437 - val_loss: 0.0431 - val_mae: 0.0270 - val_r2_keras: 0.9759 - val_root_mean_squared_error: 0.0431
# Epoch 127/200
# 20631/20631 - 0s - loss: 0.0436 - mae: 0.0272 - r2_keras: 0.9755 - root_mean_squared_error: 0.0435 - val_loss: 0.0445 - val_mae: 0.0287 - val_r2_keras: 0.9743 - val_root_mean_squared_error: 0.0445
# Epoch 128/200
# 20631/20631 - 0s - loss: 0.0436 - mae: 0.0271 - r2_keras: 0.9754 - root_mean_squared_error: 0.0436 - val_loss: 0.0439 - val_mae: 0.0272 - val_r2_keras: 0.9750 - val_root_mean_squared_error: 0.0439
# Epoch 129/200
# 20631/20631 - 0s - loss: 0.0435 - mae: 0.0272 - r2_keras: 0.9755 - root_mean_squared_error: 0.0435 - val_loss: 0.0437 - val_mae: 0.0270 - val_r2_keras: 0.9752 - val_root_mean_squared_error: 0.0437
# Epoch 130/200
# 20631/20631 - 0s - loss: 0.0433 - mae: 0.0270 - r2_keras: 0.9757 - root_mean_squared_error: 0.0433 - val_loss: 0.0439 - val_mae: 0.0273 - val_r2_keras: 0.9750 - val_root_mean_squared_error: 0.0439
# Epoch 131/200
# 20631/20631 - 0s - loss: 0.0433 - mae: 0.0271 - r2_keras: 0.9757 - root_mean_squared_error: 0.0433 - val_loss: 0.0439 - val_mae: 0.0279 - val_r2_keras: 0.9750 - val_root_mean_squared_error: 0.0439
# Epoch 132/200
# 20631/20631 - 0s - loss: 0.0432 - mae: 0.0269 - r2_keras: 0.9759 - root_mean_squared_error: 0.0432 - val_loss: 0.0433 - val_mae: 0.0267 - val_r2_keras: 0.9757 - val_root_mean_squared_error: 0.0433
# Epoch 133/200
# 20631/20631 - 0s - loss: 0.0431 - mae: 0.0269 - r2_keras: 0.9760 - root_mean_squared_error: 0.0431 - val_loss: 0.0425 - val_mae: 0.0268 - val_r2_keras: 0.9766 - val_root_mean_squared_error: 0.0425
# Epoch 134/200
# 20631/20631 - 0s - loss: 0.0428 - mae: 0.0268 - r2_keras: 0.9763 - root_mean_squared_error: 0.0428 - val_loss: 0.0427 - val_mae: 0.0274 - val_r2_keras: 0.9763 - val_root_mean_squared_error: 0.0427
# Epoch 135/200
# 20631/20631 - 0s - loss: 0.0427 - mae: 0.0267 - r2_keras: 0.9764 - root_mean_squared_error: 0.0427 - val_loss: 0.0440 - val_mae: 0.0273 - val_r2_keras: 0.9749 - val_root_mean_squared_error: 0.0440
# Epoch 136/200
# 20631/20631 - 0s - loss: 0.0425 - mae: 0.0265 - r2_keras: 0.9766 - root_mean_squared_error: 0.0425 - val_loss: 0.0429 - val_mae: 0.0269 - val_r2_keras: 0.9761 - val_root_mean_squared_error: 0.0429
# Epoch 137/200
# 20631/20631 - 0s - loss: 0.0422 - mae: 0.0264 - r2_keras: 0.9769 - root_mean_squared_error: 0.0422 - val_loss: 0.0417 - val_mae: 0.0257 - val_r2_keras: 0.9775 - val_root_mean_squared_error: 0.0417
# Epoch 138/200
# 20631/20631 - 0s - loss: 0.0421 - mae: 0.0262 - r2_keras: 0.9771 - root_mean_squared_error: 0.0421 - val_loss: 0.0424 - val_mae: 0.0264 - val_r2_keras: 0.9767 - val_root_mean_squared_error: 0.0424
# Epoch 139/200
# 20631/20631 - 0s - loss: 0.0418 - mae: 0.0260 - r2_keras: 0.9774 - root_mean_squared_error: 0.0418 - val_loss: 0.0415 - val_mae: 0.0259 - val_r2_keras: 0.9776 - val_root_mean_squared_error: 0.0415
# Epoch 140/200
# 20631/20631 - 0s - loss: 0.0417 - mae: 0.0259 - r2_keras: 0.9775 - root_mean_squared_error: 0.0417 - val_loss: 0.0407 - val_mae: 0.0253 - val_r2_keras: 0.9785 - val_root_mean_squared_error: 0.0407
# Epoch 141/200
# 20631/20631 - 0s - loss: 0.0415 - mae: 0.0258 - r2_keras: 0.9777 - root_mean_squared_error: 0.0415 - val_loss: 0.0413 - val_mae: 0.0257 - val_r2_keras: 0.9779 - val_root_mean_squared_error: 0.0413
# Epoch 142/200
# 20631/20631 - 0s - loss: 0.0414 - mae: 0.0257 - r2_keras: 0.9778 - root_mean_squared_error: 0.0414 - val_loss: 0.0416 - val_mae: 0.0260 - val_r2_keras: 0.9775 - val_root_mean_squared_error: 0.0416
# Epoch 143/200
# 20631/20631 - 0s - loss: 0.0412 - mae: 0.0256 - r2_keras: 0.9780 - root_mean_squared_error: 0.0412 - val_loss: 0.0410 - val_mae: 0.0257 - val_r2_keras: 0.9782 - val_root_mean_squared_error: 0.0410
# Epoch 144/200
# 20631/20631 - 0s - loss: 0.0411 - mae: 0.0255 - r2_keras: 0.9781 - root_mean_squared_error: 0.0411 - val_loss: 0.0414 - val_mae: 0.0260 - val_r2_keras: 0.9778 - val_root_mean_squared_error: 0.0414
# Epoch 145/200
# 20631/20631 - 0s - loss: 0.0411 - mae: 0.0254 - r2_keras: 0.9781 - root_mean_squared_error: 0.0411 - val_loss: 0.0408 - val_mae: 0.0251 - val_r2_keras: 0.9784 - val_root_mean_squared_error: 0.0408
# Epoch 146/200
# 20631/20631 - 0s - loss: 0.0409 - mae: 0.0253 - r2_keras: 0.9783 - root_mean_squared_error: 0.0409 - val_loss: 0.0400 - val_mae: 0.0251 - val_r2_keras: 0.9792 - val_root_mean_squared_error: 0.0400
# Epoch 147/200
# 20631/20631 - 0s - loss: 0.0409 - mae: 0.0253 - r2_keras: 0.9783 - root_mean_squared_error: 0.0409 - val_loss: 0.0404 - val_mae: 0.0253 - val_r2_keras: 0.9788 - val_root_mean_squared_error: 0.0404
# Epoch 148/200
# 20631/20631 - 0s - loss: 0.0408 - mae: 0.0253 - r2_keras: 0.9784 - root_mean_squared_error: 0.0408 - val_loss: 0.0404 - val_mae: 0.0245 - val_r2_keras: 0.9788 - val_root_mean_squared_error: 0.0404
# Epoch 149/200
# 20631/20631 - 0s - loss: 0.0408 - mae: 0.0252 - r2_keras: 0.9785 - root_mean_squared_error: 0.0408 - val_loss: 0.0401 - val_mae: 0.0253 - val_r2_keras: 0.9791 - val_root_mean_squared_error: 0.0401
# Epoch 150/200
# 20631/20631 - 0s - loss: 0.0407 - mae: 0.0251 - r2_keras: 0.9786 - root_mean_squared_error: 0.0407 - val_loss: 0.0422 - val_mae: 0.0261 - val_r2_keras: 0.9769 - val_root_mean_squared_error: 0.0422
# Epoch 151/200
# 20631/20631 - 0s - loss: 0.0407 - mae: 0.0252 - r2_keras: 0.9786 - root_mean_squared_error: 0.0407 - val_loss: 0.0399 - val_mae: 0.0248 - val_r2_keras: 0.9793 - val_root_mean_squared_error: 0.0399
# Epoch 152/200
# 20631/20631 - 0s - loss: 0.0406 - mae: 0.0251 - r2_keras: 0.9786 - root_mean_squared_error: 0.0406 - val_loss: 0.0397 - val_mae: 0.0248 - val_r2_keras: 0.9795 - val_root_mean_squared_error: 0.0397
# Epoch 153/200
# 20631/20631 - 0s - loss: 0.0405 - mae: 0.0250 - r2_keras: 0.9787 - root_mean_squared_error: 0.0405 - val_loss: 0.0414 - val_mae: 0.0260 - val_r2_keras: 0.9778 - val_root_mean_squared_error: 0.0414
# Epoch 154/200
# 20631/20631 - 0s - loss: 0.0405 - mae: 0.0250 - r2_keras: 0.9788 - root_mean_squared_error: 0.0405 - val_loss: 0.0417 - val_mae: 0.0260 - val_r2_keras: 0.9774 - val_root_mean_squared_error: 0.0417
# Epoch 155/200
# 20631/20631 - 0s - loss: 0.0405 - mae: 0.0250 - r2_keras: 0.9788 - root_mean_squared_error: 0.0405 - val_loss: 0.0413 - val_mae: 0.0258 - val_r2_keras: 0.9778 - val_root_mean_squared_error: 0.0413
# Epoch 156/200
# 20631/20631 - 0s - loss: 0.0404 - mae: 0.0250 - r2_keras: 0.9788 - root_mean_squared_error: 0.0404 - val_loss: 0.0403 - val_mae: 0.0254 - val_r2_keras: 0.9790 - val_root_mean_squared_error: 0.0403
# Epoch 157/200
# 20631/20631 - 0s - loss: 0.0404 - mae: 0.0250 - r2_keras: 0.9788 - root_mean_squared_error: 0.0404 - val_loss: 0.0402 - val_mae: 0.0250 - val_r2_keras: 0.9790 - val_root_mean_squared_error: 0.0402
# Epoch 158/200
# 20631/20631 - 0s - loss: 0.0404 - mae: 0.0248 - r2_keras: 0.9789 - root_mean_squared_error: 0.0404 - val_loss: 0.0398 - val_mae: 0.0246 - val_r2_keras: 0.9795 - val_root_mean_squared_error: 0.0398
# Epoch 159/200
# 20631/20631 - 0s - loss: 0.0404 - mae: 0.0249 - r2_keras: 0.9789 - root_mean_squared_error: 0.0404 - val_loss: 0.0398 - val_mae: 0.0245 - val_r2_keras: 0.9795 - val_root_mean_squared_error: 0.0398
# Epoch 160/200
# 20631/20631 - 0s - loss: 0.0403 - mae: 0.0249 - r2_keras: 0.9790 - root_mean_squared_error: 0.0403 - val_loss: 0.0401 - val_mae: 0.0247 - val_r2_keras: 0.9791 - val_root_mean_squared_error: 0.0401
# Epoch 161/200
# 20631/20631 - 0s - loss: 0.0403 - mae: 0.0248 - r2_keras: 0.9790 - root_mean_squared_error: 0.0403 - val_loss: 0.0395 - val_mae: 0.0239 - val_r2_keras: 0.9798 - val_root_mean_squared_error: 0.0395
# Epoch 162/200
# 20631/20631 - 0s - loss: 0.0402 - mae: 0.0249 - r2_keras: 0.9790 - root_mean_squared_error: 0.0402 - val_loss: 0.0402 - val_mae: 0.0247 - val_r2_keras: 0.9791 - val_root_mean_squared_error: 0.0402
# Epoch 163/200
# 20631/20631 - 0s - loss: 0.0402 - mae: 0.0248 - r2_keras: 0.9791 - root_mean_squared_error: 0.0402 - val_loss: 0.0397 - val_mae: 0.0244 - val_r2_keras: 0.9796 - val_root_mean_squared_error: 0.0397
# Epoch 164/200
# 20631/20631 - 0s - loss: 0.0402 - mae: 0.0247 - r2_keras: 0.9791 - root_mean_squared_error: 0.0402 - val_loss: 0.0410 - val_mae: 0.0251 - val_r2_keras: 0.9782 - val_root_mean_squared_error: 0.0410
# Epoch 165/200
# 20631/20631 - 0s - loss: 0.0402 - mae: 0.0248 - r2_keras: 0.9791 - root_mean_squared_error: 0.0402 - val_loss: 0.0396 - val_mae: 0.0244 - val_r2_keras: 0.9797 - val_root_mean_squared_error: 0.0396
# Epoch 166/200
# 20631/20631 - 0s - loss: 0.0401 - mae: 0.0247 - r2_keras: 0.9792 - root_mean_squared_error: 0.0401 - val_loss: 0.0406 - val_mae: 0.0256 - val_r2_keras: 0.9786 - val_root_mean_squared_error: 0.0406
# Epoch 167/200
# 20631/20631 - 0s - loss: 0.0401 - mae: 0.0247 - r2_keras: 0.9792 - root_mean_squared_error: 0.0401 - val_loss: 0.0398 - val_mae: 0.0242 - val_r2_keras: 0.9795 - val_root_mean_squared_error: 0.0398
# Epoch 168/200
# 20631/20631 - 0s - loss: 0.0400 - mae: 0.0247 - r2_keras: 0.9793 - root_mean_squared_error: 0.0400 - val_loss: 0.0406 - val_mae: 0.0247 - val_r2_keras: 0.9787 - val_root_mean_squared_error: 0.0406
# Epoch 169/200
# 20631/20631 - 0s - loss: 0.0401 - mae: 0.0247 - r2_keras: 0.9792 - root_mean_squared_error: 0.0400 - val_loss: 0.0399 - val_mae: 0.0244 - val_r2_keras: 0.9793 - val_root_mean_squared_error: 0.0399
# Epoch 170/200
# 20631/20631 - 0s - loss: 0.0400 - mae: 0.0246 - r2_keras: 0.9792 - root_mean_squared_error: 0.0400 - val_loss: 0.0407 - val_mae: 0.0248 - val_r2_keras: 0.9785 - val_root_mean_squared_error: 0.0407
# Epoch 171/200
# 20631/20631 - 0s - loss: 0.0400 - mae: 0.0245 - r2_keras: 0.9793 - root_mean_squared_error: 0.0400 - val_loss: 0.0402 - val_mae: 0.0246 - val_r2_keras: 0.9791 - val_root_mean_squared_error: 0.0402
# 20631/20631 [==============================] - 0s 8us/sample

# %%
#load encoder
def get_encoded_data(data, print_model_data):
  if os.path.isfile(model_path_autoecoder):

      # restore weights

      autoencoder_model = load_model(model_path_autoecoder,custom_objects={'r2_keras': r2_keras,'root_mean_squared_error': root_mean_squared_error })
      estimator_encoder = Model(inputs=autoencoder_model.inputs, outputs=autoencoder_model.layers[3].output)

      encoded_data = estimator_encoder.predict(data,verbose=1, batch_size=200)
      if print_model_data:
        print(estimator_encoder.summary())
      return encoded_data

# %%
##create encoded sequence data

# pick a window size
sequence_length = 64

encoded_cols = ['id', 's1', 's2', 's3','s4', 's5', 's6', 's7', 's8',]
#get encoded data first
encoded_data = get_encoded_data(train_x, True)
# Convert the dictionary into DataFrame 
encoded_train = pd.DataFrame(encoded_data) 
  
# Using DataFrame.insert() to add a column 
encoded_train.insert(0, "id", train_df['id'], True) 
#add column names
encoded_train.columns = encoded_cols

# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length):
    
    data_matrix = id_df[encoded_cols].values
    num_elements = data_matrix.shape[0]
    
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]
        

# generator for the sequences
# transform each id of the train dataset in a sequence
seq_gen = (list(gen_sequence(encoded_train[encoded_train['id']==id], sequence_length)) 
          for id in train_df['id'].unique())

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
print(seq_array.shape)
# Out:
# 20631/20631 [==============================] - 0s 6us/sample
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# =================================================================
# Total params: 1,496
# Trainable params: 1,496
# Non-trainable params: 0
# _________________________________________________________________
# None
# (14231, 64, 9)

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    return data_matrix[seq_length:num_elements, :]

# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]

label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
# (14231, 1)

# %%
##output tcn 3

timesteps = seq_array.shape[1]
nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]


i = Input(shape=(timesteps, nb_features))
#m = TCN()(i)
#m = Dense(1, activation='linear')(m)

m = TCN(nb_filters=32,dropout_rate = 0.2,dilations=[1, 2, 4, 8, 16, 32] ,return_sequences=True)(i)
#m = Dropout(0.2)(m)
m = TCN(nb_filters=16,dropout_rate = 0.2,dilations=[1, 2, 4, 8, 16, 32] ,return_sequences=False)(m)
#m = Dropout(0.2)(m)
m = Dense(1, activation='linear')(m)
model = Model(inputs=[i], outputs=[m])
'''
i = Input(shape=(sequence_length,nb_features))
x = TCN(nb_filters=64,
        kernel_size=6,
        dilations=[1,1,1, 1, 1, 1, 1, ])(i)
x = Dense(1, activation='linear')(x)
model = Model(inputs=[i], outputs=[x])
'''

model.summary()

model.compile('adam', 'mae')

model.compile(loss= root_mean_squared_error, optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 9)]           0
# _________________________________________________________________
# tcn (TCN)                    (None, 64, 32)            30560
# _________________________________________________________________
# tcn_1 (TCN)                  (None, 16)                8224
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 38,801
# Trainable params: 38,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(seq_array, label_array, epochs=200, batch_size=200, validation_split=0.05, verbose=2,
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                       keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
          )
# Out:
# Train on 13519 samples, validate on 712 samples
# Epoch 1/200
# 13519/13519 - 30s - loss: 1800.6963 - mae: 1214.7365 - r2_keras: -6.8659e+03 - root_mean_squared_error: 1791.2021 - val_loss: 72.6728 - val_mae: 61.6151 - val_r2_keras: -2.6068e+00 - val_root_mean_squared_error: 73.3074
# Epoch 2/200
# 13519/13519 - 22s - loss: 112.2468 - mae: 85.4852 - r2_keras: -3.7588e+00 - root_mean_squared_error: 111.9939 - val_loss: 53.7591 - val_mae: 45.2267 - val_r2_keras: -4.8269e-01 - val_root_mean_squared_error: 52.0840
# Epoch 3/200
# 13519/13519 - 22s - loss: 68.4006 - mae: 53.2370 - r2_keras: -6.1889e-01 - root_mean_squared_error: 68.3655 - val_loss: 53.0203 - val_mae: 44.2293 - val_r2_keras: -5.3999e-01 - val_root_mean_squared_error: 52.0367
# Epoch 4/200
# 13519/13519 - 22s - loss: 61.3814 - mae: 48.3004 - r2_keras: -3.0165e-01 - root_mean_squared_error: 61.3618 - val_loss: 51.7279 - val_mae: 43.5084 - val_r2_keras: -3.3379e-01 - val_root_mean_squared_error: 49.7071
# Epoch 5/200
# 13519/13519 - 22s - loss: 59.2941 - mae: 46.5637 - r2_keras: -2.1826e-01 - root_mean_squared_error: 59.3503 - val_loss: 57.6996 - val_mae: 48.6615 - val_r2_keras: -1.0660e+00 - val_root_mean_squared_error: 57.6025
# Epoch 6/200
# 13519/13519 - 22s - loss: 56.4828 - mae: 44.0986 - r2_keras: -1.0231e-01 - root_mean_squared_error: 56.4991 - val_loss: 48.2293 - val_mae: 40.5806 - val_r2_keras: -1.6153e-01 - val_root_mean_squared_error: 46.3673
# Epoch 7/200
# 13519/13519 - 22s - loss: 54.2960 - mae: 42.3600 - r2_keras: -2.0222e-02 - root_mean_squared_error: 54.3185 - val_loss: 58.6330 - val_mae: 49.9337 - val_r2_keras: -1.2212e+00 - val_root_mean_squared_error: 58.8080
# Epoch 8/200
# 13519/13519 - 22s - loss: 52.7386 - mae: 40.9058 - r2_keras: 0.0325 - root_mean_squared_error: 52.7321 - val_loss: 45.5547 - val_mae: 38.4063 - val_r2_keras: -1.0298e-01 - val_root_mean_squared_error: 44.4017
# Epoch 9/200
# 13519/13519 - 22s - loss: 52.0122 - mae: 40.1175 - r2_keras: 0.0397 - root_mean_squared_error: 52.0200 - val_loss: 44.8553 - val_mae: 37.8679 - val_r2_keras: -7.0866e-02 - val_root_mean_squared_error: 43.7195
# Epoch 10/200
# 13519/13519 - 22s - loss: 48.5099 - mae: 36.8526 - r2_keras: 0.1830 - root_mean_squared_error: 48.4899 - val_loss: 39.2197 - val_mae: 32.7612 - val_r2_keras: 0.2438 - val_root_mean_squared_error: 37.1260
# Epoch 11/200
# 13519/13519 - 22s - loss: 46.3792 - mae: 35.0603 - r2_keras: 0.2491 - root_mean_squared_error: 46.3728 - val_loss: 51.5135 - val_mae: 43.2940 - val_r2_keras: -3.8941e-01 - val_root_mean_squared_error: 49.8658
# Epoch 12/200
# 13519/13519 - 22s - loss: 44.0327 - mae: 32.8670 - r2_keras: 0.3161 - root_mean_squared_error: 44.0028 - val_loss: 33.7963 - val_mae: 28.0905 - val_r2_keras: 0.4430 - val_root_mean_squared_error: 31.7122
# Epoch 13/200
# 13519/13519 - 22s - loss: 42.1716 - mae: 31.4393 - r2_keras: 0.3736 - root_mean_squared_error: 42.1109 - val_loss: 28.3279 - val_mae: 22.8802 - val_r2_keras: 0.5917 - val_root_mean_squared_error: 26.7309
# Epoch 14/200
# 13519/13519 - 22s - loss: 40.9775 - mae: 30.0499 - r2_keras: 0.4081 - root_mean_squared_error: 40.9637 - val_loss: 30.9948 - val_mae: 25.1464 - val_r2_keras: 0.4790 - val_root_mean_squared_error: 29.5452
# Epoch 15/200
# 13519/13519 - 22s - loss: 38.5802 - mae: 28.1703 - r2_keras: 0.4797 - root_mean_squared_error: 38.6103 - val_loss: 46.3738 - val_mae: 40.3012 - val_r2_keras: -1.9904e-01 - val_root_mean_squared_error: 45.5089
# Epoch 16/200
# 13519/13519 - 22s - loss: 36.9624 - mae: 26.8736 - r2_keras: 0.5214 - root_mean_squared_error: 36.9486 - val_loss: 29.1961 - val_mae: 23.1343 - val_r2_keras: 0.5753 - val_root_mean_squared_error: 27.7984
# Epoch 17/200
# 13519/13519 - 22s - loss: 36.2911 - mae: 26.3075 - r2_keras: 0.5401 - root_mean_squared_error: 36.2308 - val_loss: 27.9838 - val_mae: 22.6137 - val_r2_keras: 0.6183 - val_root_mean_squared_error: 26.4609
# Epoch 18/200
# 13519/13519 - 22s - loss: 35.2801 - mae: 25.5498 - r2_keras: 0.5637 - root_mean_squared_error: 35.2168 - val_loss: 32.1037 - val_mae: 26.9915 - val_r2_keras: 0.4586 - val_root_mean_squared_error: 31.2085
# Epoch 19/200
# 13519/13519 - 22s - loss: 34.7773 - mae: 25.1040 - r2_keras: 0.5764 - root_mean_squared_error: 34.8195 - val_loss: 37.8298 - val_mae: 32.4902 - val_r2_keras: 0.2370 - val_root_mean_squared_error: 37.0259
# Epoch 20/200
# 13519/13519 - 21s - loss: 33.9203 - mae: 24.3783 - r2_keras: 0.5978 - root_mean_squared_error: 33.8764 - val_loss: 36.1740 - val_mae: 30.8496 - val_r2_keras: 0.2873 - val_root_mean_squared_error: 35.0166
# Epoch 21/200
# 13519/13519 - 22s - loss: 33.1219 - mae: 23.6588 - r2_keras: 0.6165 - root_mean_squared_error: 33.1516 - val_loss: 27.6686 - val_mae: 21.2537 - val_r2_keras: 0.5977 - val_root_mean_squared_error: 26.8598
# Epoch 22/200
# 13519/13519 - 21s - loss: 32.6952 - mae: 23.4205 - r2_keras: 0.6281 - root_mean_squared_error: 32.6727 - val_loss: 43.8741 - val_mae: 39.9305 - val_r2_keras: -2.7464e-01 - val_root_mean_squared_error: 43.4269
# Epoch 23/200
# 13519/13519 - 22s - loss: 31.8596 - mae: 22.8384 - r2_keras: 0.6458 - root_mean_squared_error: 31.8385 - val_loss: 29.0893 - val_mae: 24.4601 - val_r2_keras: 0.5523 - val_root_mean_squared_error: 28.1641
# Epoch 24/200
# 13519/13519 - 22s - loss: 31.6896 - mae: 22.6975 - r2_keras: 0.6495 - root_mean_squared_error: 31.6824 - val_loss: 32.8392 - val_mae: 26.4144 - val_r2_keras: 0.3265 - val_root_mean_squared_error: 31.9187
# Epoch 25/200
# 13519/13519 - 22s - loss: 31.4575 - mae: 22.2741 - r2_keras: 0.6549 - root_mean_squared_error: 31.4295 - val_loss: 28.2741 - val_mae: 22.8544 - val_r2_keras: 0.6097 - val_root_mean_squared_error: 26.8231
# Epoch 26/200
# 13519/13519 - 22s - loss: 30.5785 - mae: 21.6155 - r2_keras: 0.6733 - root_mean_squared_error: 30.5808 - val_loss: 30.0209 - val_mae: 25.3018 - val_r2_keras: 0.5002 - val_root_mean_squared_error: 29.1113
# Epoch 27/200
# 13519/13519 - 22s - loss: 30.3026 - mae: 21.5554 - r2_keras: 0.6815 - root_mean_squared_error: 30.2583 - val_loss: 26.2253 - val_mae: 21.3778 - val_r2_keras: 0.6586 - val_root_mean_squared_error: 24.8513
# Epoch 28/200
# 13519/13519 - 22s - loss: 30.3127 - mae: 21.3237 - r2_keras: 0.6774 - root_mean_squared_error: 30.3420 - val_loss: 29.5689 - val_mae: 21.0075 - val_r2_keras: 0.4428 - val_root_mean_squared_error: 29.3934
# Epoch 29/200
# 13519/13519 - 22s - loss: 29.5785 - mae: 20.8090 - r2_keras: 0.6957 - root_mean_squared_error: 29.6106 - val_loss: 29.0442 - val_mae: 24.1292 - val_r2_keras: 0.5393 - val_root_mean_squared_error: 28.2274
# Epoch 30/200
# 13519/13519 - 22s - loss: 29.2620 - mae: 20.4684 - r2_keras: 0.7039 - root_mean_squared_error: 29.2281 - val_loss: 29.9456 - val_mae: 25.3330 - val_r2_keras: 0.5183 - val_root_mean_squared_error: 29.1263
# Epoch 31/200
# 13519/13519 - 22s - loss: 29.2129 - mae: 20.5249 - r2_keras: 0.7012 - root_mean_squared_error: 29.2733 - val_loss: 27.9648 - val_mae: 23.5696 - val_r2_keras: 0.5851 - val_root_mean_squared_error: 27.2071
# Epoch 32/200
# 13519/13519 - 22s - loss: 28.8449 - mae: 20.1510 - r2_keras: 0.7087 - root_mean_squared_error: 28.8267 - val_loss: 28.4105 - val_mae: 22.2538 - val_r2_keras: 0.5433 - val_root_mean_squared_error: 27.2686
# Epoch 33/200
# 13519/13519 - 22s - loss: 28.3639 - mae: 19.8749 - r2_keras: 0.7206 - root_mean_squared_error: 28.3933 - val_loss: 32.1870 - val_mae: 27.5188 - val_r2_keras: 0.4167 - val_root_mean_squared_error: 31.4326
# Epoch 34/200
# 13519/13519 - 22s - loss: 28.2237 - mae: 19.7792 - r2_keras: 0.7218 - root_mean_squared_error: 28.2170 - val_loss: 25.7968 - val_mae: 20.0994 - val_r2_keras: 0.6629 - val_root_mean_squared_error: 24.6212
# Epoch 35/200
# 13519/13519 - 22s - loss: 27.9613 - mae: 19.5554 - r2_keras: 0.7288 - root_mean_squared_error: 27.9432 - val_loss: 29.9827 - val_mae: 25.7218 - val_r2_keras: 0.4954 - val_root_mean_squared_error: 29.3844
# Epoch 36/200
# 13519/13519 - 22s - loss: 27.6555 - mae: 19.3430 - r2_keras: 0.7330 - root_mean_squared_error: 27.6358 - val_loss: 28.7640 - val_mae: 21.2893 - val_r2_keras: 0.5414 - val_root_mean_squared_error: 27.2627
# Epoch 37/200
# 13519/13519 - 22s - loss: 27.6263 - mae: 19.2653 - r2_keras: 0.7327 - root_mean_squared_error: 27.6286 - val_loss: 25.4708 - val_mae: 20.8980 - val_r2_keras: 0.6458 - val_root_mean_squared_error: 24.4826
# Epoch 38/200
# 13519/13519 - 22s - loss: 27.4141 - mae: 19.1474 - r2_keras: 0.7366 - root_mean_squared_error: 27.4476 - val_loss: 26.6028 - val_mae: 20.9051 - val_r2_keras: 0.6100 - val_root_mean_squared_error: 25.2632
# Epoch 39/200
# 13519/13519 - 22s - loss: 27.1169 - mae: 18.9797 - r2_keras: 0.7419 - root_mean_squared_error: 27.1288 - val_loss: 26.9253 - val_mae: 22.0989 - val_r2_keras: 0.6077 - val_root_mean_squared_error: 25.8195
# Epoch 40/200
# 13519/13519 - 22s - loss: 26.9589 - mae: 18.6163 - r2_keras: 0.7470 - root_mean_squared_error: 26.9733 - val_loss: 33.4300 - val_mae: 27.7579 - val_r2_keras: 0.2203 - val_root_mean_squared_error: 32.4993
# Epoch 41/200
# 13519/13519 - 22s - loss: 26.9572 - mae: 18.7849 - r2_keras: 0.7465 - root_mean_squared_error: 26.9436 - val_loss: 25.8256 - val_mae: 20.5519 - val_r2_keras: 0.6643 - val_root_mean_squared_error: 24.6578
# Epoch 42/200
# 13519/13519 - 22s - loss: 26.4819 - mae: 18.3813 - r2_keras: 0.7545 - root_mean_squared_error: 26.4644 - val_loss: 30.5028 - val_mae: 25.6219 - val_r2_keras: 0.4583 - val_root_mean_squared_error: 29.9826
# Epoch 43/200
# 13519/13519 - 22s - loss: 26.3605 - mae: 18.3548 - r2_keras: 0.7534 - root_mean_squared_error: 26.4253 - val_loss: 28.9847 - val_mae: 23.9474 - val_r2_keras: 0.5422 - val_root_mean_squared_error: 28.1109
# Epoch 44/200
# 13519/13519 - 22s - loss: 26.6165 - mae: 18.3861 - r2_keras: 0.7532 - root_mean_squared_error: 26.5880 - val_loss: 26.5488 - val_mae: 21.5951 - val_r2_keras: 0.6183 - val_root_mean_squared_error: 25.6575
# Epoch 45/200
# 13519/13519 - 22s - loss: 26.0816 - mae: 18.1031 - r2_keras: 0.7617 - root_mean_squared_error: 26.0802 - val_loss: 28.8796 - val_mae: 23.4560 - val_r2_keras: 0.5241 - val_root_mean_squared_error: 27.8725
# Epoch 46/200
# 13519/13519 - 22s - loss: 26.2710 - mae: 18.1899 - r2_keras: 0.7610 - root_mean_squared_error: 26.2476 - val_loss: 26.3034 - val_mae: 19.8312 - val_r2_keras: 0.6315 - val_root_mean_squared_error: 25.2180
# Epoch 47/200
# 13519/13519 - 22s - loss: 25.7432 - mae: 17.8174 - r2_keras: 0.7695 - root_mean_squared_error: 25.7613 - val_loss: 24.1883 - val_mae: 18.6357 - val_r2_keras: 0.7089 - val_root_mean_squared_error: 23.0408
# Epoch 48/200
# 13519/13519 - 22s - loss: 25.7209 - mae: 17.6830 - r2_keras: 0.7702 - root_mean_squared_error: 25.7087 - val_loss: 26.8270 - val_mae: 21.1640 - val_r2_keras: 0.6213 - val_root_mean_squared_error: 25.4496
# Epoch 49/200
# 13519/13519 - 22s - loss: 25.6632 - mae: 17.6375 - r2_keras: 0.7698 - root_mean_squared_error: 25.6409 - val_loss: 31.6652 - val_mae: 26.9927 - val_r2_keras: 0.4301 - val_root_mean_squared_error: 30.9039
# Epoch 50/200
# 13519/13519 - 22s - loss: 25.5349 - mae: 17.5940 - r2_keras: 0.7726 - root_mean_squared_error: 25.5528 - val_loss: 26.0757 - val_mae: 20.0092 - val_r2_keras: 0.6536 - val_root_mean_squared_error: 24.6923
# Epoch 51/200
# 13519/13519 - 22s - loss: 25.4903 - mae: 17.5502 - r2_keras: 0.7742 - root_mean_squared_error: 25.5054 - val_loss: 25.0953 - val_mae: 20.1612 - val_r2_keras: 0.6780 - val_root_mean_squared_error: 24.0447
# Epoch 52/200
# 13519/13519 - 22s - loss: 25.0545 - mae: 17.2275 - r2_keras: 0.7829 - root_mean_squared_error: 25.0382 - val_loss: 28.2617 - val_mae: 22.4015 - val_r2_keras: 0.5436 - val_root_mean_squared_error: 26.9230
# Epoch 53/200
# 13519/13519 - 22s - loss: 25.4965 - mae: 17.4794 - r2_keras: 0.7753 - root_mean_squared_error: 25.4964 - val_loss: 28.0136 - val_mae: 23.2054 - val_r2_keras: 0.5909 - val_root_mean_squared_error: 27.1878
# Epoch 54/200
# 13519/13519 - 22s - loss: 25.2606 - mae: 17.3258 - r2_keras: 0.7767 - root_mean_squared_error: 25.2657 - val_loss: 27.4445 - val_mae: 20.7432 - val_r2_keras: 0.5912 - val_root_mean_squared_error: 26.4148
# Epoch 55/200
# 13519/13519 - 22s - loss: 24.8722 - mae: 17.0949 - r2_keras: 0.7850 - root_mean_squared_error: 24.8637 - val_loss: 25.6419 - val_mae: 19.3897 - val_r2_keras: 0.6619 - val_root_mean_squared_error: 24.6115
# Epoch 56/200
# 13519/13519 - 22s - loss: 25.0244 - mae: 17.2754 - r2_keras: 0.7822 - root_mean_squared_error: 25.0262 - val_loss: 30.1472 - val_mae: 22.5223 - val_r2_keras: 0.4449 - val_root_mean_squared_error: 29.3685
# Epoch 57/200
# 13519/13519 - 22s - loss: 24.6460 - mae: 16.8331 - r2_keras: 0.7882 - root_mean_squared_error: 24.6366 - val_loss: 34.7166 - val_mae: 30.3327 - val_r2_keras: 0.3243 - val_root_mean_squared_error: 34.0147

# %%
# list all data in history
print(history.history.keys())

# summarize history for R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model r^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_r2.png")

# summarize history for RMSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_RMSE.png")

# summarize history for MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_mae.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss RMSE')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_regression_loss.png")

# training metrics

#encoded_data = get_encoded_data(seq_array, False)
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nR^2: {}'.format(scores[2]))

y_pred = model.predict(seq_array,verbose=1, batch_size=200)
y_true = label_array

test_set = pd.DataFrame(y_pred)
test_set.to_csv(output_path+'/submit_train.csv', index = None)
# Out:
# dict_keys(['loss', 'mae', 'r2_keras', 'root_mean_squared_error', 'val_loss', 'val_mae', 'val_r2_keras', 'val_root_mean_squared_error'])
# 14231/14231 [==============================] - 8s 553us/sample - loss: 35.2251 - mae: 29.3645 - r2_keras: 0.3878 - root_mean_squared_error: 34.9675
#
# MAE: 29.36452293395996
#
# R^2: 0.38775312900543213
# 14231/14231 [==============================] - 8s 540us/sample

# %%
test_x = test_df[sequence_cols].values.astype(np.float32)
print(test_x.shape)
#get encoded data first
encoded_data_test = get_encoded_data(test_x, True)
# Convert the dictionary into DataFrame 
encoded_test = pd.DataFrame(encoded_data_test) 
  
# Using DataFrame.insert() to add a column 
encoded_test.insert(0, "id", test_df['id'], True) 
#add column names
encoded_test.columns = encoded_cols
# Out:
# (13096, 25)
# 13096/13096 [==============================] - 0s 7us/sample
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# =================================================================
# Total params: 1,496
# Trainable params: 1,496
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
##################################
# EVALUATE ON TEST DATA
##################################

# We pick the last sequence for each id in the test data
seq_array_test_last = [encoded_test[encoded_test['id']==id][encoded_cols].values[-sequence_length:] 
                       for id in encoded_test['id'].unique() if len(encoded_test[encoded_test['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
print("seq_array_test_last")
print(seq_array_test_last.shape)

# Similarly, we pick the labels
#print("y_mask")
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
print(label_array_test_last.shape)


# if best iteration's model was saved then load and use it
if os.path.isfile(model_path):

    # restore weights
    estimator = load_model(model_path,custom_objects={'r2_keras': r2_keras,'root_mean_squared_error': root_mean_squared_error, 'TCN': TCN})

    
    # test metrics
    scores_test = estimator.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
    print('\nMAE: {}'.format(scores_test[1]))
    print('\nR^2: {}'.format(scores_test[2]))
    print('\nRMSE: {}'.format(scores_test[3]))

    y_pred_test = estimator.predict(seq_array_test_last)
    y_true_test = label_array_test_last

    test_set = pd.DataFrame(y_pred_test)
    test_set.to_csv(output_path+'/submit_test.csv', index = None)

    #######################
    # Plot in blue color the predicted data and in orange color the
    # actual data to verify visually the accuracy of the model.
        
    x = np.arange(len(y_pred_test))
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots(figsize=(100, 50))
    rects1 = ax.bar(x - width/2, y_pred_test.flatten().round(), width, label='predicted')
    rects2 = ax.bar(x + width/2, y_true_test.flatten(), width, label='true')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('value')
    ax.set_title('prediction')
    ax.set_xticks(x)
    ax.legend()


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)

    plt.show()
    fig.savefig(output_path+"/model_verify_bar.png")
# Out:
# seq_array_test_last
# (88, 64, 9)
# (88, 1)
# 88/88 - 1s - loss: 20.6346 - mae: 15.0336 - r2_keras: 0.7440 - root_mean_squared_error: 20.4235
#
# MAE: 15.0336332321167
#
# R^2: 0.7440250515937805
#
# RMSE: 20.423473358154297
