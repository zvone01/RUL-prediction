# %%
#include google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# %tensorflow_version 2.x
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Dropout, Embedding
import tensorflow.keras.backend as K
import tensorflow.keras as keras
from sklearn import preprocessing

import random
# Out:
# TensorFlow 2.x selected.

# %%
# define paths
output_path = '/content/drive/My Drive/Fax/Master Theses/output-autoencoder'
model_path = output_path+'/model.h5'
encoder_path = output_path+'/encoder.h5'
data_path = '/content/drive/My Drive/Fax/Master Theses/Data/CMAPSSData/'

# %%
##################################
# Data Ingestion
##################################

# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv(data_path+'train_FD001.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# %%
#######
# TRAIN set
#######
# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# %%
# pick the feature columns 
sensor_cols = ['s' + str(i) for i in range(1,22)]
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)

train_x = train_df[sequence_cols].values.astype(np.float32)
print(train_x.shape)
# Out:
# (20631, 25)

# %%
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
##################################
# Autoencoder
##################################
n_samples = train_x.shape[0]
nb_features = train_x.shape[1]

input_d = Input(shape=(nb_features,))
encoded = Dense(32, activation='relu')(input_d)
encoded = Dense(16, activation='relu')(encoded)
encoded = Dense(8, activation='relu')(encoded)

decoded = Dense(16, activation='relu')(encoded)
decoded = Dense(32, activation='relu')(decoded)
decoded = Dense(nb_features, activation='sigmoid')(decoded)

autoencoder = Model(input_d, decoded)
autoencoder.compile('adam', 'mae')

autoencoder.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])
autoencoder.summary()
history = autoencoder.fit(train_x, train_x,
                epochs=200,
                verbose=2,
                batch_size=256,
                shuffle=True,
                validation_data=(train_x, train_x),
                callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                      keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)])
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                832
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_26 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_27 (Dense)             (None, 16)                144
# _________________________________________________________________
# dense_28 (Dense)             (None, 32)                544
# _________________________________________________________________
# dense_29 (Dense)             (None, 25)                825
# =================================================================
# Total params: 3,009
# Trainable params: 3,009
# Non-trainable params: 0
# _________________________________________________________________
# Train on 20631 samples, validate on 20631 samples
# Epoch 1/200
# 20631/20631 - 2s - loss: 0.0530 - mae: 0.1794 - r2_keras: 0.3167 - root_mean_squared_error: 0.2190 - val_loss: 0.0163 - val_mae: 0.0928 - val_r2_keras: 0.7896 - val_root_mean_squared_error: 0.1273
# Epoch 2/200
# 20631/20631 - 0s - loss: 0.0127 - mae: 0.0750 - r2_keras: 0.8364 - root_mean_squared_error: 0.1119 - val_loss: 0.0090 - val_mae: 0.0590 - val_r2_keras: 0.8846 - val_root_mean_squared_error: 0.0942
# Epoch 3/200
# 20631/20631 - 0s - loss: 0.0083 - mae: 0.0554 - r2_keras: 0.8925 - root_mean_squared_error: 0.0911 - val_loss: 0.0080 - val_mae: 0.0534 - val_r2_keras: 0.8974 - val_root_mean_squared_error: 0.0889
# Epoch 4/200
# 20631/20631 - 0s - loss: 0.0079 - mae: 0.0532 - r2_keras: 0.8979 - root_mean_squared_error: 0.0888 - val_loss: 0.0077 - val_mae: 0.0524 - val_r2_keras: 0.9002 - val_root_mean_squared_error: 0.0877
# Epoch 5/200
# 20631/20631 - 0s - loss: 0.0077 - mae: 0.0525 - r2_keras: 0.9001 - root_mean_squared_error: 0.0878 - val_loss: 0.0076 - val_mae: 0.0520 - val_r2_keras: 0.9021 - val_root_mean_squared_error: 0.0868
# Epoch 6/200
# 20631/20631 - 0s - loss: 0.0075 - mae: 0.0520 - r2_keras: 0.9027 - root_mean_squared_error: 0.0867 - val_loss: 0.0075 - val_mae: 0.0520 - val_r2_keras: 0.9038 - val_root_mean_squared_error: 0.0861
# Epoch 7/200
# 20631/20631 - 0s - loss: 0.0072 - mae: 0.0513 - r2_keras: 0.9065 - root_mean_squared_error: 0.0850 - val_loss: 0.0071 - val_mae: 0.0512 - val_r2_keras: 0.9079 - val_root_mean_squared_error: 0.0842
# Epoch 8/200
# 20631/20631 - 0s - loss: 0.0068 - mae: 0.0503 - r2_keras: 0.9121 - root_mean_squared_error: 0.0824 - val_loss: 0.0066 - val_mae: 0.0498 - val_r2_keras: 0.9151 - val_root_mean_squared_error: 0.0808
# Epoch 9/200
# 20631/20631 - 0s - loss: 0.0062 - mae: 0.0491 - r2_keras: 0.9195 - root_mean_squared_error: 0.0789 - val_loss: 0.0059 - val_mae: 0.0484 - val_r2_keras: 0.9233 - val_root_mean_squared_error: 0.0768
# Epoch 10/200
# 20631/20631 - 0s - loss: 0.0057 - mae: 0.0475 - r2_keras: 0.9260 - root_mean_squared_error: 0.0756 - val_loss: 0.0056 - val_mae: 0.0469 - val_r2_keras: 0.9279 - val_root_mean_squared_error: 0.0745
# Epoch 11/200
# 20631/20631 - 0s - loss: 0.0054 - mae: 0.0463 - r2_keras: 0.9301 - root_mean_squared_error: 0.0735 - val_loss: 0.0053 - val_mae: 0.0462 - val_r2_keras: 0.9313 - val_root_mean_squared_error: 0.0727
# Epoch 12/200
# 20631/20631 - 0s - loss: 0.0052 - mae: 0.0455 - r2_keras: 0.9328 - root_mean_squared_error: 0.0720 - val_loss: 0.0051 - val_mae: 0.0449 - val_r2_keras: 0.9344 - val_root_mean_squared_error: 0.0710
# Epoch 13/200
# 20631/20631 - 0s - loss: 0.0050 - mae: 0.0448 - r2_keras: 0.9350 - root_mean_squared_error: 0.0709 - val_loss: 0.0050 - val_mae: 0.0448 - val_r2_keras: 0.9357 - val_root_mean_squared_error: 0.0703
# Epoch 14/200
# 20631/20631 - 0s - loss: 0.0049 - mae: 0.0442 - r2_keras: 0.9368 - root_mean_squared_error: 0.0699 - val_loss: 0.0048 - val_mae: 0.0439 - val_r2_keras: 0.9381 - val_root_mean_squared_error: 0.0690
# Epoch 15/200
# 20631/20631 - 0s - loss: 0.0048 - mae: 0.0436 - r2_keras: 0.9385 - root_mean_squared_error: 0.0690 - val_loss: 0.0047 - val_mae: 0.0435 - val_r2_keras: 0.9390 - val_root_mean_squared_error: 0.0684
# Epoch 16/200
# 20631/20631 - 0s - loss: 0.0046 - mae: 0.0431 - r2_keras: 0.9400 - root_mean_squared_error: 0.0681 - val_loss: 0.0047 - val_mae: 0.0432 - val_r2_keras: 0.9399 - val_root_mean_squared_error: 0.0680
# Epoch 17/200
# 20631/20631 - 0s - loss: 0.0045 - mae: 0.0424 - r2_keras: 0.9417 - root_mean_squared_error: 0.0671 - val_loss: 0.0045 - val_mae: 0.0421 - val_r2_keras: 0.9424 - val_root_mean_squared_error: 0.0665
# Epoch 18/200
# 20631/20631 - 0s - loss: 0.0044 - mae: 0.0418 - r2_keras: 0.9434 - root_mean_squared_error: 0.0661 - val_loss: 0.0042 - val_mae: 0.0411 - val_r2_keras: 0.9452 - val_root_mean_squared_error: 0.0649
# Epoch 19/200
# 20631/20631 - 0s - loss: 0.0042 - mae: 0.0411 - r2_keras: 0.9455 - root_mean_squared_error: 0.0649 - val_loss: 0.0042 - val_mae: 0.0411 - val_r2_keras: 0.9455 - val_root_mean_squared_error: 0.0647
# Epoch 20/200
# 20631/20631 - 0s - loss: 0.0040 - mae: 0.0402 - r2_keras: 0.9478 - root_mean_squared_error: 0.0635 - val_loss: 0.0039 - val_mae: 0.0394 - val_r2_keras: 0.9497 - val_root_mean_squared_error: 0.0622
# Epoch 21/200
# 20631/20631 - 0s - loss: 0.0038 - mae: 0.0388 - r2_keras: 0.9512 - root_mean_squared_error: 0.0614 - val_loss: 0.0036 - val_mae: 0.0383 - val_r2_keras: 0.9531 - val_root_mean_squared_error: 0.0600
# Epoch 22/200
# 20631/20631 - 0s - loss: 0.0036 - mae: 0.0378 - r2_keras: 0.9537 - root_mean_squared_error: 0.0598 - val_loss: 0.0036 - val_mae: 0.0380 - val_r2_keras: 0.9534 - val_root_mean_squared_error: 0.0599
# Epoch 23/200
# 20631/20631 - 0s - loss: 0.0035 - mae: 0.0372 - r2_keras: 0.9551 - root_mean_squared_error: 0.0589 - val_loss: 0.0034 - val_mae: 0.0369 - val_r2_keras: 0.9558 - val_root_mean_squared_error: 0.0583
# Epoch 24/200
# 20631/20631 - 0s - loss: 0.0034 - mae: 0.0368 - r2_keras: 0.9561 - root_mean_squared_error: 0.0582 - val_loss: 0.0033 - val_mae: 0.0361 - val_r2_keras: 0.9573 - val_root_mean_squared_error: 0.0573
# Epoch 25/200
# 20631/20631 - 0s - loss: 0.0033 - mae: 0.0364 - r2_keras: 0.9569 - root_mean_squared_error: 0.0577 - val_loss: 0.0033 - val_mae: 0.0360 - val_r2_keras: 0.9578 - val_root_mean_squared_error: 0.0570
# Epoch 26/200
# 20631/20631 - 0s - loss: 0.0033 - mae: 0.0361 - r2_keras: 0.9576 - root_mean_squared_error: 0.0572 - val_loss: 0.0032 - val_mae: 0.0353 - val_r2_keras: 0.9592 - val_root_mean_squared_error: 0.0561
# Epoch 27/200
# 20631/20631 - 0s - loss: 0.0032 - mae: 0.0359 - r2_keras: 0.9581 - root_mean_squared_error: 0.0569 - val_loss: 0.0032 - val_mae: 0.0356 - val_r2_keras: 0.9586 - val_root_mean_squared_error: 0.0564
# Epoch 28/200
# 20631/20631 - 0s - loss: 0.0032 - mae: 0.0356 - r2_keras: 0.9587 - root_mean_squared_error: 0.0565 - val_loss: 0.0032 - val_mae: 0.0359 - val_r2_keras: 0.9584 - val_root_mean_squared_error: 0.0566
# Epoch 29/200
# 20631/20631 - 0s - loss: 0.0032 - mae: 0.0354 - r2_keras: 0.9590 - root_mean_squared_error: 0.0563 - val_loss: 0.0031 - val_mae: 0.0354 - val_r2_keras: 0.9595 - val_root_mean_squared_error: 0.0558
# Epoch 30/200
# 20631/20631 - 0s - loss: 0.0031 - mae: 0.0352 - r2_keras: 0.9596 - root_mean_squared_error: 0.0559 - val_loss: 0.0032 - val_mae: 0.0355 - val_r2_keras: 0.9587 - val_root_mean_squared_error: 0.0564
# Epoch 31/200
# 20631/20631 - 0s - loss: 0.0031 - mae: 0.0351 - r2_keras: 0.9599 - root_mean_squared_error: 0.0556 - val_loss: 0.0033 - val_mae: 0.0359 - val_r2_keras: 0.9579 - val_root_mean_squared_error: 0.0569
# Epoch 32/200
# 20631/20631 - 0s - loss: 0.0031 - mae: 0.0349 - r2_keras: 0.9603 - root_mean_squared_error: 0.0554 - val_loss: 0.0030 - val_mae: 0.0343 - val_r2_keras: 0.9615 - val_root_mean_squared_error: 0.0544
# Epoch 33/200
# 20631/20631 - 0s - loss: 0.0030 - mae: 0.0346 - r2_keras: 0.9608 - root_mean_squared_error: 0.0550 - val_loss: 0.0031 - val_mae: 0.0350 - val_r2_keras: 0.9601 - val_root_mean_squared_error: 0.0554
# Epoch 34/200
# 20631/20631 - 0s - loss: 0.0030 - mae: 0.0345 - r2_keras: 0.9611 - root_mean_squared_error: 0.0548 - val_loss: 0.0030 - val_mae: 0.0342 - val_r2_keras: 0.9617 - val_root_mean_squared_error: 0.0543
# Epoch 35/200
# 20631/20631 - 0s - loss: 0.0030 - mae: 0.0344 - r2_keras: 0.9614 - root_mean_squared_error: 0.0546 - val_loss: 0.0029 - val_mae: 0.0340 - val_r2_keras: 0.9620 - val_root_mean_squared_error: 0.0541
# Epoch 36/200
# 20631/20631 - 0s - loss: 0.0030 - mae: 0.0342 - r2_keras: 0.9617 - root_mean_squared_error: 0.0544 - val_loss: 0.0029 - val_mae: 0.0338 - val_r2_keras: 0.9628 - val_root_mean_squared_error: 0.0536
# Epoch 37/200
# 20631/20631 - 0s - loss: 0.0029 - mae: 0.0342 - r2_keras: 0.9620 - root_mean_squared_error: 0.0542 - val_loss: 0.0029 - val_mae: 0.0337 - val_r2_keras: 0.9627 - val_root_mean_squared_error: 0.0536
# Epoch 38/200
# 20631/20631 - 0s - loss: 0.0029 - mae: 0.0340 - r2_keras: 0.9622 - root_mean_squared_error: 0.0541 - val_loss: 0.0029 - val_mae: 0.0336 - val_r2_keras: 0.9628 - val_root_mean_squared_error: 0.0536
# Epoch 39/200
# 20631/20631 - 0s - loss: 0.0029 - mae: 0.0339 - r2_keras: 0.9624 - root_mean_squared_error: 0.0539 - val_loss: 0.0029 - val_mae: 0.0340 - val_r2_keras: 0.9629 - val_root_mean_squared_error: 0.0535
# Epoch 40/200
# 20631/20631 - 0s - loss: 0.0029 - mae: 0.0339 - r2_keras: 0.9626 - root_mean_squared_error: 0.0538 - val_loss: 0.0029 - val_mae: 0.0337 - val_r2_keras: 0.9631 - val_root_mean_squared_error: 0.0533
# Epoch 41/200
# 20631/20631 - 0s - loss: 0.0029 - mae: 0.0338 - r2_keras: 0.9627 - root_mean_squared_error: 0.0537 - val_loss: 0.0028 - val_mae: 0.0338 - val_r2_keras: 0.9631 - val_root_mean_squared_error: 0.0533
# Epoch 42/200
# 20631/20631 - 0s - loss: 0.0029 - mae: 0.0337 - r2_keras: 0.9629 - root_mean_squared_error: 0.0535 - val_loss: 0.0028 - val_mae: 0.0332 - val_r2_keras: 0.9636 - val_root_mean_squared_error: 0.0529
# Epoch 43/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0336 - r2_keras: 0.9632 - root_mean_squared_error: 0.0533 - val_loss: 0.0028 - val_mae: 0.0338 - val_r2_keras: 0.9633 - val_root_mean_squared_error: 0.0531
# Epoch 44/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0335 - r2_keras: 0.9633 - root_mean_squared_error: 0.0532 - val_loss: 0.0028 - val_mae: 0.0332 - val_r2_keras: 0.9638 - val_root_mean_squared_error: 0.0528
# Epoch 45/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0334 - r2_keras: 0.9634 - root_mean_squared_error: 0.0532 - val_loss: 0.0030 - val_mae: 0.0345 - val_r2_keras: 0.9617 - val_root_mean_squared_error: 0.0544
# Epoch 46/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0333 - r2_keras: 0.9636 - root_mean_squared_error: 0.0530 - val_loss: 0.0029 - val_mae: 0.0339 - val_r2_keras: 0.9626 - val_root_mean_squared_error: 0.0537
# Epoch 47/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0333 - r2_keras: 0.9638 - root_mean_squared_error: 0.0529 - val_loss: 0.0028 - val_mae: 0.0330 - val_r2_keras: 0.9637 - val_root_mean_squared_error: 0.0528
# Epoch 48/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0331 - r2_keras: 0.9640 - root_mean_squared_error: 0.0527 - val_loss: 0.0028 - val_mae: 0.0334 - val_r2_keras: 0.9640 - val_root_mean_squared_error: 0.0526
# Epoch 49/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0332 - r2_keras: 0.9640 - root_mean_squared_error: 0.0528 - val_loss: 0.0027 - val_mae: 0.0325 - val_r2_keras: 0.9649 - val_root_mean_squared_error: 0.0520
# Epoch 50/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0330 - r2_keras: 0.9642 - root_mean_squared_error: 0.0526 - val_loss: 0.0027 - val_mae: 0.0329 - val_r2_keras: 0.9647 - val_root_mean_squared_error: 0.0521
# Epoch 51/200
# 20631/20631 - 0s - loss: 0.0028 - mae: 0.0330 - r2_keras: 0.9643 - root_mean_squared_error: 0.0525 - val_loss: 0.0029 - val_mae: 0.0339 - val_r2_keras: 0.9624 - val_root_mean_squared_error: 0.0538
# Epoch 52/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0329 - r2_keras: 0.9646 - root_mean_squared_error: 0.0523 - val_loss: 0.0028 - val_mae: 0.0332 - val_r2_keras: 0.9642 - val_root_mean_squared_error: 0.0525
# Epoch 53/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0328 - r2_keras: 0.9645 - root_mean_squared_error: 0.0523 - val_loss: 0.0028 - val_mae: 0.0334 - val_r2_keras: 0.9641 - val_root_mean_squared_error: 0.0526
# Epoch 54/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0327 - r2_keras: 0.9646 - root_mean_squared_error: 0.0523 - val_loss: 0.0027 - val_mae: 0.0325 - val_r2_keras: 0.9649 - val_root_mean_squared_error: 0.0520
# Epoch 55/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0327 - r2_keras: 0.9649 - root_mean_squared_error: 0.0521 - val_loss: 0.0027 - val_mae: 0.0324 - val_r2_keras: 0.9656 - val_root_mean_squared_error: 0.0515
# Epoch 56/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0326 - r2_keras: 0.9650 - root_mean_squared_error: 0.0520 - val_loss: 0.0027 - val_mae: 0.0327 - val_r2_keras: 0.9652 - val_root_mean_squared_error: 0.0518
# Epoch 57/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0325 - r2_keras: 0.9652 - root_mean_squared_error: 0.0519 - val_loss: 0.0027 - val_mae: 0.0328 - val_r2_keras: 0.9650 - val_root_mean_squared_error: 0.0519
# Epoch 58/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0324 - r2_keras: 0.9655 - root_mean_squared_error: 0.0517 - val_loss: 0.0027 - val_mae: 0.0324 - val_r2_keras: 0.9647 - val_root_mean_squared_error: 0.0522
# Epoch 59/200
# 20631/20631 - 0s - loss: 0.0027 - mae: 0.0323 - r2_keras: 0.9655 - root_mean_squared_error: 0.0516 - val_loss: 0.0027 - val_mae: 0.0323 - val_r2_keras: 0.9647 - val_root_mean_squared_error: 0.0522
# Epoch 60/200
# 20631/20631 - 0s - loss: 0.0026 - mae: 0.0321 - r2_keras: 0.9658 - root_mean_squared_error: 0.0514 - val_loss: 0.0026 - val_mae: 0.0313 - val_r2_keras: 0.9667 - val_root_mean_squared_error: 0.0507
# Epoch 61/200
# 20631/20631 - 0s - loss: 0.0026 - mae: 0.0321 - r2_keras: 0.9660 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_mae: 0.0321 - val_r2_keras: 0.9656 - val_root_mean_squared_error: 0.0515
# Epoch 62/200
# 20631/20631 - 0s - loss: 0.0026 - mae: 0.0319 - r2_keras: 0.9662 - root_mean_squared_error: 0.0511 - val_loss: 0.0026 - val_mae: 0.0317 - val_r2_keras: 0.9664 - val_root_mean_squared_error: 0.0509
# Epoch 63/200
# 20631/20631 - 0s - loss: 0.0026 - mae: 0.0317 - r2_keras: 0.9665 - root_mean_squared_error: 0.0509 - val_loss: 0.0025 - val_mae: 0.0312 - val_r2_keras: 0.9674 - val_root_mean_squared_error: 0.0502
# Epoch 64/200
# 20631/20631 - 0s - loss: 0.0026 - mae: 0.0316 - r2_keras: 0.9668 - root_mean_squared_error: 0.0507 - val_loss: 0.0026 - val_mae: 0.0320 - val_r2_keras: 0.9667 - val_root_mean_squared_error: 0.0507
# Epoch 65/200
# 20631/20631 - 0s - loss: 0.0026 - mae: 0.0314 - r2_keras: 0.9670 - root_mean_squared_error: 0.0505 - val_loss: 0.0025 - val_mae: 0.0306 - val_r2_keras: 0.9678 - val_root_mean_squared_error: 0.0498
# Epoch 66/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0313 - r2_keras: 0.9672 - root_mean_squared_error: 0.0503 - val_loss: 0.0025 - val_mae: 0.0313 - val_r2_keras: 0.9670 - val_root_mean_squared_error: 0.0505
# Epoch 67/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0311 - r2_keras: 0.9675 - root_mean_squared_error: 0.0501 - val_loss: 0.0024 - val_mae: 0.0303 - val_r2_keras: 0.9685 - val_root_mean_squared_error: 0.0493
# Epoch 68/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0310 - r2_keras: 0.9676 - root_mean_squared_error: 0.0500 - val_loss: 0.0025 - val_mae: 0.0313 - val_r2_keras: 0.9671 - val_root_mean_squared_error: 0.0503
# Epoch 69/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0309 - r2_keras: 0.9678 - root_mean_squared_error: 0.0499 - val_loss: 0.0025 - val_mae: 0.0316 - val_r2_keras: 0.9672 - val_root_mean_squared_error: 0.0503
# Epoch 70/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0308 - r2_keras: 0.9679 - root_mean_squared_error: 0.0498 - val_loss: 0.0024 - val_mae: 0.0302 - val_r2_keras: 0.9685 - val_root_mean_squared_error: 0.0493
# Epoch 71/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0307 - r2_keras: 0.9680 - root_mean_squared_error: 0.0497 - val_loss: 0.0024 - val_mae: 0.0304 - val_r2_keras: 0.9686 - val_root_mean_squared_error: 0.0492
# Epoch 72/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0307 - r2_keras: 0.9681 - root_mean_squared_error: 0.0497 - val_loss: 0.0025 - val_mae: 0.0309 - val_r2_keras: 0.9678 - val_root_mean_squared_error: 0.0498
# Epoch 73/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0306 - r2_keras: 0.9682 - root_mean_squared_error: 0.0496 - val_loss: 0.0024 - val_mae: 0.0304 - val_r2_keras: 0.9685 - val_root_mean_squared_error: 0.0493
# Epoch 74/200
# 20631/20631 - 0s - loss: 0.0025 - mae: 0.0305 - r2_keras: 0.9683 - root_mean_squared_error: 0.0495 - val_loss: 0.0025 - val_mae: 0.0308 - val_r2_keras: 0.9678 - val_root_mean_squared_error: 0.0498
# Epoch 75/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0304 - r2_keras: 0.9684 - root_mean_squared_error: 0.0494 - val_loss: 0.0025 - val_mae: 0.0307 - val_r2_keras: 0.9679 - val_root_mean_squared_error: 0.0498
# Epoch 76/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0305 - r2_keras: 0.9683 - root_mean_squared_error: 0.0495 - val_loss: 0.0025 - val_mae: 0.0302 - val_r2_keras: 0.9682 - val_root_mean_squared_error: 0.0496
# Epoch 77/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0304 - r2_keras: 0.9685 - root_mean_squared_error: 0.0493 - val_loss: 0.0025 - val_mae: 0.0309 - val_r2_keras: 0.9681 - val_root_mean_squared_error: 0.0496
# Epoch 78/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0304 - r2_keras: 0.9685 - root_mean_squared_error: 0.0493 - val_loss: 0.0024 - val_mae: 0.0300 - val_r2_keras: 0.9691 - val_root_mean_squared_error: 0.0488
# Epoch 79/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0303 - r2_keras: 0.9686 - root_mean_squared_error: 0.0493 - val_loss: 0.0024 - val_mae: 0.0307 - val_r2_keras: 0.9686 - val_root_mean_squared_error: 0.0492
# Epoch 80/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0303 - r2_keras: 0.9687 - root_mean_squared_error: 0.0492 - val_loss: 0.0024 - val_mae: 0.0301 - val_r2_keras: 0.9692 - val_root_mean_squared_error: 0.0487
# Epoch 81/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0303 - r2_keras: 0.9687 - root_mean_squared_error: 0.0492 - val_loss: 0.0024 - val_mae: 0.0304 - val_r2_keras: 0.9690 - val_root_mean_squared_error: 0.0489
# Epoch 82/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0303 - r2_keras: 0.9688 - root_mean_squared_error: 0.0491 - val_loss: 0.0025 - val_mae: 0.0308 - val_r2_keras: 0.9677 - val_root_mean_squared_error: 0.0499
# Epoch 83/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0302 - r2_keras: 0.9688 - root_mean_squared_error: 0.0491 - val_loss: 0.0024 - val_mae: 0.0300 - val_r2_keras: 0.9690 - val_root_mean_squared_error: 0.0489
# Epoch 84/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0302 - r2_keras: 0.9689 - root_mean_squared_error: 0.0491 - val_loss: 0.0024 - val_mae: 0.0302 - val_r2_keras: 0.9690 - val_root_mean_squared_error: 0.0489
# Epoch 85/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0302 - r2_keras: 0.9689 - root_mean_squared_error: 0.0490 - val_loss: 0.0024 - val_mae: 0.0303 - val_r2_keras: 0.9691 - val_root_mean_squared_error: 0.0489
# Epoch 86/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0301 - r2_keras: 0.9690 - root_mean_squared_error: 0.0490 - val_loss: 0.0026 - val_mae: 0.0314 - val_r2_keras: 0.9669 - val_root_mean_squared_error: 0.0505
# Epoch 87/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0301 - r2_keras: 0.9690 - root_mean_squared_error: 0.0489 - val_loss: 0.0023 - val_mae: 0.0295 - val_r2_keras: 0.9698 - val_root_mean_squared_error: 0.0483
# Epoch 88/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0300 - r2_keras: 0.9692 - root_mean_squared_error: 0.0488 - val_loss: 0.0024 - val_mae: 0.0300 - val_r2_keras: 0.9690 - val_root_mean_squared_error: 0.0489
# Epoch 89/200
# 20631/20631 - 0s - loss: 0.0024 - mae: 0.0299 - r2_keras: 0.9694 - root_mean_squared_error: 0.0486 - val_loss: 0.0024 - val_mae: 0.0307 - val_r2_keras: 0.9692 - val_root_mean_squared_error: 0.0488
# Epoch 90/200
# 20631/20631 - 0s - loss: 0.0023 - mae: 0.0297 - r2_keras: 0.9699 - root_mean_squared_error: 0.0482 - val_loss: 0.0023 - val_mae: 0.0296 - val_r2_keras: 0.9702 - val_root_mean_squared_error: 0.0480
# Epoch 91/200
# 20631/20631 - 0s - loss: 0.0023 - mae: 0.0295 - r2_keras: 0.9703 - root_mean_squared_error: 0.0479 - val_loss: 0.0024 - val_mae: 0.0308 - val_r2_keras: 0.9690 - val_root_mean_squared_error: 0.0489
# Epoch 92/200
# 20631/20631 - 0s - loss: 0.0023 - mae: 0.0293 - r2_keras: 0.9707 - root_mean_squared_error: 0.0476 - val_loss: 0.0023 - val_mae: 0.0290 - val_r2_keras: 0.9705 - val_root_mean_squared_error: 0.0477
# Epoch 93/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0291 - r2_keras: 0.9709 - root_mean_squared_error: 0.0474 - val_loss: 0.0023 - val_mae: 0.0294 - val_r2_keras: 0.9706 - val_root_mean_squared_error: 0.0477
# Epoch 94/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0291 - r2_keras: 0.9711 - root_mean_squared_error: 0.0472 - val_loss: 0.0022 - val_mae: 0.0290 - val_r2_keras: 0.9714 - val_root_mean_squared_error: 0.0470
# Epoch 95/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0289 - r2_keras: 0.9713 - root_mean_squared_error: 0.0471 - val_loss: 0.0022 - val_mae: 0.0290 - val_r2_keras: 0.9713 - val_root_mean_squared_error: 0.0470
# Epoch 96/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0288 - r2_keras: 0.9714 - root_mean_squared_error: 0.0470 - val_loss: 0.0021 - val_mae: 0.0282 - val_r2_keras: 0.9723 - val_root_mean_squared_error: 0.0462
# Epoch 97/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0288 - r2_keras: 0.9715 - root_mean_squared_error: 0.0469 - val_loss: 0.0022 - val_mae: 0.0295 - val_r2_keras: 0.9709 - val_root_mean_squared_error: 0.0474
# Epoch 98/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0287 - r2_keras: 0.9715 - root_mean_squared_error: 0.0469 - val_loss: 0.0021 - val_mae: 0.0283 - val_r2_keras: 0.9721 - val_root_mean_squared_error: 0.0464
# Epoch 99/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0287 - r2_keras: 0.9717 - root_mean_squared_error: 0.0467 - val_loss: 0.0022 - val_mae: 0.0286 - val_r2_keras: 0.9716 - val_root_mean_squared_error: 0.0468
# Epoch 100/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0287 - r2_keras: 0.9717 - root_mean_squared_error: 0.0468 - val_loss: 0.0022 - val_mae: 0.0286 - val_r2_keras: 0.9717 - val_root_mean_squared_error: 0.0467
# Epoch 101/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0286 - r2_keras: 0.9718 - root_mean_squared_error: 0.0467 - val_loss: 0.0022 - val_mae: 0.0291 - val_r2_keras: 0.9718 - val_root_mean_squared_error: 0.0466
# Epoch 102/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0286 - r2_keras: 0.9718 - root_mean_squared_error: 0.0467 - val_loss: 0.0021 - val_mae: 0.0280 - val_r2_keras: 0.9724 - val_root_mean_squared_error: 0.0462
# Epoch 103/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0285 - r2_keras: 0.9719 - root_mean_squared_error: 0.0466 - val_loss: 0.0021 - val_mae: 0.0281 - val_r2_keras: 0.9722 - val_root_mean_squared_error: 0.0463
# Epoch 104/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0285 - r2_keras: 0.9720 - root_mean_squared_error: 0.0465 - val_loss: 0.0022 - val_mae: 0.0285 - val_r2_keras: 0.9718 - val_root_mean_squared_error: 0.0466
# Epoch 105/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0285 - r2_keras: 0.9720 - root_mean_squared_error: 0.0465 - val_loss: 0.0022 - val_mae: 0.0288 - val_r2_keras: 0.9721 - val_root_mean_squared_error: 0.0464
# Epoch 106/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0285 - r2_keras: 0.9721 - root_mean_squared_error: 0.0464 - val_loss: 0.0021 - val_mae: 0.0275 - val_r2_keras: 0.9730 - val_root_mean_squared_error: 0.0456
# Epoch 107/200
# 20631/20631 - 0s - loss: 0.0022 - mae: 0.0284 - r2_keras: 0.9721 - root_mean_squared_error: 0.0464 - val_loss: 0.0022 - val_mae: 0.0284 - val_r2_keras: 0.9719 - val_root_mean_squared_error: 0.0465
# Epoch 108/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0284 - r2_keras: 0.9722 - root_mean_squared_error: 0.0463 - val_loss: 0.0021 - val_mae: 0.0282 - val_r2_keras: 0.9727 - val_root_mean_squared_error: 0.0459
# Epoch 109/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0284 - r2_keras: 0.9723 - root_mean_squared_error: 0.0463 - val_loss: 0.0021 - val_mae: 0.0286 - val_r2_keras: 0.9725 - val_root_mean_squared_error: 0.0461
# Epoch 110/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0283 - r2_keras: 0.9723 - root_mean_squared_error: 0.0463 - val_loss: 0.0022 - val_mae: 0.0288 - val_r2_keras: 0.9718 - val_root_mean_squared_error: 0.0466
# Epoch 111/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0283 - r2_keras: 0.9724 - root_mean_squared_error: 0.0462 - val_loss: 0.0021 - val_mae: 0.0276 - val_r2_keras: 0.9731 - val_root_mean_squared_error: 0.0456
# Epoch 112/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0283 - r2_keras: 0.9724 - root_mean_squared_error: 0.0462 - val_loss: 0.0021 - val_mae: 0.0279 - val_r2_keras: 0.9724 - val_root_mean_squared_error: 0.0461
# Epoch 113/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0283 - r2_keras: 0.9724 - root_mean_squared_error: 0.0462 - val_loss: 0.0021 - val_mae: 0.0277 - val_r2_keras: 0.9732 - val_root_mean_squared_error: 0.0455
# Epoch 114/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9724 - root_mean_squared_error: 0.0461 - val_loss: 0.0021 - val_mae: 0.0283 - val_r2_keras: 0.9726 - val_root_mean_squared_error: 0.0459
# Epoch 115/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9725 - root_mean_squared_error: 0.0461 - val_loss: 0.0022 - val_mae: 0.0285 - val_r2_keras: 0.9713 - val_root_mean_squared_error: 0.0471
# Epoch 116/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9726 - root_mean_squared_error: 0.0460 - val_loss: 0.0021 - val_mae: 0.0280 - val_r2_keras: 0.9731 - val_root_mean_squared_error: 0.0455
# Epoch 117/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9726 - root_mean_squared_error: 0.0460 - val_loss: 0.0021 - val_mae: 0.0285 - val_r2_keras: 0.9724 - val_root_mean_squared_error: 0.0462
# Epoch 118/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9726 - root_mean_squared_error: 0.0460 - val_loss: 0.0021 - val_mae: 0.0280 - val_r2_keras: 0.9725 - val_root_mean_squared_error: 0.0461
# Epoch 119/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9727 - root_mean_squared_error: 0.0460 - val_loss: 0.0021 - val_mae: 0.0280 - val_r2_keras: 0.9728 - val_root_mean_squared_error: 0.0458
# Epoch 120/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0282 - r2_keras: 0.9727 - root_mean_squared_error: 0.0460 - val_loss: 0.0021 - val_mae: 0.0289 - val_r2_keras: 0.9723 - val_root_mean_squared_error: 0.0462
# Epoch 121/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0281 - r2_keras: 0.9727 - root_mean_squared_error: 0.0459 - val_loss: 0.0021 - val_mae: 0.0279 - val_r2_keras: 0.9731 - val_root_mean_squared_error: 0.0456
# Epoch 122/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0281 - r2_keras: 0.9728 - root_mean_squared_error: 0.0459 - val_loss: 0.0021 - val_mae: 0.0277 - val_r2_keras: 0.9731 - val_root_mean_squared_error: 0.0456
# Epoch 123/200
# 20631/20631 - 0s - loss: 0.0021 - mae: 0.0281 - r2_keras: 0.9728 - root_mean_squared_error: 0.0458 - val_loss: 0.0021 - val_mae: 0.0285 - val_r2_keras: 0.9722 - val_root_mean_squared_error: 0.0463

# %%
# list all data in history
print(history.history.keys())

# summarize history for R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model r^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_r2.png")

# summarize history for RMSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_RMSE.png")

# summarize history for MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_mae.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss RMSE')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_regression_loss.png")
# Out:
# dict_keys(['loss', 'mae', 'r2_keras', 'root_mean_squared_error', 'val_loss', 'val_mae', 'val_r2_keras', 'val_root_mean_squared_error'])

# %%
# get encoder
encoder = Model(inputs=autoencoder.inputs, outputs=autoencoder.layers[3].output)
encoder.summary()
encoder.save(encoder_path)
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                832
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_26 (Dense)             (None, 8)                 136
# =================================================================
# Total params: 1,496
# Trainable params: 1,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoded_data = encoder.predict(train_x,verbose=1, batch_size=200)
encoded_df = pd.DataFrame(encoded_data)
# Out:
# 20631/20631 [==============================] - 0s 5us/sample

# %%
encoded_data = encoder.predict(train_x,verbose=1, batch_size=200)
encoded_df = pd.DataFrame(encoded_data) 

encoded_cols_id = ['id', 's1', 's2', 's3','s4', 's5', 's6', 's7', 's8']

# Convert the dictionary into DataFrame 
encoded_df = pd.DataFrame(encoded_data) 
  
# Using DataFrame.insert() to add a column 
encoded_df.insert(0, "id", train_df['id'], True) 
#add column names
encoded_df.columns = encoded_cols_id

encoded_cols = ['s' + str(i) for i in range(1,9)]

# %%
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...       s20       s21  RUL  cycle_norm
# 0   1      1  0.459770  0.166667  ...  0.713178  0.724662  191     0.00000
# 1   1      2  0.609195  0.250000  ...  0.666667  0.731014  190     0.00277
# 2   1      3  0.252874  0.750000  ...  0.627907  0.621375  189     0.00554
# 3   1      4  0.540230  0.500000  ...  0.573643  0.662386  188     0.00831
# 4   1      5  0.390805  0.333333  ...  0.589147  0.704502  187     0.01108
#
# [5 rows x 28 columns]

# %%
xxxx = train_df[sequence_cols].columns
xxxx
# Out:
# Index(['setting1', 'setting2', 'setting3', 'cycle_norm', 's1', 's2', 's3',
#        's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
#        's15', 's16', 's17', 's18', 's19', 's20', 's21'],
#       dtype='object')

# %%
autoencoder_data = autoencoder.predict(train_x,verbose=1, batch_size=200)
autoencoder_df = pd.DataFrame(autoencoder_data) 


#add column names
autoencoder_df.columns = train_df[sequence_cols].columns

# Using DataFrame.insert() to add a column 
autoencoder_df.insert(0, "id", train_df['id'], True)
# Out:
# 20631/20631 [==============================] - 0s 6us/sample

# %%
autoencoder_df.head()
# Out:
#    id         0         1  ...            22        23        24
# 0   1  0.455364  0.186794  ...  9.247009e-08  0.686917  0.688895
# 1   1  0.613421  0.250417  ...  5.064778e-08  0.657663  0.661807
# 2   1  0.271411  0.764687  ...  4.299818e-06  0.654501  0.686445
# 3   1  0.546046  0.512966  ...  1.735836e-07  0.684394  0.720236
# 4   1  0.383052  0.332779  ...  1.198308e-06  0.639965  0.658074
#
# [5 rows x 26 columns]

# %%
def display_encoded_data(data, col_names, rul=None):
    
    samples = data.shape[0]
    x = np.arange(samples)
    
    # Total plots 
    n = len(col_names)
     
    nrows = n // 3
    ncols = n // nrows
    
    fig = plt.figure(figsize=(20, n))
    
    print(" Samples: {}, Features: {}".format( samples, n))
    
    for i, m in enumerate(col_names):
        ax = plt.subplot(nrows, ncols, i+1)
        ax.set_title(m)
        
        y = data[m].values
        ax.plot(x, y)
        
    
    plt.tight_layout()
    plt.show()

# %%
# Three operational setting columns
setting_cols = ['setting' + str(i) for i in range(1,4)]

# Twenty one sensor columns
sensor_cols = ['s' + str(i) for i in range(1,22)]

def display_data(df, engine_id, col_names, rul=None):
    
    engine_data = df[df['id'] == engine_id]
    samples = engine_data.shape[0]
    x = np.arange(samples)
    
    # Total plots 
    n = len(col_names)
     
    nrows = n // 3
    ncols = n // nrows
    
    fig = plt.figure(figsize=(20, n))
    
    print("Engine: {}, Samples: {}, Features: {}".format( engine_id, samples, n))
    
    for i, m in enumerate(col_names):
        ax = plt.subplot(nrows, ncols, i+1)
        ax.set_title(m)
        
        y = engine_data[m].values
        ax.plot(x, y)
        
        if rul:
            ax.axvline(x=rul, color='r')
    
    plt.tight_layout()
    plt.show()

# %%
display_data( train_df, 1, setting_cols)
# Out:
# Engine: 1, Samples: 192, Features: 3

# %%
display_data( train_df, 3, sensor_cols)
# Out:
# Engine: 3, Samples: 179, Features: 21

# %%
display_data( autoencoder_df, 3, sensor_cols)
# Out:
# Engine: 3, Samples: 179, Features: 21

# %%
display_data( encoded_df, 70, encoded_cols)
# Out:
# Engine: 70, Samples: 137, Features: 8

# %%
def display_multiple(df, engines, col_names):
    
    engine_data = []
    
    for i in engines:
        engine_id = i+1
        engine = train_df[train_df['id'] == engine_id]
        engine_data.append(engine)
        
    # Total plots 
    n = len(col_names)
     
    nrows = n // 3
    ncols = n // nrows
    
    fig = plt.figure(figsize=(20, n))
        
    for i, m in enumerate(col_names):
        ax = plt.subplot(nrows, ncols, i+1)
        ax.set_title(m)
        
        for i in range(len(engine_data)):
            e = engine_data[i]
            x = np.arange(e.shape[0])
            y = e[m].values
            ax.plot(x, y)
    
    plt.tight_layout()
    plt.show()

# %%
engine_ids
# Out:
# [24, 48]

# %%
# Compare 10 random engines

num_engines = train_df.groupby(['id']).count().shape[0]
engine_ids = random.sample(range(1,num_engines), 2)
display_multiple( train_df, engine_ids, setting_cols)

# %%
# Compare 10 random engines

engine_ids = random.sample(range(1,num_engines), 10)
display_multiple( train_df, engine_ids, sensor_cols)

# %%
engine_ids = random.sample(range(1,num_engines), 10)
print(engine_ids)
display_multiple( encoded_df, engine_ids, encoded_cols)
# Out:
# [3, 70, 97, 82, 64, 13, 96, 25, 94, 16]

# %%
def display_combined(df1,df2,engine_id, col_names):
    
    engine_data = []
    
    engine_data.append(df1[df1['id'] == engine_id])
    engine_data.append(df2[df2['id'] == engine_id])
        
    # Total plots 
    n = len(col_names)
     
    nrows = n // 3
    ncols = n // nrows
    
    fig = plt.figure(figsize=(20, n))
        
    for i, m in enumerate(col_names):
        ax = plt.subplot(nrows, ncols, i+1)
        ax.set_title(m)
        
        for i in range(len(engine_data)):
            e = engine_data[i]
            x = np.arange(e.shape[0])
            y = e[m].values
            ax.plot(x, y)
    
    plt.tight_layout()
    plt.show()

# %%
display_combined(train_df,autoencoder_df,3,sensor_cols)
