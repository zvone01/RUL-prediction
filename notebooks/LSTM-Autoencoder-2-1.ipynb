# %% [markdown]
# Use autoencoder to get only 8 values

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %tensorflow_version 2.x
import tensorflow.keras as keras
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Activation
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras import Input, Model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing
# Out:
# TensorFlow 2.x selected.

# %%
# Setting seed for reproducibility
np.random.seed(1234)  
PYTHONHASHSEED = 0


# define paths
output_path = '/content/drive/My Drive/Fax/Master Theses/output-LSTM-Autoencoder-2-1'
model_path = output_path+'/model.h5'

data_path = '/content/drive/My Drive/Fax/Master Theses/Data/CMAPSSData/'
autoencoder_path = '/content/drive/My Drive/Fax/Master Theses/output-autoencoder2/model.h5'
encoder_path = '/content/drive/My Drive/Fax/Master Theses/output-autoencoder2/encoder.h5'

# %%
##################################
# Data Ingestion
##################################

# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv(data_path+'train_FD001.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv(data_path+'test_FD001.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# read ground truth data - It contains the information of true remaining cycles for each engine in the testing data.
truth_df = pd.read_csv(data_path+'RUL_FD001.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %%
#######
# TRAIN set
#######
# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

# generate label columns for training data
# we will only make use of "label1" for binary classification, 
# while trying to answer the question: is a specific engine going to fail within w1 cycles?
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

#train_df.to_csv('../../Dataset/PredictiveManteinanceEngineTraining.csv', encoding='utf-8',index = None)

# %%
######
# TEST set
######
# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
print(test_df.head())

# We use the ground truth dataset to generate labels for the test data.
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)

# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2

#test_df.to_csv('../../Dataset/PredictiveManteinanceEngineValidation.csv', encoding='utf-8',index = None)
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  0.632184  0.750000  ...  0.0  0.558140  0.661834     0.00000
# 1   1      2  0.344828  0.250000  ...  0.0  0.682171  0.686827     0.00277
# 2   1      3  0.517241  0.583333  ...  0.0  0.728682  0.721348     0.00554
# 3   1      4  0.741379  0.500000  ...  0.0  0.666667  0.662110     0.00831
# 4   1      5  0.580460  0.500000  ...  0.0  0.658915  0.716377     0.01108
#
# [5 rows x 27 columns]

# %%
# pick the feature columns 

sensor_cols= ['s2','s3','s4','s7','s8','s9','s11','s12','s13','s14','s15','s17','s20','s21']
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)

train_x = train_df[sequence_cols].values.astype(np.float32)
print(train_x.shape)
# Out:
# (20631, 18)

# %%
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
#load encoder
def get_encoded_data(data, print_model_data):
  if os.path.isfile(encoder_path):

      # restore weights

      autoencoder_model = load_model(encoder_path,custom_objects={'r2_keras': r2_keras,'root_mean_squared_error': root_mean_squared_error })
      estimator_encoder = Model(inputs=autoencoder_model.inputs, outputs=autoencoder_model.layers[3].output)

      encoded_data = estimator_encoder.predict(data,verbose=1, batch_size=200)
      if print_model_data:
        print(estimator_encoder.summary())
      return encoded_data

# %%
##create encoded sequence data

# pick a window size
sequence_length = 50

encoded_cols = ['id', 's1', 's2', 's3','s4', 's5', 's6', 's7', 's8']
#get encoded data first
encoded_data = get_encoded_data(train_x, True)
# Convert the dictionary into DataFrame 
encoded_train = pd.DataFrame(encoded_data) 
  
# Using DataFrame.insert() to add a column 
encoded_train.insert(0, "id", train_df['id'], True) 
#add column names
encoded_train.columns = encoded_cols

# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length):
    
    data_matrix = id_df[encoded_cols].values
    num_elements = data_matrix.shape[0]
    
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]
        

# generator for the sequences
# transform each id of the train dataset in a sequence
seq_gen = (list(gen_sequence(encoded_train[encoded_train['id']==id], sequence_length)) 
          for id in train_df['id'].unique())

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
print(seq_array.shape)
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# 20631/20631 [==============================] - 1s 25us/sample
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 18)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                608
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_20 (Dense)             (None, 8)                 136
# =================================================================
# Total params: 1,272
# Trainable params: 1,272
# Non-trainable params: 0
# _________________________________________________________________
# None
# (15631, 50, 9)

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    return data_matrix[seq_length:num_elements, :]

# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]

label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
# (15631, 1)

# %%
nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]
(sequence_length, nb_features)
# Out:
# (50, 9)

# %%
##################################
# Modeling
##################################

# Next, we build a deep network. 
# The first layer is an LSTM layer with 100 units followed by another LSTM layer with 50 units. 
# Dropout is also applied after each LSTM layer to control overfitting. 
# Final layer is a Dense output layer with single unit and linear activation since this is a regression problem.
nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()
model.add(LSTM(
         input_shape=(sequence_length, nb_features),
         units=100,
         return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(
          units=50,
          return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=nb_out))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])
#model.compile(loss=root_mean_squared_error, optimizer='rmsprop',metrics=['mae',r2_keras,root_mean_squared_error])
print(model.summary())

# fit the network
history = model.fit(seq_array, label_array, epochs=200, batch_size=200, validation_split=0.05, verbose=2,
          callbacks = [#keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                       keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
          )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 100)           44000
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 74,251
# Trainable params: 74,251
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14849 samples, validate on 782 samples
# Epoch 1/200
# 14849/14849 - 5s - loss: 8715.0110 - mae: 74.5733 - r2_keras: -1.6874e+00 - root_mean_squared_error: 93.2133 - val_loss: 8085.0377 - val_mae: 71.4467 - val_r2_keras: -2.3928e+00 - val_root_mean_squared_error: 83.9700
# Epoch 2/200
# 14849/14849 - 1s - loss: 8004.9915 - mae: 70.4836 - r2_keras: -1.4589e+00 - root_mean_squared_error: 89.2908 - val_loss: 7577.0014 - val_mae: 68.4998 - val_r2_keras: -2.1533e+00 - val_root_mean_squared_error: 80.9889
# Epoch 3/200
# 14849/14849 - 1s - loss: 7495.0769 - mae: 67.5506 - r2_keras: -1.3118e+00 - root_mean_squared_error: 86.3853 - val_loss: 7077.5053 - val_mae: 65.6192 - val_r2_keras: -1.9198e+00 - val_root_mean_squared_error: 77.9649
# Epoch 4/200
# 14849/14849 - 1s - loss: 7015.8058 - mae: 64.8139 - r2_keras: -1.1575e+00 - root_mean_squared_error: 83.5949 - val_loss: 6620.1302 - val_mae: 62.9991 - val_r2_keras: -1.7080e+00 - val_root_mean_squared_error: 75.1104
# Epoch 5/200
# 14849/14849 - 1s - loss: 6566.7620 - mae: 62.2649 - r2_keras: -1.0165e+00 - root_mean_squared_error: 80.8189 - val_loss: 6191.1324 - val_mae: 60.5599 - val_r2_keras: -1.5115e+00 - val_root_mean_squared_error: 72.3556
# Epoch 6/200
# 14849/14849 - 1s - loss: 6140.1713 - mae: 59.8857 - r2_keras: -8.8969e-01 - root_mean_squared_error: 78.2348 - val_loss: 5788.3307 - val_mae: 58.2916 - val_r2_keras: -1.3292e+00 - val_root_mean_squared_error: 69.7003
# Epoch 7/200
# 14849/14849 - 1s - loss: 5762.9614 - mae: 57.8026 - r2_keras: -7.7774e-01 - root_mean_squared_error: 75.8999 - val_loss: 5415.9103 - val_mae: 56.2162 - val_r2_keras: -1.1631e+00 - val_root_mean_squared_error: 67.1879
# Epoch 8/200
# 14849/14849 - 1s - loss: 5397.4974 - mae: 55.7766 - r2_keras: -6.6089e-01 - root_mean_squared_error: 73.3518 - val_loss: 5073.2095 - val_mae: 54.3290 - val_r2_keras: -1.0129e+00 - val_root_mean_squared_error: 64.8327
# Epoch 9/200
# 14849/14849 - 1s - loss: 5070.3534 - mae: 54.0214 - r2_keras: -5.6273e-01 - root_mean_squared_error: 71.0266 - val_loss: 4761.0439 - val_mae: 52.6339 - val_r2_keras: -8.7884e-01 - val_root_mean_squared_error: 62.6603
# Epoch 10/200
# 14849/14849 - 1s - loss: 4766.8558 - mae: 52.4229 - r2_keras: -4.6265e-01 - root_mean_squared_error: 68.8529 - val_loss: 4474.7423 - val_mae: 51.1076 - val_r2_keras: -7.5893e-01 - val_root_mean_squared_error: 60.6589
# Epoch 11/200
# 14849/14849 - 1s - loss: 4487.9798 - mae: 50.9424 - r2_keras: -3.8153e-01 - root_mean_squared_error: 66.7819 - val_loss: 4216.9755 - val_mae: 49.7641 - val_r2_keras: -6.5433e-01 - val_root_mean_squared_error: 58.8682
# Epoch 12/200
# 14849/14849 - 1s - loss: 4258.5381 - mae: 49.7616 - r2_keras: -3.0835e-01 - root_mean_squared_error: 64.9963 - val_loss: 3992.0846 - val_mae: 48.6234 - val_r2_keras: -5.6668e-01 - val_root_mean_squared_error: 57.3378
# Epoch 13/200
# 14849/14849 - 1s - loss: 4033.0780 - mae: 48.7090 - r2_keras: -2.3656e-01 - root_mean_squared_error: 63.3051 - val_loss: 3793.4324 - val_mae: 47.6507 - val_r2_keras: -4.9329e-01 - val_root_mean_squared_error: 56.0394
# Epoch 14/200
# 14849/14849 - 1s - loss: 3857.1006 - mae: 47.8829 - r2_keras: -1.8293e-01 - root_mean_squared_error: 61.9551 - val_loss: 3621.6730 - val_mae: 46.8534 - val_r2_keras: -4.3444e-01 - val_root_mean_squared_error: 54.9919
# Epoch 15/200
# 14849/14849 - 1s - loss: 3693.7828 - mae: 47.1846 - r2_keras: -1.3307e-01 - root_mean_squared_error: 60.6915 - val_loss: 3479.5049 - val_mae: 46.2394 - val_r2_keras: -3.9097e-01 - val_root_mean_squared_error: 54.2191
# Epoch 16/200
# 14849/14849 - 1s - loss: 3554.5511 - mae: 46.5712 - r2_keras: -9.0385e-02 - root_mean_squared_error: 59.5010 - val_loss: 3366.0610 - val_mae: 45.8017 - val_r2_keras: -3.6227e-01 - val_root_mean_squared_error: 53.7129
# Epoch 17/200
# 14849/14849 - 1s - loss: 3464.7055 - mae: 46.3415 - r2_keras: -6.4143e-02 - root_mean_squared_error: 58.6388 - val_loss: 3284.0608 - val_mae: 45.5405 - val_r2_keras: -3.4772e-01 - val_root_mean_squared_error: 53.4582
# Epoch 18/200
# 14849/14849 - 1s - loss: 3288.8911 - mae: 44.6562 - r2_keras: -9.4631e-03 - root_mean_squared_error: 57.1591 - val_loss: 3111.4182 - val_mae: 44.3804 - val_r2_keras: -2.8466e-01 - val_root_mean_squared_error: 52.1171
# Epoch 19/200
# 14849/14849 - 1s - loss: 2915.1638 - mae: 40.5624 - r2_keras: 0.1082 - root_mean_squared_error: 53.7454 - val_loss: 2842.2942 - val_mae: 42.1605 - val_r2_keras: -1.8230e-01 - val_root_mean_squared_error: 49.7369
# Epoch 20/200
# 14849/14849 - 1s - loss: 2592.4004 - mae: 36.7946 - r2_keras: 0.2045 - root_mean_squared_error: 50.6990 - val_loss: 2308.0447 - val_mae: 34.3786 - val_r2_keras: 0.1782 - val_root_mean_squared_error: 40.1406
# Epoch 21/200
# 14849/14849 - 1s - loss: 2280.2862 - mae: 33.2718 - r2_keras: 0.3019 - root_mean_squared_error: 47.5358 - val_loss: 2272.3893 - val_mae: 35.2168 - val_r2_keras: 0.0694 - val_root_mean_squared_error: 43.4599
# Epoch 22/200
# 14849/14849 - 1s - loss: 2071.1722 - mae: 30.9194 - r2_keras: 0.3673 - root_mean_squared_error: 45.2988 - val_loss: 2697.7150 - val_mae: 42.1724 - val_r2_keras: -1.9898e-01 - val_root_mean_squared_error: 49.7290
# Epoch 23/200
# 14849/14849 - 1s - loss: 1909.2714 - mae: 29.1836 - r2_keras: 0.4174 - root_mean_squared_error: 43.4282 - val_loss: 1757.4967 - val_mae: 29.0346 - val_r2_keras: 0.3734 - val_root_mean_squared_error: 34.8049
# Epoch 24/200
# 14849/14849 - 1s - loss: 1756.4155 - mae: 27.6152 - r2_keras: 0.4657 - root_mean_squared_error: 41.6345 - val_loss: 1678.6694 - val_mae: 27.9505 - val_r2_keras: 0.3316 - val_root_mean_squared_error: 35.9672
# Epoch 25/200
# 14849/14849 - 1s - loss: 1608.4476 - mae: 25.8981 - r2_keras: 0.5080 - root_mean_squared_error: 39.9658 - val_loss: 1490.0784 - val_mae: 26.1661 - val_r2_keras: 0.4538 - val_root_mean_squared_error: 32.6440
# Epoch 26/200
# 14849/14849 - 1s - loss: 1502.9755 - mae: 24.9614 - r2_keras: 0.5417 - root_mean_squared_error: 38.5565 - val_loss: 1493.8467 - val_mae: 26.6082 - val_r2_keras: 0.3905 - val_root_mean_squared_error: 34.3544
# Epoch 27/200
# 14849/14849 - 1s - loss: 1404.5666 - mae: 24.0780 - r2_keras: 0.5709 - root_mean_squared_error: 37.2567 - val_loss: 1996.4062 - val_mae: 30.6187 - val_r2_keras: 0.3340 - val_root_mean_squared_error: 34.7662
# Epoch 28/200
# 14849/14849 - 1s - loss: 1296.0474 - mae: 22.7765 - r2_keras: 0.6035 - root_mean_squared_error: 35.9249 - val_loss: 1288.0501 - val_mae: 23.9462 - val_r2_keras: 0.5531 - val_root_mean_squared_error: 29.2896
# Epoch 29/200
# 14849/14849 - 1s - loss: 1220.2397 - mae: 22.0310 - r2_keras: 0.6292 - root_mean_squared_error: 34.6860 - val_loss: 1323.3307 - val_mae: 25.9427 - val_r2_keras: 0.4239 - val_root_mean_squared_error: 33.2567
# Epoch 30/200
# 14849/14849 - 1s - loss: 1147.1442 - mae: 21.2214 - r2_keras: 0.6507 - root_mean_squared_error: 33.6067 - val_loss: 1401.5563 - val_mae: 28.8964 - val_r2_keras: 0.3602 - val_root_mean_squared_error: 35.1223
# Epoch 31/200
# 14849/14849 - 1s - loss: 1070.7860 - mae: 20.3831 - r2_keras: 0.6741 - root_mean_squared_error: 32.5068 - val_loss: 1049.0198 - val_mae: 21.9325 - val_r2_keras: 0.6026 - val_root_mean_squared_error: 28.2140
# Epoch 32/200
# 14849/14849 - 1s - loss: 1032.7130 - mae: 20.1894 - r2_keras: 0.6835 - root_mean_squared_error: 32.0035 - val_loss: 1131.0652 - val_mae: 23.5416 - val_r2_keras: 0.5102 - val_root_mean_squared_error: 31.2836
# Epoch 33/200
# 14849/14849 - 1s - loss: 959.3048 - mae: 19.2462 - r2_keras: 0.7081 - root_mean_squared_error: 30.7283 - val_loss: 1853.3766 - val_mae: 33.7407 - val_r2_keras: -1.6341e-02 - val_root_mean_squared_error: 41.4446
# Epoch 34/200
# 14849/14849 - 1s - loss: 921.5304 - mae: 18.9660 - r2_keras: 0.7193 - root_mean_squared_error: 30.1623 - val_loss: 1017.8456 - val_mae: 22.0269 - val_r2_keras: 0.5687 - val_root_mean_squared_error: 29.1406
# Epoch 35/200
# 14849/14849 - 1s - loss: 874.6697 - mae: 18.4834 - r2_keras: 0.7332 - root_mean_squared_error: 29.3534 - val_loss: 995.3734 - val_mae: 21.5731 - val_r2_keras: 0.6234 - val_root_mean_squared_error: 27.3854
# Epoch 36/200
# 14849/14849 - 1s - loss: 835.5404 - mae: 18.1300 - r2_keras: 0.7434 - root_mean_squared_error: 28.7879 - val_loss: 1155.3675 - val_mae: 22.8700 - val_r2_keras: 0.5968 - val_root_mean_squared_error: 27.6383
# Epoch 37/200
# 14849/14849 - 1s - loss: 801.9148 - mae: 17.7854 - r2_keras: 0.7561 - root_mean_squared_error: 28.0724 - val_loss: 1114.8446 - val_mae: 23.3352 - val_r2_keras: 0.5012 - val_root_mean_squared_error: 31.7786
# Epoch 38/200
# 14849/14849 - 1s - loss: 806.2952 - mae: 17.9222 - r2_keras: 0.7556 - root_mean_squared_error: 28.0732 - val_loss: 1531.3152 - val_mae: 30.8363 - val_r2_keras: 0.1665 - val_root_mean_squared_error: 38.3584
# Epoch 39/200
# 14849/14849 - 1s - loss: 749.0682 - mae: 17.1080 - r2_keras: 0.7722 - root_mean_squared_error: 27.1196 - val_loss: 1199.0492 - val_mae: 22.7485 - val_r2_keras: 0.5418 - val_root_mean_squared_error: 29.5761
# Epoch 40/200
# 14849/14849 - 1s - loss: 740.5322 - mae: 17.2847 - r2_keras: 0.7735 - root_mean_squared_error: 27.0768 - val_loss: 1153.3321 - val_mae: 23.8502 - val_r2_keras: 0.5691 - val_root_mean_squared_error: 29.0692
# Epoch 41/200
# 14849/14849 - 1s - loss: 708.5348 - mae: 16.8962 - r2_keras: 0.7839 - root_mean_squared_error: 26.4060 - val_loss: 1163.0729 - val_mae: 22.4162 - val_r2_keras: 0.5870 - val_root_mean_squared_error: 27.8894
# Epoch 42/200
# 14849/14849 - 1s - loss: 682.3468 - mae: 16.5146 - r2_keras: 0.7913 - root_mean_squared_error: 26.0544 - val_loss: 1201.7890 - val_mae: 24.5959 - val_r2_keras: 0.3683 - val_root_mean_squared_error: 33.2794
# Epoch 43/200
# 14849/14849 - 1s - loss: 665.4278 - mae: 16.3689 - r2_keras: 0.7958 - root_mean_squared_error: 25.7064 - val_loss: 1040.1542 - val_mae: 20.6048 - val_r2_keras: 0.5870 - val_root_mean_squared_error: 28.8516
# Epoch 44/200
# 14849/14849 - 1s - loss: 647.6917 - mae: 16.1784 - r2_keras: 0.8002 - root_mean_squared_error: 25.4094 - val_loss: 1176.8040 - val_mae: 26.1798 - val_r2_keras: 0.5393 - val_root_mean_squared_error: 30.8909
# Epoch 45/200
# 14849/14849 - 1s - loss: 637.1736 - mae: 15.9818 - r2_keras: 0.8055 - root_mean_squared_error: 25.0686 - val_loss: 1973.2652 - val_mae: 37.8123 - val_r2_keras: -1.3340e-01 - val_root_mean_squared_error: 43.7875
# Epoch 46/200
# 14849/14849 - 1s - loss: 615.8437 - mae: 15.7526 - r2_keras: 0.8112 - root_mean_squared_error: 24.6405 - val_loss: 1058.8708 - val_mae: 23.4388 - val_r2_keras: 0.5896 - val_root_mean_squared_error: 28.4493
# Epoch 47/200
# 14849/14849 - 1s - loss: 592.4462 - mae: 15.5202 - r2_keras: 0.8182 - root_mean_squared_error: 24.1988 - val_loss: 1148.2011 - val_mae: 24.9535 - val_r2_keras: 0.3795 - val_root_mean_squared_error: 31.5009
# Epoch 48/200
# 14849/14849 - 1s - loss: 581.8472 - mae: 15.2813 - r2_keras: 0.8228 - root_mean_squared_error: 23.9184 - val_loss: 1239.9112 - val_mae: 26.4327 - val_r2_keras: 0.3694 - val_root_mean_squared_error: 33.7198
# Epoch 49/200
# 14849/14849 - 1s - loss: 563.6990 - mae: 15.1361 - r2_keras: 0.8280 - root_mean_squared_error: 23.5536 - val_loss: 1472.0328 - val_mae: 27.8484 - val_r2_keras: 0.1706 - val_root_mean_squared_error: 36.1401
# Epoch 50/200
# 14849/14849 - 1s - loss: 538.4737 - mae: 14.8121 - r2_keras: 0.8356 - root_mean_squared_error: 23.0410 - val_loss: 1352.3691 - val_mae: 26.8837 - val_r2_keras: 0.2652 - val_root_mean_squared_error: 35.5263
# Epoch 51/200
# 14849/14849 - 1s - loss: 553.0247 - mae: 14.9680 - r2_keras: 0.8305 - root_mean_squared_error: 23.3607 - val_loss: 1391.0599 - val_mae: 26.1214 - val_r2_keras: 0.2430 - val_root_mean_squared_error: 35.2865
# Epoch 52/200
# 14849/14849 - 1s - loss: 525.3312 - mae: 14.6241 - r2_keras: 0.8399 - root_mean_squared_error: 22.6942 - val_loss: 1317.4617 - val_mae: 25.6657 - val_r2_keras: 0.3184 - val_root_mean_squared_error: 34.3898
# Epoch 53/200
# 14849/14849 - 1s - loss: 521.8220 - mae: 14.5216 - r2_keras: 0.8398 - root_mean_squared_error: 22.6291 - val_loss: 1521.8886 - val_mae: 27.7615 - val_r2_keras: 0.1015 - val_root_mean_squared_error: 35.2948
# Epoch 54/200
# 14849/14849 - 1s - loss: 513.0314 - mae: 14.3432 - r2_keras: 0.8429 - root_mean_squared_error: 22.4421 - val_loss: 1172.1599 - val_mae: 26.4707 - val_r2_keras: 0.4020 - val_root_mean_squared_error: 33.1914
# Epoch 55/200
# 14849/14849 - 1s - loss: 495.3650 - mae: 14.2242 - r2_keras: 0.8473 - root_mean_squared_error: 22.1787 - val_loss: 1450.0627 - val_mae: 30.7648 - val_r2_keras: 0.1729 - val_root_mean_squared_error: 36.4914
# Epoch 56/200
# 14849/14849 - 1s - loss: 489.0664 - mae: 14.1248 - r2_keras: 0.8510 - root_mean_squared_error: 21.8738 - val_loss: 1178.6125 - val_mae: 23.4420 - val_r2_keras: 0.4113 - val_root_mean_squared_error: 33.5295
# Epoch 57/200
# 14849/14849 - 1s - loss: 473.5164 - mae: 13.9606 - r2_keras: 0.8549 - root_mean_squared_error: 21.6096 - val_loss: 1611.3613 - val_mae: 29.0633 - val_r2_keras: 0.2630 - val_root_mean_squared_error: 38.9655
# Epoch 58/200
# 14849/14849 - 1s - loss: 465.3828 - mae: 13.7030 - r2_keras: 0.8576 - root_mean_squared_error: 21.3617 - val_loss: 1061.3024 - val_mae: 24.3351 - val_r2_keras: 0.5141 - val_root_mean_squared_error: 30.5910
# Epoch 59/200
# 14849/14849 - 1s - loss: 461.5766 - mae: 13.7019 - r2_keras: 0.8586 - root_mean_squared_error: 21.3971 - val_loss: 1432.1736 - val_mae: 29.8843 - val_r2_keras: 0.2311 - val_root_mean_squared_error: 36.1758
# Epoch 60/200
# 14849/14849 - 1s - loss: 455.8171 - mae: 13.6376 - r2_keras: 0.8606 - root_mean_squared_error: 21.0784 - val_loss: 1538.2458 - val_mae: 27.9241 - val_r2_keras: 0.4065 - val_root_mean_squared_error: 33.8104
# Epoch 61/200
# 14849/14849 - 1s - loss: 429.4615 - mae: 13.1205 - r2_keras: 0.8683 - root_mean_squared_error: 20.5317 - val_loss: 1402.1675 - val_mae: 28.8109 - val_r2_keras: 0.2353 - val_root_mean_squared_error: 35.6144
# Epoch 62/200
# 14849/14849 - 1s - loss: 439.0505 - mae: 13.3561 - r2_keras: 0.8660 - root_mean_squared_error: 20.7085 - val_loss: 1730.0641 - val_mae: 28.5186 - val_r2_keras: 0.0621 - val_root_mean_squared_error: 38.8495
# Epoch 63/200
# 14849/14849 - 1s - loss: 431.3554 - mae: 13.3019 - r2_keras: 0.8687 - root_mean_squared_error: 20.4802 - val_loss: 1425.1758 - val_mae: 23.9683 - val_r2_keras: 0.2683 - val_root_mean_squared_error: 34.7326
# Epoch 64/200
# 14849/14849 - 1s - loss: 409.9735 - mae: 12.8880 - r2_keras: 0.8752 - root_mean_squared_error: 19.9766 - val_loss: 1217.8802 - val_mae: 25.6921 - val_r2_keras: 0.4230 - val_root_mean_squared_error: 33.7332
# Epoch 65/200
# 14849/14849 - 1s - loss: 411.7432 - mae: 12.8882 - r2_keras: 0.8749 - root_mean_squared_error: 19.9273 - val_loss: 1504.5353 - val_mae: 30.7773 - val_r2_keras: 0.2066 - val_root_mean_squared_error: 37.6658
# Epoch 66/200
# 14849/14849 - 1s - loss: 409.8694 - mae: 12.7915 - r2_keras: 0.8753 - root_mean_squared_error: 19.9768 - val_loss: 1479.7826 - val_mae: 27.1626 - val_r2_keras: 0.2184 - val_root_mean_squared_error: 35.9078
# Epoch 67/200
# 14849/14849 - 1s - loss: 390.5790 - mae: 12.7779 - r2_keras: 0.8806 - root_mean_squared_error: 19.5584 - val_loss: 1708.9423 - val_mae: 27.0525 - val_r2_keras: 0.0552 - val_root_mean_squared_error: 36.9116
# Epoch 68/200
# 14849/14849 - 1s - loss: 384.7252 - mae: 12.5438 - r2_keras: 0.8823 - root_mean_squared_error: 19.3539 - val_loss: 1502.0928 - val_mae: 27.1298 - val_r2_keras: 0.2034 - val_root_mean_squared_error: 35.6533
# Epoch 69/200
# 14849/14849 - 1s - loss: 380.4853 - mae: 12.4838 - r2_keras: 0.8837 - root_mean_squared_error: 19.3318 - val_loss: 2052.6369 - val_mae: 29.6633 - val_r2_keras: -1.5510e-01 - val_root_mean_squared_error: 40.8647
# Epoch 70/200
# 14849/14849 - 1s - loss: 378.7893 - mae: 12.5120 - r2_keras: 0.8836 - root_mean_squared_error: 19.2645 - val_loss: 1694.3675 - val_mae: 29.4142 - val_r2_keras: -2.7144e-03 - val_root_mean_squared_error: 37.0560
# Epoch 71/200
# 14849/14849 - 1s - loss: 379.9454 - mae: 12.3878 - r2_keras: 0.8838 - root_mean_squared_error: 19.2137 - val_loss: 1628.6002 - val_mae: 27.0518 - val_r2_keras: 0.1847 - val_root_mean_squared_error: 37.9366
# Epoch 72/200
# 14849/14849 - 1s - loss: 367.9013 - mae: 12.2782 - r2_keras: 0.8874 - root_mean_squared_error: 18.9292 - val_loss: 1762.1077 - val_mae: 28.8947 - val_r2_keras: 0.0942 - val_root_mean_squared_error: 40.0261
# Epoch 73/200
# 14849/14849 - 1s - loss: 364.2305 - mae: 12.1515 - r2_keras: 0.8885 - root_mean_squared_error: 18.7514 - val_loss: 1930.3177 - val_mae: 28.2887 - val_r2_keras: -6.2837e-02 - val_root_mean_squared_error: 39.2802
# Epoch 74/200
# 14849/14849 - 1s - loss: 340.5668 - mae: 11.7474 - r2_keras: 0.8959 - root_mean_squared_error: 18.1896 - val_loss: 1228.1071 - val_mae: 23.8821 - val_r2_keras: 0.3438 - val_root_mean_squared_error: 33.9562
# Epoch 75/200
# 14849/14849 - 1s - loss: 355.5545 - mae: 12.1174 - r2_keras: 0.8905 - root_mean_squared_error: 18.6628 - val_loss: 1407.5788 - val_mae: 26.8083 - val_r2_keras: 0.2923 - val_root_mean_squared_error: 35.7933
# Epoch 76/200
# 14849/14849 - 1s - loss: 338.8892 - mae: 11.8051 - r2_keras: 0.8958 - root_mean_squared_error: 18.1884 - val_loss: 1345.0653 - val_mae: 25.4134 - val_r2_keras: 0.2508 - val_root_mean_squared_error: 35.6104
# Epoch 77/200
# 14849/14849 - 1s - loss: 337.5772 - mae: 11.9401 - r2_keras: 0.8961 - root_mean_squared_error: 18.2320 - val_loss: 2769.1874 - val_mae: 37.0613 - val_r2_keras: -5.9379e-01 - val_root_mean_squared_error: 48.7688
# Epoch 78/200
# 14849/14849 - 1s - loss: 329.5209 - mae: 11.6712 - r2_keras: 0.8995 - root_mean_squared_error: 17.9297 - val_loss: 1910.3300 - val_mae: 28.8794 - val_r2_keras: -4.2734e-02 - val_root_mean_squared_error: 40.0256
# Epoch 79/200
# 14849/14849 - 1s - loss: 337.6806 - mae: 11.7022 - r2_keras: 0.8962 - root_mean_squared_error: 18.1823 - val_loss: 1742.1228 - val_mae: 30.5583 - val_r2_keras: -4.5276e-03 - val_root_mean_squared_error: 41.0738
# Epoch 80/200
# 14849/14849 - 1s - loss: 329.7015 - mae: 11.6363 - r2_keras: 0.8989 - root_mean_squared_error: 17.9284 - val_loss: 2282.0262 - val_mae: 33.3154 - val_r2_keras: -2.5514e-01 - val_root_mean_squared_error: 46.0949
# Epoch 81/200
# 14849/14849 - 1s - loss: 316.5918 - mae: 11.6177 - r2_keras: 0.9025 - root_mean_squared_error: 17.5719 - val_loss: 2297.4655 - val_mae: 33.2837 - val_r2_keras: -2.8342e-01 - val_root_mean_squared_error: 45.2279
# Epoch 82/200
# 14849/14849 - 1s - loss: 304.7934 - mae: 11.2551 - r2_keras: 0.9053 - root_mean_squared_error: 17.2747 - val_loss: 1224.8191 - val_mae: 24.3235 - val_r2_keras: 0.3571 - val_root_mean_squared_error: 33.0288
# Epoch 83/200
# 14849/14849 - 1s - loss: 316.2592 - mae: 11.5322 - r2_keras: 0.9026 - root_mean_squared_error: 17.5599 - val_loss: 1968.7284 - val_mae: 28.4880 - val_r2_keras: -1.3190e-02 - val_root_mean_squared_error: 42.9488
# Epoch 84/200
# 14849/14849 - 1s - loss: 297.3872 - mae: 11.1610 - r2_keras: 0.9078 - root_mean_squared_error: 17.0722 - val_loss: 1897.9875 - val_mae: 30.8686 - val_r2_keras: -8.0870e-02 - val_root_mean_squared_error: 39.5505
# Epoch 85/200
# 14849/14849 - 1s - loss: 303.3171 - mae: 11.1828 - r2_keras: 0.9068 - root_mean_squared_error: 17.1421 - val_loss: 3177.5663 - val_mae: 38.8631 - val_r2_keras: -9.5784e-01 - val_root_mean_squared_error: 50.8710
# Epoch 86/200
# 14849/14849 - 1s - loss: 311.6655 - mae: 11.3416 - r2_keras: 0.9045 - root_mean_squared_error: 17.3745 - val_loss: 2380.8125 - val_mae: 32.2441 - val_r2_keras: -4.1080e-01 - val_root_mean_squared_error: 45.2760
# Epoch 87/200
# 14849/14849 - 1s - loss: 292.1685 - mae: 11.0089 - r2_keras: 0.9088 - root_mean_squared_error: 16.9476 - val_loss: 1541.0943 - val_mae: 27.1576 - val_r2_keras: 0.1979 - val_root_mean_squared_error: 37.4598
# Epoch 88/200
# 14849/14849 - 1s - loss: 296.9717 - mae: 11.0541 - r2_keras: 0.9092 - root_mean_squared_error: 16.9979 - val_loss: 1846.7108 - val_mae: 27.7523 - val_r2_keras: -3.7651e-02 - val_root_mean_squared_error: 40.0874
# Epoch 89/200
# 14849/14849 - 1s - loss: 342.0514 - mae: 11.7635 - r2_keras: 0.8947 - root_mean_squared_error: 18.1179 - val_loss: 1996.9114 - val_mae: 29.9611 - val_r2_keras: -1.8555e-01 - val_root_mean_squared_error: 40.8336
# Epoch 90/200
# 14849/14849 - 1s - loss: 295.6772 - mae: 11.0081 - r2_keras: 0.9092 - root_mean_squared_error: 16.9186 - val_loss: 1685.9066 - val_mae: 27.8723 - val_r2_keras: 0.0048 - val_root_mean_squared_error: 37.2240
# Epoch 91/200
# 14849/14849 - 1s - loss: 285.7346 - mae: 10.9472 - r2_keras: 0.9123 - root_mean_squared_error: 16.6715 - val_loss: 1875.5397 - val_mae: 29.5406 - val_r2_keras: -9.7992e-02 - val_root_mean_squared_error: 38.9750
# Epoch 92/200
# 14849/14849 - 1s - loss: 280.6094 - mae: 10.8405 - r2_keras: 0.9132 - root_mean_squared_error: 16.5445 - val_loss: 2565.3454 - val_mae: 32.1561 - val_r2_keras: -5.2116e-01 - val_root_mean_squared_error: 43.9442
# Epoch 93/200
# 14849/14849 - 1s - loss: 273.4794 - mae: 10.7882 - r2_keras: 0.9154 - root_mean_squared_error: 16.3758 - val_loss: 1474.0012 - val_mae: 26.5891 - val_r2_keras: 0.1854 - val_root_mean_squared_error: 35.4410
# Epoch 94/200
# 14849/14849 - 1s - loss: 269.0711 - mae: 10.7046 - r2_keras: 0.9175 - root_mean_squared_error: 16.1602 - val_loss: 1845.1548 - val_mae: 27.9468 - val_r2_keras: -6.2300e-02 - val_root_mean_squared_error: 38.1710
# Epoch 95/200
# 14849/14849 - 1s - loss: 274.9756 - mae: 10.7720 - r2_keras: 0.9160 - root_mean_squared_error: 16.2717 - val_loss: 2267.5275 - val_mae: 30.1920 - val_r2_keras: -3.1581e-01 - val_root_mean_squared_error: 41.2069
# Epoch 96/200
# 14849/14849 - 1s - loss: 274.1252 - mae: 10.6775 - r2_keras: 0.9164 - root_mean_squared_error: 16.1577 - val_loss: 2285.0543 - val_mae: 29.8527 - val_r2_keras: -3.5516e-01 - val_root_mean_squared_error: 40.7352
# Epoch 97/200
# 14849/14849 - 1s - loss: 268.6733 - mae: 10.6206 - r2_keras: 0.9175 - root_mean_squared_error: 16.1027 - val_loss: 2623.3967 - val_mae: 32.7181 - val_r2_keras: -4.3959e-01 - val_root_mean_squared_error: 45.9379
# Epoch 98/200
# 14849/14849 - 1s - loss: 255.7082 - mae: 10.4690 - r2_keras: 0.9213 - root_mean_squared_error: 15.7527 - val_loss: 2136.9370 - val_mae: 28.6177 - val_r2_keras: -2.3048e-01 - val_root_mean_squared_error: 40.7138
# Epoch 99/200
# 14849/14849 - 1s - loss: 254.1932 - mae: 10.3724 - r2_keras: 0.9229 - root_mean_squared_error: 15.5698 - val_loss: 2732.8896 - val_mae: 31.9443 - val_r2_keras: -5.6804e-01 - val_root_mean_squared_error: 45.0411
# Epoch 100/200
# 14849/14849 - 1s - loss: 246.2046 - mae: 10.3540 - r2_keras: 0.9238 - root_mean_squared_error: 15.4610 - val_loss: 3234.1670 - val_mae: 42.2366 - val_r2_keras: -9.7653e-01 - val_root_mean_squared_error: 51.5183
# Epoch 101/200
# 14849/14849 - 1s - loss: 262.2622 - mae: 10.4272 - r2_keras: 0.9197 - root_mean_squared_error: 15.8325 - val_loss: 1674.0475 - val_mae: 26.6157 - val_r2_keras: 0.0539 - val_root_mean_squared_error: 37.9775
# Epoch 102/200
# 14849/14849 - 1s - loss: 259.7353 - mae: 10.3136 - r2_keras: 0.9191 - root_mean_squared_error: 15.7807 - val_loss: 2193.4580 - val_mae: 32.6570 - val_r2_keras: -2.2616e-01 - val_root_mean_squared_error: 43.7091
# Epoch 103/200
# 14849/14849 - 1s - loss: 236.5753 - mae: 10.0933 - r2_keras: 0.9273 - root_mean_squared_error: 15.1106 - val_loss: 1603.9646 - val_mae: 26.1387 - val_r2_keras: 0.0738 - val_root_mean_squared_error: 38.5705
# Epoch 104/200
# 14849/14849 - 1s - loss: 265.9856 - mae: 10.4056 - r2_keras: 0.9181 - root_mean_squared_error: 15.8678 - val_loss: 2141.9036 - val_mae: 30.0085 - val_r2_keras: -2.3231e-01 - val_root_mean_squared_error: 42.9776
# Epoch 105/200
# 14849/14849 - 1s - loss: 241.1654 - mae: 10.1288 - r2_keras: 0.9259 - root_mean_squared_error: 15.2783 - val_loss: 2533.4817 - val_mae: 30.9516 - val_r2_keras: -5.4677e-01 - val_root_mean_squared_error: 43.0928
# Epoch 106/200
# 14849/14849 - 1s - loss: 240.3943 - mae: 10.0501 - r2_keras: 0.9259 - root_mean_squared_error: 15.3019 - val_loss: 2182.9769 - val_mae: 30.7900 - val_r2_keras: -3.3467e-01 - val_root_mean_squared_error: 41.5586
# Epoch 107/200
# 14849/14849 - 1s - loss: 241.8440 - mae: 10.0347 - r2_keras: 0.9261 - root_mean_squared_error: 15.1960 - val_loss: 2502.9054 - val_mae: 33.3955 - val_r2_keras: -4.0651e-01 - val_root_mean_squared_error: 45.2242
# Epoch 108/200
# 14849/14849 - 1s - loss: 234.1505 - mae: 10.0090 - r2_keras: 0.9281 - root_mean_squared_error: 14.9881 - val_loss: 2622.9432 - val_mae: 32.5864 - val_r2_keras: -4.8624e-01 - val_root_mean_squared_error: 47.5994
# Epoch 109/200
# 14849/14849 - 1s - loss: 254.2675 - mae: 10.2052 - r2_keras: 0.9211 - root_mean_squared_error: 15.5911 - val_loss: 2624.5554 - val_mae: 31.5021 - val_r2_keras: -5.2184e-01 - val_root_mean_squared_error: 45.7537
# Epoch 110/200
# 14849/14849 - 1s - loss: 237.0807 - mae: 9.9779 - r2_keras: 0.9255 - root_mean_squared_error: 15.1828 - val_loss: 2430.5306 - val_mae: 29.8634 - val_r2_keras: -3.9255e-01 - val_root_mean_squared_error: 43.8358
# Epoch 111/200
# 14849/14849 - 1s - loss: 225.4444 - mae: 9.7563 - r2_keras: 0.9301 - root_mean_squared_error: 14.6158 - val_loss: 2265.2705 - val_mae: 29.3641 - val_r2_keras: -2.9727e-01 - val_root_mean_squared_error: 43.2892
# Epoch 112/200
# 14849/14849 - 1s - loss: 222.2012 - mae: 9.6661 - r2_keras: 0.9325 - root_mean_squared_error: 14.5018 - val_loss: 3147.5823 - val_mae: 33.0932 - val_r2_keras: -6.9499e-01 - val_root_mean_squared_error: 49.6039
# Epoch 113/200
# 14849/14849 - 1s - loss: 224.7173 - mae: 9.8104 - r2_keras: 0.9309 - root_mean_squared_error: 14.6736 - val_loss: 2786.0440 - val_mae: 32.6927 - val_r2_keras: -6.7380e-01 - val_root_mean_squared_error: 47.9854
# Epoch 114/200
# 14849/14849 - 1s - loss: 226.5330 - mae: 9.8314 - r2_keras: 0.9309 - root_mean_squared_error: 14.6416 - val_loss: 2265.7655 - val_mae: 29.9020 - val_r2_keras: -3.4447e-01 - val_root_mean_squared_error: 42.4914
# Epoch 115/200
# 14849/14849 - 1s - loss: 212.7492 - mae: 9.5852 - r2_keras: 0.9342 - root_mean_squared_error: 14.3866 - val_loss: 1614.7050 - val_mae: 25.5122 - val_r2_keras: 0.1195 - val_root_mean_squared_error: 39.6427
# Epoch 116/200
# 14849/14849 - 1s - loss: 250.4977 - mae: 9.9558 - r2_keras: 0.9233 - root_mean_squared_error: 15.4546 - val_loss: 2785.4594 - val_mae: 32.5657 - val_r2_keras: -6.4496e-01 - val_root_mean_squared_error: 46.2527
# Epoch 117/200
# 14849/14849 - 1s - loss: 204.0160 - mae: 9.4937 - r2_keras: 0.9364 - root_mean_squared_error: 14.1050 - val_loss: 2592.4345 - val_mae: 30.4109 - val_r2_keras: -4.7071e-01 - val_root_mean_squared_error: 44.0727
# Epoch 118/200
# 14849/14849 - 1s - loss: 222.4489 - mae: 9.5844 - r2_keras: 0.9311 - root_mean_squared_error: 14.5019 - val_loss: 2351.3897 - val_mae: 31.0743 - val_r2_keras: -3.4033e-01 - val_root_mean_squared_error: 44.4958
# Epoch 119/200
# 14849/14849 - 1s - loss: 208.9603 - mae: 9.4791 - r2_keras: 0.9360 - root_mean_squared_error: 14.1789 - val_loss: 1712.6301 - val_mae: 29.0169 - val_r2_keras: 0.0194 - val_root_mean_squared_error: 39.0746
# Epoch 120/200
# 14849/14849 - 1s - loss: 215.0824 - mae: 9.5717 - r2_keras: 0.9334 - root_mean_squared_error: 14.4968 - val_loss: 1545.8250 - val_mae: 28.8305 - val_r2_keras: 0.2416 - val_root_mean_squared_error: 38.1408
# Epoch 121/200
# 14849/14849 - 1s - loss: 213.7046 - mae: 9.4942 - r2_keras: 0.9335 - root_mean_squared_error: 14.2682 - val_loss: 3372.3318 - val_mae: 36.9240 - val_r2_keras: -9.1870e-01 - val_root_mean_squared_error: 52.5027
# Epoch 122/200
# 14849/14849 - 1s - loss: 200.1626 - mae: 9.3148 - r2_keras: 0.9388 - root_mean_squared_error: 13.8098 - val_loss: 3381.3837 - val_mae: 35.3814 - val_r2_keras: -8.6946e-01 - val_root_mean_squared_error: 52.6434
# Epoch 123/200
# 14849/14849 - 1s - loss: 264.4671 - mae: 10.0848 - r2_keras: 0.9191 - root_mean_squared_error: 15.5276 - val_loss: 2889.6970 - val_mae: 32.5551 - val_r2_keras: -6.5690e-01 - val_root_mean_squared_error: 46.2356
# Epoch 124/200
# 14849/14849 - 1s - loss: 206.4719 - mae: 9.4581 - r2_keras: 0.9356 - root_mean_squared_error: 14.2165 - val_loss: 3115.5085 - val_mae: 34.4581 - val_r2_keras: -9.2510e-01 - val_root_mean_squared_error: 47.8992
# Epoch 125/200
# 14849/14849 - 1s - loss: 207.1850 - mae: 9.2796 - r2_keras: 0.9367 - root_mean_squared_error: 13.9030 - val_loss: 2826.6704 - val_mae: 32.7720 - val_r2_keras: -6.8449e-01 - val_root_mean_squared_error: 46.8285
# Epoch 126/200
# 14849/14849 - 1s - loss: 216.1078 - mae: 9.4015 - r2_keras: 0.9335 - root_mean_squared_error: 14.3359 - val_loss: 2591.7687 - val_mae: 31.3783 - val_r2_keras: -4.3803e-01 - val_root_mean_squared_error: 45.7656
# Epoch 127/200
# 14849/14849 - 1s - loss: 179.5333 - mae: 8.9322 - r2_keras: 0.9449 - root_mean_squared_error: 13.1295 - val_loss: 3389.9101 - val_mae: 35.6359 - val_r2_keras: -8.8580e-01 - val_root_mean_squared_error: 50.3538
# Epoch 128/200
# 14849/14849 - 1s - loss: 200.2429 - mae: 9.1263 - r2_keras: 0.9395 - root_mean_squared_error: 13.6409 - val_loss: 2293.2121 - val_mae: 29.8629 - val_r2_keras: -2.9832e-01 - val_root_mean_squared_error: 45.0636
# Epoch 129/200
# 14849/14849 - 1s - loss: 186.4785 - mae: 9.0864 - r2_keras: 0.9416 - root_mean_squared_error: 13.5770 - val_loss: 2772.8795 - val_mae: 34.5970 - val_r2_keras: -6.6925e-01 - val_root_mean_squared_error: 45.4086
# Epoch 130/200
# 14849/14849 - 1s - loss: 194.9871 - mae: 9.0259 - r2_keras: 0.9404 - root_mean_squared_error: 13.5811 - val_loss: 3293.5493 - val_mae: 34.7082 - val_r2_keras: -8.3370e-01 - val_root_mean_squared_error: 52.4932
# Epoch 131/200
# 14849/14849 - 1s - loss: 207.2525 - mae: 9.2542 - r2_keras: 0.9367 - root_mean_squared_error: 13.9543 - val_loss: 3412.7238 - val_mae: 36.3118 - val_r2_keras: -9.2086e-01 - val_root_mean_squared_error: 52.5324
# Epoch 132/200
# 14849/14849 - 1s - loss: 201.1359 - mae: 9.1326 - r2_keras: 0.9384 - root_mean_squared_error: 13.7952 - val_loss: 3083.0328 - val_mae: 35.3041 - val_r2_keras: -6.8409e-01 - val_root_mean_squared_error: 51.0673
# Epoch 133/200
# 14849/14849 - 1s - loss: 185.6142 - mae: 8.9849 - r2_keras: 0.9428 - root_mean_squared_error: 13.4182 - val_loss: 1386.2807 - val_mae: 26.2506 - val_r2_keras: 0.2810 - val_root_mean_squared_error: 35.2755
# Epoch 134/200
# 14849/14849 - 1s - loss: 179.5041 - mae: 8.8258 - r2_keras: 0.9440 - root_mean_squared_error: 13.2102 - val_loss: 1732.5782 - val_mae: 28.9089 - val_r2_keras: -1.4327e-02 - val_root_mean_squared_error: 39.6346
# Epoch 135/200
# 14849/14849 - 1s - loss: 186.3099 - mae: 8.9667 - r2_keras: 0.9394 - root_mean_squared_error: 13.5917 - val_loss: 1400.0590 - val_mae: 26.4046 - val_r2_keras: 0.2764 - val_root_mean_squared_error: 35.2986
# Epoch 136/200
# 14849/14849 - 1s - loss: 190.1531 - mae: 8.9170 - r2_keras: 0.9418 - root_mean_squared_error: 13.3416 - val_loss: 2263.6211 - val_mae: 28.7530 - val_r2_keras: -3.3473e-01 - val_root_mean_squared_error: 41.2970
# Epoch 137/200
# 14849/14849 - 1s - loss: 180.5383 - mae: 8.8008 - r2_keras: 0.9442 - root_mean_squared_error: 13.1246 - val_loss: 2089.6428 - val_mae: 29.4013 - val_r2_keras: -1.8438e-01 - val_root_mean_squared_error: 40.8944
# Epoch 138/200
# 14849/14849 - 1s - loss: 187.5155 - mae: 8.9906 - r2_keras: 0.9423 - root_mean_squared_error: 13.4288 - val_loss: 2575.7405 - val_mae: 31.4299 - val_r2_keras: -4.8143e-01 - val_root_mean_squared_error: 46.2582
# Epoch 139/200
# 14849/14849 - 1s - loss: 191.6187 - mae: 8.8828 - r2_keras: 0.9405 - root_mean_squared_error: 13.4808 - val_loss: 2178.1234 - val_mae: 28.5590 - val_r2_keras: -3.1220e-01 - val_root_mean_squared_error: 41.1411
# Epoch 140/200
# 14849/14849 - 1s - loss: 170.9285 - mae: 8.6327 - r2_keras: 0.9473 - root_mean_squared_error: 12.8515 - val_loss: 2435.3263 - val_mae: 32.1518 - val_r2_keras: -4.7082e-01 - val_root_mean_squared_error: 44.0002
# Epoch 141/200
# 14849/14849 - 1s - loss: 180.1844 - mae: 8.7138 - r2_keras: 0.9447 - root_mean_squared_error: 13.0917 - val_loss: 2387.4050 - val_mae: 30.1862 - val_r2_keras: -4.0226e-01 - val_root_mean_squared_error: 42.8178
# Epoch 142/200
# 14849/14849 - 1s - loss: 181.7533 - mae: 8.8238 - r2_keras: 0.9445 - root_mean_squared_error: 13.1632 - val_loss: 2270.2769 - val_mae: 28.5267 - val_r2_keras: -3.8457e-01 - val_root_mean_squared_error: 43.7321
# Epoch 143/200
# 14849/14849 - 1s - loss: 174.0963 - mae: 8.6178 - r2_keras: 0.9458 - root_mean_squared_error: 12.8953 - val_loss: 2671.1129 - val_mae: 31.8658 - val_r2_keras: -5.5571e-01 - val_root_mean_squared_error: 46.6882
# Epoch 144/200
# 14849/14849 - 1s - loss: 171.0368 - mae: 8.6937 - r2_keras: 0.9470 - root_mean_squared_error: 12.8716 - val_loss: 2752.6260 - val_mae: 31.5715 - val_r2_keras: -6.8814e-01 - val_root_mean_squared_error: 44.3032
# Epoch 145/200
# 14849/14849 - 1s - loss: 175.0636 - mae: 8.6785 - r2_keras: 0.9456 - root_mean_squared_error: 12.8603 - val_loss: 2396.7986 - val_mae: 31.3950 - val_r2_keras: -4.2492e-01 - val_root_mean_squared_error: 44.7462
# Epoch 146/200
# 14849/14849 - 1s - loss: 170.5498 - mae: 8.5587 - r2_keras: 0.9481 - root_mean_squared_error: 12.7247 - val_loss: 2820.7443 - val_mae: 31.3543 - val_r2_keras: -7.2763e-01 - val_root_mean_squared_error: 45.3889
# Epoch 147/200
# 14849/14849 - 1s - loss: 171.1618 - mae: 8.6411 - r2_keras: 0.9475 - root_mean_squared_error: 12.8130 - val_loss: 2571.7952 - val_mae: 30.6570 - val_r2_keras: -5.3504e-01 - val_root_mean_squared_error: 46.7930
# Epoch 148/200
# 14849/14849 - 1s - loss: 171.2771 - mae: 8.4959 - r2_keras: 0.9479 - root_mean_squared_error: 12.6791 - val_loss: 3233.6493 - val_mae: 34.0386 - val_r2_keras: -9.2699e-01 - val_root_mean_squared_error: 48.5402
# Epoch 149/200
# 14849/14849 - 1s - loss: 172.5141 - mae: 8.5222 - r2_keras: 0.9466 - root_mean_squared_error: 12.8407 - val_loss: 3052.2107 - val_mae: 33.9458 - val_r2_keras: -8.6229e-01 - val_root_mean_squared_error: 49.0707
# Epoch 150/200
# 14849/14849 - 1s - loss: 185.2604 - mae: 8.7224 - r2_keras: 0.9426 - root_mean_squared_error: 13.0998 - val_loss: 4040.8904 - val_mae: 39.7451 - val_r2_keras: -1.3240e+00 - val_root_mean_squared_error: 56.0466
# Epoch 151/200
# 14849/14849 - 1s - loss: 170.7249 - mae: 8.5249 - r2_keras: 0.9463 - root_mean_squared_error: 12.6783 - val_loss: 2467.7423 - val_mae: 34.1803 - val_r2_keras: -3.0588e-01 - val_root_mean_squared_error: 47.8046
# Epoch 152/200
# 14849/14849 - 1s - loss: 167.8419 - mae: 8.4321 - r2_keras: 0.9485 - root_mean_squared_error: 12.5788 - val_loss: 3327.3470 - val_mae: 35.2002 - val_r2_keras: -9.3549e-01 - val_root_mean_squared_error: 51.4260
# Epoch 153/200
# 14849/14849 - 1s - loss: 158.9328 - mae: 8.3540 - r2_keras: 0.9510 - root_mean_squared_error: 12.3196 - val_loss: 3247.5264 - val_mae: 35.0816 - val_r2_keras: -6.3559e-01 - val_root_mean_squared_error: 54.2819
# Epoch 154/200
# 14849/14849 - 1s - loss: 151.4894 - mae: 8.2619 - r2_keras: 0.9532 - root_mean_squared_error: 11.9975 - val_loss: 2280.0252 - val_mae: 31.2711 - val_r2_keras: -3.3511e-01 - val_root_mean_squared_error: 43.2280
# Epoch 155/200
# 14849/14849 - 1s - loss: 185.9701 - mae: 8.6947 - r2_keras: 0.9432 - root_mean_squared_error: 13.0518 - val_loss: 2811.9401 - val_mae: 31.8605 - val_r2_keras: -4.3480e-01 - val_root_mean_squared_error: 49.9591
# Epoch 156/200
# 14849/14849 - 1s - loss: 154.2056 - mae: 8.3064 - r2_keras: 0.9520 - root_mean_squared_error: 12.2470 - val_loss: 4239.5182 - val_mae: 41.7823 - val_r2_keras: -1.3579e+00 - val_root_mean_squared_error: 60.4913
# Epoch 157/200
# 14849/14849 - 1s - loss: 164.6163 - mae: 8.3839 - r2_keras: 0.9498 - root_mean_squared_error: 12.3821 - val_loss: 2553.7660 - val_mae: 31.2113 - val_r2_keras: -5.3085e-01 - val_root_mean_squared_error: 45.8535
# Epoch 158/200
# 14849/14849 - 1s - loss: 166.7822 - mae: 8.4512 - r2_keras: 0.9486 - root_mean_squared_error: 12.6185 - val_loss: 2922.9235 - val_mae: 34.8326 - val_r2_keras: -5.9047e-01 - val_root_mean_squared_error: 50.5602
# Epoch 159/200
# 14849/14849 - 1s - loss: 160.8530 - mae: 8.3421 - r2_keras: 0.9501 - root_mean_squared_error: 12.3831 - val_loss: 2583.7567 - val_mae: 30.9156 - val_r2_keras: -4.9846e-01 - val_root_mean_squared_error: 45.3071
# Epoch 160/200
# 14849/14849 - 1s - loss: 149.1029 - mae: 8.1531 - r2_keras: 0.9535 - root_mean_squared_error: 11.9330 - val_loss: 2406.4724 - val_mae: 31.1753 - val_r2_keras: -4.0861e-01 - val_root_mean_squared_error: 46.2917
# Epoch 161/200
# 14849/14849 - 1s - loss: 152.2764 - mae: 8.2642 - r2_keras: 0.9533 - root_mean_squared_error: 12.0299 - val_loss: 3133.0033 - val_mae: 35.0037 - val_r2_keras: -7.5460e-01 - val_root_mean_squared_error: 51.2681
# Epoch 162/200
# 14849/14849 - 1s - loss: 168.4903 - mae: 8.4241 - r2_keras: 0.9483 - root_mean_squared_error: 12.5758 - val_loss: 2089.3828 - val_mae: 28.3235 - val_r2_keras: -2.7199e-01 - val_root_mean_squared_error: 42.2442
# Epoch 163/200
# 14849/14849 - 1s - loss: 146.3807 - mae: 8.0595 - r2_keras: 0.9550 - root_mean_squared_error: 11.8547 - val_loss: 2802.4038 - val_mae: 32.6465 - val_r2_keras: -6.0636e-01 - val_root_mean_squared_error: 49.0717
# Epoch 164/200
# 14849/14849 - 1s - loss: 159.2789 - mae: 8.2397 - r2_keras: 0.9508 - root_mean_squared_error: 12.3152 - val_loss: 2976.9046 - val_mae: 32.7010 - val_r2_keras: -7.5809e-01 - val_root_mean_squared_error: 47.5207
# Epoch 165/200
# 14849/14849 - 1s - loss: 154.6684 - mae: 8.1644 - r2_keras: 0.9516 - root_mean_squared_error: 12.0691 - val_loss: 2140.6393 - val_mae: 34.6420 - val_r2_keras: -1.2884e-01 - val_root_mean_squared_error: 44.9681
# Epoch 166/200
# 14849/14849 - 1s - loss: 160.1512 - mae: 8.1345 - r2_keras: 0.9501 - root_mean_squared_error: 12.2308 - val_loss: 2599.2875 - val_mae: 32.1324 - val_r2_keras: -5.3014e-01 - val_root_mean_squared_error: 45.7811
# Epoch 167/200
# 14849/14849 - 1s - loss: 148.5727 - mae: 8.1502 - r2_keras: 0.9538 - root_mean_squared_error: 11.9609 - val_loss: 3120.3840 - val_mae: 35.5888 - val_r2_keras: -8.8003e-01 - val_root_mean_squared_error: 50.1243
# Epoch 168/200
# 14849/14849 - 1s - loss: 158.3087 - mae: 8.2844 - r2_keras: 0.9513 - root_mean_squared_error: 12.2965 - val_loss: 2261.8025 - val_mae: 29.7023 - val_r2_keras: -4.1381e-01 - val_root_mean_squared_error: 45.0811
# Epoch 169/200
# 14849/14849 - 1s - loss: 144.7184 - mae: 8.0226 - r2_keras: 0.9554 - root_mean_squared_error: 11.7450 - val_loss: 3543.0308 - val_mae: 36.3453 - val_r2_keras: -1.1559e+00 - val_root_mean_squared_error: 53.5066
# Epoch 170/200
# 14849/14849 - 1s - loss: 145.7139 - mae: 7.8055 - r2_keras: 0.9555 - root_mean_squared_error: 11.6061 - val_loss: 3887.7743 - val_mae: 38.1514 - val_r2_keras: -1.2518e+00 - val_root_mean_squared_error: 55.0132
# Epoch 171/200
# 14849/14849 - 1s - loss: 151.6932 - mae: 8.1059 - r2_keras: 0.9534 - root_mean_squared_error: 12.0048 - val_loss: 3163.1989 - val_mae: 33.3365 - val_r2_keras: -9.1933e-01 - val_root_mean_squared_error: 47.7943
# Epoch 172/200
# 14849/14849 - 1s - loss: 145.6177 - mae: 7.8749 - r2_keras: 0.9557 - root_mean_squared_error: 11.5369 - val_loss: 3408.6598 - val_mae: 36.4988 - val_r2_keras: -1.0997e+00 - val_root_mean_squared_error: 50.0446
# Epoch 173/200
# 14849/14849 - 1s - loss: 141.6045 - mae: 8.0217 - r2_keras: 0.9564 - root_mean_squared_error: 11.6499 - val_loss: 3278.1726 - val_mae: 35.8462 - val_r2_keras: -9.5987e-01 - val_root_mean_squared_error: 52.1761
# Epoch 174/200
# 14849/14849 - 1s - loss: 145.1997 - mae: 7.9880 - r2_keras: 0.9550 - root_mean_squared_error: 11.7426 - val_loss: 3929.0960 - val_mae: 39.1138 - val_r2_keras: -1.2815e+00 - val_root_mean_squared_error: 55.3051
# Epoch 175/200
# 14849/14849 - 1s - loss: 157.1867 - mae: 8.1880 - r2_keras: 0.9518 - root_mean_squared_error: 12.1091 - val_loss: 3510.5567 - val_mae: 37.9742 - val_r2_keras: -1.0660e+00 - val_root_mean_squared_error: 54.3388
# Epoch 176/200
# 14849/14849 - 1s - loss: 147.0101 - mae: 7.9242 - r2_keras: 0.9550 - root_mean_squared_error: 11.7321 - val_loss: 3795.5420 - val_mae: 38.3425 - val_r2_keras: -1.2509e+00 - val_root_mean_squared_error: 55.5874
# Epoch 177/200
# 14849/14849 - 1s - loss: 147.4252 - mae: 7.9448 - r2_keras: 0.9543 - root_mean_squared_error: 11.8030 - val_loss: 2528.3233 - val_mae: 31.6655 - val_r2_keras: -4.5598e-01 - val_root_mean_squared_error: 46.1497
# Epoch 178/200
# 14849/14849 - 1s - loss: 143.8870 - mae: 7.9271 - r2_keras: 0.9557 - root_mean_squared_error: 11.6220 - val_loss: 3681.9778 - val_mae: 35.9439 - val_r2_keras: -1.2012e+00 - val_root_mean_squared_error: 51.8226
# Epoch 179/200
# 14849/14849 - 1s - loss: 138.9958 - mae: 7.9085 - r2_keras: 0.9569 - root_mean_squared_error: 11.5747 - val_loss: 3192.4445 - val_mae: 35.8167 - val_r2_keras: -8.5973e-01 - val_root_mean_squared_error: 51.2415
# Epoch 180/200
# 14849/14849 - 1s - loss: 145.5988 - mae: 7.9526 - r2_keras: 0.9545 - root_mean_squared_error: 11.7084 - val_loss: 3488.3509 - val_mae: 38.9402 - val_r2_keras: -1.1425e+00 - val_root_mean_squared_error: 50.0233
# Epoch 181/200
# 14849/14849 - 1s - loss: 140.2874 - mae: 7.8314 - r2_keras: 0.9566 - root_mean_squared_error: 11.4478 - val_loss: 3390.3586 - val_mae: 35.4187 - val_r2_keras: -1.0306e+00 - val_root_mean_squared_error: 52.7876
# Epoch 182/200
# 14849/14849 - 1s - loss: 141.2323 - mae: 7.7913 - r2_keras: 0.9552 - root_mean_squared_error: 11.6720 - val_loss: 2965.8953 - val_mae: 37.2281 - val_r2_keras: -7.2949e-01 - val_root_mean_squared_error: 52.9185
# Epoch 183/200
# 14849/14849 - 1s - loss: 140.3750 - mae: 7.7140 - r2_keras: 0.9569 - root_mean_squared_error: 11.3356 - val_loss: 4624.1698 - val_mae: 41.6406 - val_r2_keras: -1.7187e+00 - val_root_mean_squared_error: 61.1497
# Epoch 184/200
# 14849/14849 - 1s - loss: 151.8878 - mae: 7.8781 - r2_keras: 0.9528 - root_mean_squared_error: 11.8910 - val_loss: 3116.3904 - val_mae: 34.4118 - val_r2_keras: -8.2344e-01 - val_root_mean_squared_error: 50.8994
# Epoch 185/200
# 14849/14849 - 1s - loss: 132.0057 - mae: 7.6821 - r2_keras: 0.9594 - root_mean_squared_error: 11.2656 - val_loss: 3030.6125 - val_mae: 34.7511 - val_r2_keras: -8.5768e-01 - val_root_mean_squared_error: 52.7651
# Epoch 186/200
# 14849/14849 - 1s - loss: 133.5512 - mae: 7.7613 - r2_keras: 0.9588 - root_mean_squared_error: 11.3874 - val_loss: 2469.1239 - val_mae: 30.4802 - val_r2_keras: -4.4767e-01 - val_root_mean_squared_error: 46.4943
# Epoch 187/200
# 14849/14849 - 1s - loss: 149.0684 - mae: 8.0016 - r2_keras: 0.9537 - root_mean_squared_error: 11.8997 - val_loss: 2648.7040 - val_mae: 33.5794 - val_r2_keras: -5.4457e-01 - val_root_mean_squared_error: 45.3337
# Epoch 188/200
# 14849/14849 - 1s - loss: 166.1746 - mae: 8.1709 - r2_keras: 0.9487 - root_mean_squared_error: 12.4238 - val_loss: 4375.4450 - val_mae: 42.6734 - val_r2_keras: -1.6018e+00 - val_root_mean_squared_error: 60.4382
# Epoch 189/200
# 14849/14849 - 1s - loss: 121.7406 - mae: 7.5161 - r2_keras: 0.9620 - root_mean_squared_error: 10.8361 - val_loss: 4048.9177 - val_mae: 41.0370 - val_r2_keras: -1.5073e+00 - val_root_mean_squared_error: 56.9988
# Epoch 190/200
# 14849/14849 - 1s - loss: 145.7310 - mae: 7.7681 - r2_keras: 0.9547 - root_mean_squared_error: 11.6041 - val_loss: 3296.1741 - val_mae: 35.0211 - val_r2_keras: -9.6557e-01 - val_root_mean_squared_error: 50.6773
# Epoch 191/200
# 14849/14849 - 1s - loss: 137.7557 - mae: 7.7158 - r2_keras: 0.9570 - root_mean_squared_error: 11.3157 - val_loss: 1523.1550 - val_mae: 26.8545 - val_r2_keras: 0.1793 - val_root_mean_squared_error: 38.4073
# Epoch 192/200
# 14849/14849 - 1s - loss: 126.0948 - mae: 7.5517 - r2_keras: 0.9612 - root_mean_squared_error: 10.9983 - val_loss: 4029.7020 - val_mae: 39.4189 - val_r2_keras: -1.3157e+00 - val_root_mean_squared_error: 56.4668
# Epoch 193/200
# 14849/14849 - 1s - loss: 129.8126 - mae: 7.6540 - r2_keras: 0.9599 - root_mean_squared_error: 11.2415 - val_loss: 3653.2402 - val_mae: 37.8754 - val_r2_keras: -1.1173e+00 - val_root_mean_squared_error: 54.4688
# Epoch 194/200
# 14849/14849 - 1s - loss: 134.1514 - mae: 7.6611 - r2_keras: 0.9589 - root_mean_squared_error: 11.2361 - val_loss: 3926.1188 - val_mae: 37.1759 - val_r2_keras: -1.3038e+00 - val_root_mean_squared_error: 54.9533
# Epoch 195/200
# 14849/14849 - 1s - loss: 141.3505 - mae: 7.7697 - r2_keras: 0.9560 - root_mean_squared_error: 11.4792 - val_loss: 3587.9194 - val_mae: 36.0813 - val_r2_keras: -1.0898e+00 - val_root_mean_squared_error: 52.7257
# Epoch 196/200
# 14849/14849 - 1s - loss: 140.4589 - mae: 7.7320 - r2_keras: 0.9570 - root_mean_squared_error: 11.3983 - val_loss: 3249.3118 - val_mae: 36.5363 - val_r2_keras: -9.0441e-01 - val_root_mean_squared_error: 51.9011
# Epoch 197/200
# 14849/14849 - 1s - loss: 121.9646 - mae: 7.4366 - r2_keras: 0.9625 - root_mean_squared_error: 10.8568 - val_loss: 3557.3821 - val_mae: 35.5983 - val_r2_keras: -1.0803e+00 - val_root_mean_squared_error: 53.6921
# Epoch 198/200
# 14849/14849 - 1s - loss: 149.3030 - mae: 7.8355 - r2_keras: 0.9541 - root_mean_squared_error: 11.7817 - val_loss: 3048.0716 - val_mae: 34.0810 - val_r2_keras: -8.4460e-01 - val_root_mean_squared_error: 47.7807
# Epoch 199/200
# 14849/14849 - 1s - loss: 128.0426 - mae: 7.5120 - r2_keras: 0.9608 - root_mean_squared_error: 11.0344 - val_loss: 3459.2529 - val_mae: 34.7395 - val_r2_keras: -9.9913e-01 - val_root_mean_squared_error: 53.4342
# Epoch 200/200
# 14849/14849 - 1s - loss: 122.6772 - mae: 7.5531 - r2_keras: 0.9627 - root_mean_squared_error: 10.8210 - val_loss: 3021.7036 - val_mae: 33.0844 - val_r2_keras: -8.1240e-01 - val_root_mean_squared_error: 50.7025

# %%
# list all data in history
print(history.history.keys())

# summarize history for R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model r^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_r2.png")

# summarize history for RMSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_RMSE.png")

# summarize history for MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_mae.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(output_path+"/model_regression_loss.png")

# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nR^2: {}'.format(scores[2]))

y_pred = model.predict(seq_array,verbose=1, batch_size=200)
y_true = label_array

test_set = pd.DataFrame(y_pred)
test_set.to_csv(output_path+'/submit_train.csv', index = None)
# Out:
# dict_keys(['loss', 'mae', 'r2_keras', 'root_mean_squared_error', 'val_loss', 'val_mae', 'val_r2_keras', 'val_root_mean_squared_error'])
# 15631/15631 [==============================] - 0s 31us/sample - loss: 192.4797 - mae: 5.9392 - r2_keras: 0.8839 - root_mean_squared_error: 8.1991
#
# MAE: 5.939230442047119
#
# R^2: 0.8838838934898376
# 15631/15631 [==============================] - 1s 51us/sample

# %%
test_x = test_df[sequence_cols].values.astype(np.float32)
print(test_x.shape)
#get encoded data first
encoded_data_test = get_encoded_data(test_x, False)
# Convert the dictionary into DataFrame 
encoded_test = pd.DataFrame(encoded_data_test) 
  
# Using DataFrame.insert() to add a column 
encoded_test.insert(0, "id", test_df['id'], True) 
#add column names
encoded_test.columns = encoded_cols
# Out:
# (13096, 18)
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# 13096/13096 [==============================] - 0s 8us/sample

# %%
##################################
# EVALUATE ON TEST DATA
##################################

# We pick the last sequence for each id in the test data
seq_array_test_last = [encoded_test[encoded_test['id']==id][encoded_cols].values[-sequence_length:] 
                       for id in encoded_test['id'].unique() if len(encoded_test[encoded_test['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
print("seq_array_test_last")
print(seq_array_test_last.shape)

# Similarly, we pick the labels
#print("y_mask")
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
print(label_array_test_last.shape)


# if best iteration's model was saved then load and use it
if os.path.isfile(model_path):
    estimator = load_model(model_path,custom_objects={'r2_keras': r2_keras, 'root_mean_squared_error':root_mean_squared_error})

    # test metrics
    scores_test = estimator.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
    print('\nMAE: {}'.format(scores_test[1]))
    print('\nR^2: {}'.format(scores_test[2]))
    print('\nRMSE: {}'.format(scores_test[3]))

    y_pred_test = estimator.predict(seq_array_test_last)
    y_true_test = label_array_test_last

    test_set = pd.DataFrame(y_pred_test)
    test_set.to_csv(output_path+'/submit_test.csv', index = None)

    #######################
    # Plot in blue color the predicted data and in orange color the
    # actual data to verify visually the accuracy of the model.
        
    x = np.arange(len(y_pred_test))
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots(figsize=(100, 50))
    rects1 = ax.bar(x - width/2, y_pred_test.flatten().round(), width, label='predicted')
    rects2 = ax.bar(x + width/2, y_true_test.flatten(), width, label='true')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('value')
    ax.set_title('prediction')
    ax.set_xticks(x)
    ax.legend()


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)

    plt.show()
    fig.savefig(output_path+"/model_verify_bar.png")
# Out:
# seq_array_test_last
# (93, 50, 9)
# (93, 1)
# 93/93 - 0s - loss: 384.1324 - mae: 14.0454 - r2_keras: 0.7647 - root_mean_squared_error: 19.6021
#
# MAE: 14.045432090759277
#
# R^2: 0.7646724581718445
#
# RMSE: 19.60206413269043
